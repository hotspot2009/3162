# %%
# Import Libraries
import pandas as pd
import pickle as pk
import numpy as np
from collections import defaultdict

# %%
# Import processed sample data from folder
infile = open("Stored Data/sample_review_w_aspects.pickle", "rb")
data = pk.load(infile)
infile.close()

data.head(3)
# Out:
#          Hotel                                            Reviews  \
# 0  Hotel Arena   Only the park outside of the hotel was beauti...
# 1  Hotel Arena   No real complaints the hotel was great great ...
# 2  Hotel Arena   Location was good and staff were ok It is cut...
#
#                                     Aspect_Sentiment
# 0                                {'park': [0.75, 0]}
# 1  {'deposit': [2.875, -1.375], 'payment': [2.875...
# 2  {'hotel': [0.5, 0], 'location': [0.5, 0], 'bre...

# %%
# Merges two dictionary into one, combines the values of its corresponding keys
def merge_dictionies(dict1, dict2):

    dict_merge = defaultdict(list)

    for d in (dict1, dict2):
        for key, value in d.items():
            dict_merge.setdefault(key, [0,0])
            dict_merge[key][0] += value[0]
            dict_merge[key][1] += value[1]
    
    return dict_merge

# merge_dictionies({"a":[5,4]},{"a":[5,4]})

# %%
# Convert pandas DataFrame to python List
array = sorted(data.values.tolist())

# Get all the hotel(unique) names
hotels = data['Hotel'].tolist()
hotels = np.unique(hotels)

hotels
# Out:
# array(['Apex Temple Court Hotel', 'Hotel Arena', 'K K Hotel George',
#        'The Park Grand London Paddington', 'The Principal London'],
#       dtype='<U32')

# %%
def unify_hotels(hotels, cluster_data):
    count = 0
    hotel_single = []
    for hotel in hotels:
        
        dict1 = {}
        while hotel == cluster_data[count][0]:
            dict1 = merge_dictionies(dict1, cluster_data[count][2])
            if count == len(cluster_data)-1:
                break
            else:
                count += 1
            
        hotel_single.append([cluster_data[count-1][0], dict1, count])
        dict1 = {}
        
    return hotel_single

hotel_info = unify_hotels(hotels, array)
hotel_info
# Out:
# [['Apex Temple Court Hotel',
#   defaultdict(list,
#               {'a': [0.5, 0],
#                'a la carte': [0, 0],
#                'a lot': [3.25, -1.5],
#                'access': [0, 0],
#                'acknowledgement': [0, -1.25],
#                'adapter': [0, -0.625],
#                'advance': [1.5, -0.625],
#                'afternoon': [0.875, -0.625],
#                'age': [1.875, -0.875],
#                'air': [1.625, -0.75],
#                'aldwych theatre': [3.0, -1.25],
#                'alex hotel couldn t': [0, 0],
#                'ambience': [1.75, -0.5],
#                'anything': [0.875, 0],
#                'apart': [1.0, -0.625],
#                'apex': [3.25, -1.125],
#                'apex duck': [7.75, -1.5],
#                'apex duck would': [2.625, 0],
#                'apex hotel': [1.75, 0],
#                'area': [5.375, -0.75],
#                'atmosphere': [5.25, -2.125],
#                'aways': [0, -0.25],
#                'backdrop': [1.25, 0],
#                'bacon': [0.625, -1.0],
#                'badge': [0, 0],
#                'balcony': [0, -1.25],
#                'band': [1.0, 0],
#                'bar': [1.125, -3.875],
#                'bar area': [1.0, 0],
#                'bar room wasn': [2.875, -0.25],
#                'bar space': [1.0, -0.75],
#                'bar super': [1.75, 0],
#                'bar variety': [0, -3.0],
#                'bath': [8.0, -3.5],
#                'bath quiet': [0.5, 0],
#                'bath tub': [1.0, 0],
#                'bathroom': [14.375, -4.25],
#                'bathroom mirror': [1.25, 0],
#                'bed': [10.0, -9.0],
#                'bedroom': [0.25, -2.25],
#                'beds': [3.0, -1.25],
#                'beer': [0.875, -0.625],
#                'being': [0.5, 0],
#                'best': [0, 0],
#                'birthday': [1.5, -1.875],
#                'bit': [0.625, -0.75],
#                'board': [0.375, -0.625],
#                'board iron': [2.75, -1.75],
#                'boat': [0, -0.75],
#                'bonus': [0.875, 0],
#                'booking': [1.75, -0.875],
#                'booking com': [0, 0],
#                'bose sound system': [4.0, -1.875],
#                'bose speaker': [3.75, -1.75],
#                'bottle opener': [3.75, -1.75],
#                'box': [1.125, -0.25],
#                'boyfriend': [0.875, 0],
#                'breakfast': [10.25, -7.875],
#                'breakfast buffet continental': [0, 0],
#                'breakfast room': [3.5, -0.75],
#                'breakfast system': [4.25, -3.375],
#                'britain': [0.5, -0.625],
#                'buffet': [0, -1.5],
#                'business': [3.0, -1.25],
#                'cable jack': [1.5, -0.5],
#                'car': [0.5, 0],
#                'card': [0.625, 0],
#                'carpet': [1.875, -0.875],
#                'center': [0, -0.25],
#                'centre': [1.125, -0.125],
#                'change': [1.125, -2.375],
#                'charge': [0, -0.625],
#                'check': [0.875, -0.875],
#                'choc': [1.375, -0.875],
#                'chocolate': [0.875, -0.625],
#                'city': [1.25, -1.25],
#                'city river': [1.0, -1.25],
#                'cleaner': [0, 0],
#                'cleaning staff': [3.5, -1.0],
#                'cleanliness': [1.75, -0.5],
#                'close': [1.125, -0.125],
#                'club lounge': [1.75, -1.5],
#                'coffee': [2.375, -2.125],
#                'coffee machine': [1.75, -1.25],
#                'coffee milk': [0, 0],
#                'cold': [0.75, 0],
#                'colleague': [1.375, -0.5],
#                'com cost': [0, -1.0],
#                'comfy': [1.875, -1.125],
#                'conceierge service': [2.75, -1.0],
#                'concession': [0.5, 0],
#                'concierge': [1.375, -1.625],
#                'connection': [0.75, 0],
#                'consisting': [0.625, -1.0],
#                'continental breakfast': [4.25, -3.375],
#                'convenient': [1.125, -0.125],
#                'corner': [0, 0],
#                'corridor': [1.75, -0.375],
#                'couple': [0.625, -2.25],
#                'course': [0.25, 0],
#                'courtyard terrace': [1.25, 0],
#                'covent garden': [3.0, -1.75],
#                'covent garden soho': [0, 0],
#                'cozy bath': [3.5, 0],
#                'day': [2.25, -0.625],
#                'decoration': [1.25, 0],
#                'design': [0.625, -0.625],
#                'design flaw': [1.25, 0],
#                'desk': [0, -0.125],
#                'didn t': [0, -0.125],
#                'difficult': [0, -0.75],
#                'discount': [0, -0.5],
#                'discreet': [0, -0.875],
#                'distance': [3.375, 0],
#                'distance temple area': [9.0, -3.75],
#                'district': [0, -0.75],
#                'door': [0, 0],
#                'doorway': [0.625, -1.0],
#                'duck': [0.25, -0.375],
#                'duty': [1.375, -0.5],
#                'easy': [0.875, -0.75],
#                'edge': [2.75, 0],
#                'elephant': [0.625, -1.0],
#                'email': [0, -0.625],
#                'end': [1.25, -0.375],
#                'end room': [1.5, 0],
#                'entrance': [1.875, -1.25],
#                'eu': [1.875, -0.875],
#                'evening': [0, 0],
#                'everyone': [0.625, -0.25],
#                'everything': [5.75, -1.375],
#                'excellent': [1.625, -0.75],
#                'expense': [0.5, 0],
#                'extra': [0, -0.125],
#                'extras': [0.5, 0],
#                'extremely': [0.75, -0.75],
#                'face': [0, 0],
#                'fact': [3.0, -1.25],
#                'family': [3.0, -1.625],
#                'fan': [0.375, -0.625],
#                'fault': [1.125, -0.625],
#                'feel home': [1.25, 0],
#                'first night': [2.25, -4.75],
#                'food': [4.75, -4.0],
#                'food menu': [1.75, -3.0],
#                'friday': [0, 0],
#                'front entrance': [2.5, -0.5],
#                'fruit': [0.875, -0.625],
#                'fussy': [0, 0],
#                'glad': [0, 0],
#                'good location': [2.5, 0],
#                'gorgeous': [1.125, 0],
#                'great location': [1.75, -1.5],
#                'great location room': [4.125, -2.25],
#                'guest svc manager francesco': [15.5, -3.0],
#                'hair': [0, 0],
#                'half': [0, 0],
#                'hallway': [0, -1.25],
#                'hallway wall': [3.75, -1.75],
#                'happening': [0, -0.75],
#                'hassle': [2.25, -0.875],
#                'heart': [0.625, 0],
#                'home': [0, 0],
#                'hotel': [30.625, -11.0],
#                'hotel bar': [3.75, 0],
#                'hotel room stank': [1.125, -6.75],
#                'hotel wifi': [1.25, -1.25],
#                'hotel yesterday': [0, -1.25],
#                'husband': [0.125, -0.625],
#                'i': [1.375, -2.125],
#                'idea': [0, -0.25],
#                'ideal': [0, 0],
#                'info': [0.25, 0],
#                'innercourt': [0.875, -0.625],
#                'inside': [2.75, 0],
#                'invitation': [0, -0.875],
#                'invoice': [0, -0.625],
#                'iphone': [1.875, -1.5],
#                'issue': [0, -0.625],
#                'job': [0.25, -0.25],
#                'jug': [0, -0.25],
#                'junior suite': [0, 0],
#                'kind': [0.75, 0],
#                'king': [1.125, -2.375],
#                'location': [16.75, -5.125],
#                'location right': [2.5, -0.375],
#                'london': [5.875, -2.375],
#                'london eye': [0.625, 0],
#                'lot': [3.125, -2.875],
#                'lot staff': [1.625, -0.25],
#                'lounge': [0.875, -0.625],
#                'luca': [1.75, -0.5],
#                'machine': [0.625, 0],
#                'make': [2.25, -0.875],
#                'menu': [3.25, -2.125],
#                'mile': [0, 0],
#                'mine': [0.625, -0.625],
#                'minimalistic': [1.875, -1.0],
#                'mobility': [0, -0.125],
#                'money': [0, -1.25],
#                'mr francis': [2.75, -1.0],
#                'music': [0.375, -0.25],
#                'my standard room': [5.25, -1.5],
#                'need': [0, -0.25],
#                'nice bathroom': [0.5, 0],
#                'nice room': [0, 0],
#                'nice room modern': [0.5, -0.375],
#                'night': [2.625, -0.75],
#                'night room temperature control': [4.5, -9.5],
#                'night s sleep': [6.75, -2.375],
#                'none': [1.0, -2.25],
#                'notch quality': [0, -2.5],
#                'note': [4.5, -1.875],
#                'nothing': [0, 0],
#                'novello': [0, -0.25],
#                'office': [2.875, -1.0],
#                'office window': [0, -0.75],
#                'one': [1.0, -1.25],
#                'one office chair': [7.625, -3.0],
#                'order': [0.625, 0],
#                'packet': [0, -1.25],
#                'parking': [1.5, 0],
#                'part': [0, 0],
#                'party': [1.0, -1.25],
#                'permission': [0, 0],
#                'person': [1.5, -0.625],
#                'phone': [0.125, -2.625],
#                'place': [1.0, 0],
#                'place closer': [2.0, 0],
#                'plan': [0, -1.25],
#                'plane': [0, 0],
#                'possibility': [1.875, -1.0],
#                'presentation': [0, 0],
#                'price': [2.125, -2.125],
#                'pringles': [0, -0.125],
#                'privacy location temple': [1.5, -1.125],
#                'problem': [1.25, -0.375],
#                'proof': [1.75, 0],
#                'pudding': [0.625, -1.0],
#                'quality': [0.5, 0],
#                'question': [0.375, 0],
#                'really': [1.375, -0.875],
#                'reason': [1.75, -0.375],
#                'reception': [4.375, -1.0],
#                'reception greeting': [3.5, -1.0],
#                'reduction coupon': [1.75, 0],
#                'reference': [0, -0.5],
#                'relaxing soak': [2.75, -2.75],
#                'reservation': [1.25, -0.75],
#                'restaurant': [0.5, 0],
#                'restaurant food': [0.5, -3.75],
#                'restaurant neither': [0, 0],
#                'river': [0.5, -1.0],
#                'road': [0.5, 0],
#                'room': [23.5, -17.625],
#                'room balcony': [0.5, -1.0],
#                'room bed': [7.75, -1.5],
#                'room broken': [3.75, -1.75],
#                'room everything': [4.25, -1.25],
#                'room hidden courtyard view': [5.0, 0],
#                'room hotel': [3.0, -3.625],
#                'room key': [2.25, -4.75],
#                'room nothing': [3.75, -2.0],
#                'room price': [0, -1.0],
#                'room service': [2.0, -3.0],
#                'room service food': [2.875, -0.25],
#                'room spacious bathroom': [1.5, -2.25],
#                'rubber duck': [0, 0],
#                'sausage': [0.625, -1.0],
#                'seal': [0, 0],
#                'seating': [0.5, 0],
#                'section': [0.5, -0.625],
#                'selection': [2.0, -1.0],
#                'service': [0, -2.75],
#                'shard half hour walk': [0, -3.0],
#                'show': [2.75, -0.75],
#                'shower': [6.375, -2.75],
#                'shower cabin': [3.5, 0],
#                'shower door': [0, 0],
#                'shut': [0.25, -2.25],
#                'side': [1.125, -2.375],
#                'sight': [0.5, 0],
#                'sink': [0, 0],
#                'site': [0, 0],
#                'size': [2.0, -0.75],
#                'sized bathroom': [7.75, -1.5],
#                'slab third night': [3.375, -7.125],
#                'soft': [1.125, -2.375],
#                'soho oxford st nice': [0.5, -3.25],
#                'son': [0, -0.5],
#                'soulless': [0, -1.25],
#                'spaciousness': [2.625, -0.125],
#                'spent': [0, -1.25],
#                'spoonful': [0.625, -1.0],
#                'st pancras fairly': [1.0, -2.75],
#                'st paul s tate modern': [2.5, -2.75],
#                'staff': [11.625, -4.75],
#                'staff didn t': [2.5, 0],
#                'staff walking': [2.0, -1.25],
#                'standard': [2.5, -0.75],
#                'standard hotel': [0, -2.5],
#                'standard room': [2.25, 0],
#                'start': [1.5, -0.625],
#                'stay': [1.625, 0],
#                'street': [1.375, -1.625],
#                'student': [0, -1.25],
#                'stuff': [0.875, 0],
#                'subway station': [0.5, 0],
#                'sue': [0, 0],
#                'suite': [0.875, 0],
#                'summer': [0.75, -1.25],
#                'sunday': [0, 0],
#                'supplement': [0, 0],
#                'system outage': [1.5, 0],
#                't': [0, -0.375],
#                't experience': [5.5, -2.0],
#                't forget': [3.25, -0.5],
#                't use': [3.5, -0.75],
#                'table': [1.375, -1.625],
#                'taxi': [0, -0.75],
#                'tea': [0, -0.25],
#                'tea making': [3.25, -1.5],
#                'temple': [0.5, -0.375],
#                'temple court': [3.0, -1.25],
#                'thank you': [0, 0],
#                'theater district': [5.5, 0],
#                'theatre district': [0.5, -3.75],
#                'thing': [2.75, -1.5],
#                'tidy': [1.75, -0.375],
#                'time': [4.75, -2.125],
#                'toilet': [0.625, 0],
#                'toilet bowl': [1.25, 0],
#                'toilet seat': [1.25, 0],
#                'tomato': [0.625, -1.0],
#                'tooth': [0, -0.625],
#                'top': [0.625, 0],
#                'trafalgar square': [0, -1.5],
#                'traffic noise': [1.0, -0.5],
#                'transport blackfriars tube station': [5.0, 0],
#                'tray charge': [2.0, -4.5],
#                'trip': [0, -1.25],
#                'tube': [1.375, -0.875],
#                'tube room': [2.25, 0],
#                'tv': [2.375, -3.125],
#                'underground': [0, -0.25],
#                'underground tube': [5.5, 0],
#                'understand': [0, 0],
#                'upgrade': [3.875, -0.75],
#                'upon arrival': [1.75, 0],
#                'value': [3.875, -2.125],
#                'variety': [0.875, -0.625],
#                'ventilation': [0.25, -2.25],
#                'very': [0.75, -1.125],
#                'vibe': [2.5, -0.75],
#                'view': [0.875, -0.875],
#                'voucher': [1.5, -0.625],
#                'walk': [2.875, -2.75],
#                'walkway': [0, -1.25],
#                'wardrobe space': [3.25, -1.5],
#                'water': [0, 0],
#                'water soda wine': [2.625, -1.875],
#                'way': [1.875, -1.0],
#                'weather': [1.25, -0.25],
#                'wednesday thursday': [2.25, -4.75],
#                'week': [3.0, -1.25],
#                'weekend': [2.875, -0.625],
#                'westminster': [0, -0.75],
#                'westminster room': [1.5, -2.25],
#                'wheelchair': [0, -0.125],
#                'whenever': [0.875, 0],
#                'wi fi': [0, -3.75],
#                'wth': [1.75, -0.5]}),
#   109],
#  ['Hotel Arena',
#   defaultdict(list,
#               {'access': [1.75, 0],
#                'advance': [0, -1.25],
#                'advertising': [0.5, -0.75],
#                'affair': [2.625, -2.375],
#                'aircondition': [0, -0.75],
#                'airconditioning': [0, -0.75],
#                'airport': [0, -1.25],
#                'airy': [0.75, -0.75],
#                'am': [0.25, -0.375],
#                'amazing building park location amazing bobby gin': [0, 0],
#                'amount': [0.625, -0.625],
#                'amsterdam': [2.375, -4.75],
#                'amsterdam room': [1.25, -1.5],
#                'amsterdam staff': [1.5, -1.75],
#                'amsterdam would': [1.0, -2.0],
#                'annoying': [0, -0.625],
#                'answer': [0, 0],
#                'anyone': [2.875, -1.375],
#                'anything': [4.125, -2.375],
#                'anything door': [0.5, -2.5],
#                'appreciation': [0.5, -0.75],
#                'architecture': [1.0, 0],
#                'area': [1.75, -2.5],
#                'area shower': [5.25, -4.75],
#                'arrival': [0.875, -2.25],
#                'aside': [2.875, -1.375],
#                'asleep': [0, -1.375],
#                'attention': [2.75, -3.0],
#                'audio recording': [0.75, -1.25],
#                'awesome park arrive': [6.125, -4.125],
#                'axcess': [0, 0],
#                'background': [2.875, -1.375],
#                'backyard': [0, 0],
#                'bacon': [0, -0.5],
#                'bakery': [1.625, 0],
#                'banging': [0.5, -1.5],
#                'bank': [0.625, -0.625],
#                'bar': [2.0, -1.875],
#                'bar area': [6.75, -1.5],
#                'bar restaurant area': [4.125, 0],
#                'bar staff': [0, -2.5],
#                'barefoot': [2.125, -4.125],
#                'bath': [1.375, 0],
#                'bath tub': [0, 0],
#                'bathroom': [7.25, -10.5],
#                'bathroom lighting': [0.25, 0],
#                'bathtub': [0, 0],
#                'beautiful': [0.25, 0],
#                'beauty': [1.375, 0],
#                'bed': [19.0, -12.75],
#                'bed didn': [1.25, 0],
#                'bedroom': [0.875, -1.5],
#                'bid': [0.5, -1.5],
#                'big breakfast spread perfect': [1.0, 0],
#                'bike': [0.25, -1.0],
#                'bio weapon': [0, -1.25],
#                'birthday present please': [1.0, 0],
#                'bit': [6.125, -6.5],
#                'boiler': [1.625, 0],
#                'book': [0.375, 0],
#                'break': [4.125, -2.375],
#                'breakfast': [14.25, -12.875],
#                'breakfast check': [2.5, -5.5],
#                'breakfast food': [5.0, 0],
#                'breakfast range': [1.0, 0],
#                'breakfast selection': [1.0, -1.5],
#                'breakfast selection quiet': [1.875, 0],
#                'breakfast staff': [2.5, -5.5],
#                'bright': [0.75, -0.75],
#                'brit': [0, -0.25],
#                'broken window': [1.25, -1.25],
#                'brunch': [0.5, 0],
#                'btw': [0.625, 0],
#                'buffet': [0.75, -0.625],
#                'building': [15.0, -8.125],
#                'building meeting': [0, 0],
#                'building work': [7.25, -5.75],
#                'business': [0.5, 0],
#                'cappuccino room': [2.5, -4.25],
#                'card': [0.625, -0.625],
#                'care': [3.125, -3.125],
#                'cause': [0.5, -0.75],
#                'ceiling': [1.0, 0],
#                'center': [0, 0],
#                'center train': [1.75, 0],
#                'centre': [1.875, -2.25],
#                'chair': [1.25, -1.625],
#                'chair room service hair dryer fridge kettle': [5.125, -0.75],
#                'change': [0.25, -1.0],
#                'check': [4.625, -8.125],
#                'chill': [0.875, 0],
#                'city': [8.375, -5.625],
#                'city center': [0.25, -1.25],
#                'city centre': [5.5, -1.5],
#                'city tax': [0.625, 0],
#                'clean': [3.375, -0.75],
#                'cleaner': [1.375, -0.625],
#                'cleaning': [1.75, -5.0],
#                'cleaning lady': [1.875, -5.875],
#                'clock': [0.5, -1.375],
#                'coffee': [4.125, -0.125],
#                'com': [0.375, -0.625],
#                'com price': [0, 0],
#                'comfy': [0.5, 0],
#                'company': [0.375, 0],
#                'complain': [0, -0.5],
#                'connoisseur': [0, -0.25],
#                'construction': [2.125, -5.0],
#                'construction renovation': [0, -2.5],
#                'construction work': [0, -2.5],
#                'consumer': [0.375, 0],
#                'convenience': [0.625, 0],
#                'cool': [0, 0],
#                'corridor': [0.5, -1.5],
#                'couple': [2.625, -2.375],
#                'course': [0.625, -0.875],
#                'courtyard': [4.125, -2.375],
#                'curtain': [0, -0.5],
#                'dam square': [0.75, 0],
#                'damp': [2.625, -2.375],
#                'day': [9.0, -9.125],
#                'deal': [0.625, -0.625],
#                'deposit': [2.875, -1.375],
#                'design': [2.0, -0.75],
#                'design disaster': [1.25, -5.75],
#                'desk chairs': [0, -1.0],
#                'destination': [0, -0.25],
#                'difficulty': [2.25, -0.875],
#                'dining': [0, 0],
#                'dinner bar': [0, -0.75],
#                'direction': [0, -0.75],
#                'dirt': [0.875, -3.625],
#                'dirty': [4.875, -9.625],
#                'disaster room': [1.75, -7.25],
#                'disruption': [0.875, 0],
#                'distance': [0.5, -1.0],
#                'dog my shower drain': [5.5, -16.5],
#                'door': [3.5, -5.25],
#                'dust': [0.875, -3.625],
#                'duvet': [0.75, -0.625],
#                'element': [0.75, -0.625],
#                'english': [1.625, 0],
#                'entrance': [0.75, 0],
#                'euros': [0.375, -2.125],
#                'evening': [0, -0.25],
#                'everyone': [0.625, -0.5],
#                'everything': [0.75, -1.5],
#                'extra': [0, 0],
#                'eye contact': [1.25, 0],
#                'fact': [0.375, -1.25],
#                'fault': [2.625, -2.375],
#                'feel': [1.5, -1.375],
#                'feeling': [0.875, -0.625],
#                'first': [0, -0.625],
#                'floor': [6.5, -8.5],
#                'floor corridor': [8.625, -4.75],
#                'food': [1.625, -1.25],
#                'fridge': [0.875, -0.5],
#                'front': [0.25, -1.0],
#                'front desk': [3.75, -4.75],
#                'garage door': [0, 0],
#                'garden view': [1.75, 0],
#                'gentleman': [0.625, -0.625],
#                'glass bathroom': [2.0, -1.25],
#                'glass box': [1.25, -2.0],
#                'glass wall': [0, -0.25],
#                'glass window': [1.0, -1.5],
#                'great': [0, 0],
#                'great hotel': [0, 0],
#                'great location': [1.25, 0],
#                'greenery': [0.5, -0.75],
#                'guess': [2.625, -2.375],
#                'guest': [4.125, -2.375],
#                'gutter': [0.5, -0.75],
#                'hair': [0, 0],
#                'hair dryer': [1.25, 0],
#                'half': [0.375, 0],
#                'hall': [0, -0.625],
#                'hallway': [0, -0.625],
#                'hand': [0.125, 0],
#                'handrail': [0, 0],
#                'handrail was kind': [2.25, -2.5],
#                'head location': [4.25, -2.0],
#                'health food': [1.5, -1.25],
#                'heating': [1.25, -2.125],
#                'hell': [0, -0.875],
#                'help': [2.75, -0.75],
#                'history': [1.0, 0],
#                'hold church': [3.5, -2.75],
#                'holiday': [0.25, -0.625],
#                'hospital': [0.875, -0.5],
#                'hot': [1.25, -3.375],
#                'hotel': [45.625, -25.625],
#                'hotel bar': [0, -1.25],
#                'hotel couldn t fault': [4.25, -1.5],
#                'hotel dirty dusty': [1.625, -7.875],
#                'hotel inside': [4.375, -2.75],
#                'hotel manager': [2.5, -1.0],
#                'hotel public transportation': [5.375, 0],
#                'hotel restaurant': [2.0, -1.5],
#                'hotel room': [1.625, -1.875],
#                'hotel s chapel': [3.375, -1.25],
#                'hotel s restaurant': [1.875, -1.875],
#                'hour': [0.625, 0],
#                'i': [9.0, -10.25],
#                'idea': [0.75, -0.125],
#                'information': [0, 0],
#                'inside': [2.125, -0.75],
#                'interest': [0, -0.5],
#                'issue': [4.375, -3.375],
#                'juice': [0.625, -1.625],
#                'july': [0, 0],
#                'key everyday': [0, 0],
#                'kinky amsterdam window': [2.25, 0],
#                'lay': [0.625, -0.875],
#                'level': [4.625, -0.875],
#                'light': [0, -0.625],
#                'lighting': [0.5, -0.75],
#                'line': [0.375, 0],
#                'little privacy': [0, -1.25],
#                'lobby': [0.375, 0],
#                'location': [12.875, -4.5],
#                'location my': [1.0, -1.5],
#                'location set': [2.0, 0],
#                'london': [4.125, -2.375],
#                'lot': [2.375, -4.5],
#                'love first room': [7.875, -7.125],
#                'luggage': [0, 0],
#                'mail': [0.375, -0.625],
#                'manager': [0, -0.875],
#                'mattress': [0.75, -0.75],
#                'meal': [0.25, 0],
#                'meant': [0.625, -0.625],
#                'mess shouldn t': [0, 0],
#                'meter': [1.25, -2.125],
#                'metro close': [4.5, -1.75],
#                'middle': [1.0, -0.5],
#                'midnight': [2.125, -1.125],
#                'mile': [4.125, -2.375],
#                'mini fridge': [0, -1.25],
#                'minute walk': [1.0, -2.0],
#                'mirror': [0.5, -2.125],
#                'mistake': [0.375, 0],
#                'mix': [0, -0.5],
#                'moment': [0.5, -0.75],
#                'monastery building': [3.25, 0],
#                'money': [0.375, 0],
#                'mood': [1.625, 0],
#                'morning': [2.5, -0.625],
#                'morning water': [2.5, -4.25],
#                'nail': [0.75, 0],
#                'neck room service': [1.0, -3.125],
#                'need': [3.5, -2.375],
#                'negligence': [2.125, -0.5],
#                'nice restaurant': [2.125, -1.0],
#                'night': [3.125, -1.0],
#                'night guard': [0, -0.25],
#                'night room': [1.25, -1.5],
#                'night shift manager': [6.375, -1.5],
#                'noise': [1.125, -1.0],
#                'nothing': [0.625, -0.875],
#                'novelty': [4.125, -2.375],
#                'o clock': [4.75, -5.75],
#                'occurrence': [1.375, -4.125],
#                'offer': [0.625, -0.5],
#                'one': [1.875, -1.375],
#                'online': [0.25, 0],
#                'oosterpark': [3.125, -0.875],
#                'opinion': [0.5, -0.625],
#                'option': [2.875, -1.375],
#                'order': [1.375, -0.625],
#                'order shower': [2.25, -1.625],
#                'orphanage': [0.25, 0],
#                'outside': [1.25, -0.25],
#                'ownership': [0, 0],
#                'pad': [1.25, -1.625],
#                'pain': [0, -0.25],
#                'park': [23.625, -8.625],
#                'park ca': [1.125, -0.625],
#                'park cool': [0, 0],
#                'park room': [6.75, -1.5],
#                'part': [0, 0],
#                'party': [0.625, 0],
#                'payment': [2.875, -1.375],
#                'perfect': [0, -1.25],
#                'perfect launch pad': [0.75, 0],
#                'phone': [0, -0.625],
#                'photos': [0.625, 0],
#                'pillows super stiff': [0.75, -1.875],
#                'place': [5.625, -1.25],
#                'place great park': [2.625, 0],
#                'plaster': [2.625, -2.375],
#                'point': [0.625, -1.25],
#                'pointless': [0.625, -0.625],
#                'pond': [0, -0.375],
#                'pop': [2.625, -2.375],
#                'post': [0.375, 0],
#                'practice': [0, 0],
#                'pretty': [1.125, 0],
#                'price': [1.5, -1.25],
#                'pricing': [0.25, 0],
#                'problem': [2.625, -2.375],
#                'product': [0.125, 0],
#                'property': [2.125, -0.5],
#                'proud': [1.625, -0.625],
#                'public': [0.25, 0],
#                'quality': [1.875, 0],
#                'quality food': [5.75, -2.75],
#                'question': [0.625, 0],
#                'rain': [0, -0.625],
#                'rainfall': [1.375, -4.125],
#                'reason': [0.625, 0],
#                'reception': [3.125, -3.75],
#                'reception area': [2.0, -4.75],
#                'receptionist': [0.625, 0],
#                'refrigerator': [0, -1.875],
#                'relaxing stay': [1.0, 0],
#                'remodeling': [0, 0],
#                'renovation': [0.875, 0],
#                'rent': [1.375, -1.0],
#                'repairman': [2.125, -0.5],
#                'request': [1.375, -4.125],
#                'restaurant': [6.75, -2.375],
#                'restaurant downstairs': [0.5, 0],
#                'restaurant menu': [1.0, -2.0],
#                'ride': [1.375, 0],
#                'right friendly': [0.5, 0],
#                'roof': [1.375, -4.125],
#                'room': [37.375, -37.375],
#                'room decor': [0, -0.125],
#                'room decoration': [2.25, -2.25],
#                'room fridge': [0, -1.375],
#                'room i': [8.25, -8.0],
#                'room i guess': [8.25, -8.875],
#                'room was': [2.5, -5.5],
#                'route': [0, -0.25],
#                'saturday night': [0, -1.25],
#                'search': [0.5, -0.75],
#                'selection': [0.75, -0.625],
#                'service': [5.875, -4.125],
#                'set': [1.5, -0.75],
#                'setting': [3.375, -0.75],
#                'shampoo body': [1.25, 0],
#                'shampoo shower gel dispenser': [0, -7.5],
#                'sheet': [0.75, -0.625],
#                'shower': [1.375, -3.625],
#                'shower tea': [1.75, -0.25],
#                'showering': [0.25, -0.625],
#                'site': [0, -0.875],
#                'site restaurant': [5.75, -2.75],
#                'situation': [0.25, -1.0],
#                'slam': [0.625, -0.875],
#                'sleep': [1.125, 0],
#                'smell': [1.25, -2.875],
#                'soap': [0.875, -0.125],
#                'someone': [1.25, 0],
#                'someone drilling concrete': [2.25, 0],
#                'something': [3.5, -3.25],
#                'something wet': [1.25, -3.25],
#                'sort': [0, -0.625],
#                'sound': [1.25, -0.75],
#                'space': [2.0, -4.0],
#                'speed': [1.375, -0.75],
#                'split level room': [7.625, -2.75],
#                'spot': [2.875, -1.375],
#                'staff': [24.625, -15.5],
#                'staff food': [2.0, 0],
#                'staff offer': [5.75, -2.75],
#                'staff oostpark': [1.25, 0],
#                'staff shampoo': [1.75, -0.25],
#                'staircase': [2.125, -3.625],
#                'standard': [0.5, -0.75],
#                'start': [0.5, 0],
#                'state': [1.125, 0],
#                'station': [3.0, -1.625],
#                'stay': [3.625, -2.875],
#                'sticky': [0.625, -1.625],
#                'story': [0, -0.75],
#                'street': [0.5, -0.75],
#                'structure': [2.25, -2.125],
#                'style': [0, 0],
#                'sure': [1.75, -1.375],
#                'system': [0, -0.125],
#                't': [2.25, -3.875],
#                't seem': [2.875, -5.375],
#                'taste': [1.125, -1.375],
#                'taxi': [0.875, 0],
#                'tea': [0, -0.5],
#                'tea coffee': [0.5, -2.0],
#                'telephone huge price difference': [0, 0],
#                'temperature forget': [1.25, -2.125],
#                'tennis court': [0, -0.75],
#                'terrace': [0.75, -0.625],
#                'their': [4.125, -2.375],
#                'thermostat': [0, -1.875],
#                'thing': [1.625, -1.875],
#                'ticket': [2.125, 0],
#                'ticket machine': [3.875, 0],
#                'time': [2.625, -0.75],
#                'toilet': [1.25, -1.25],
#                'top': [3.5, -1.5],
#                'tour': [0.25, -1.0],
#                'tourist': [2.125, -1.0],
#                'tourist trap': [2.0, -2.5],
#                'town': [1.75, -0.875],
#                'training': [0.625, -0.625],
#                'tram': [4.0, -2.25],
#                'tram ride': [1.75, 0],
#                'tram stop': [1.0, -2.0],
#                'tram subway': [1.25, -1.5],
#                'tram system': [12.25, -3.0],
#                'transaction': [0.625, -0.625],
#                'transaction charge': [1.25, -1.25],
#                'transformer': [2.625, -2.375],
#                'transport': [0.875, 0],
#                'transportation': [2.75, -1.0],
#                'trash lorry': [0, -0.75],
#                'tv': [0, -0.75],
#                'tv s': [0.75, -2.625],
#                'twist staircase': [0.75, 0],
#                'usb port': [0, -1.25],
#                'use': [0, -1.25],
#                'variety': [2.25, -0.875],
#                'very': [0, -0.75],
#                'view': [5.625, -5.125],
#                'view temporary reception area': [0, 0],
#                'villa suite': [0, 0],
#                'volume': [0.625, 0],
#                'waist': [1.125, 0],
#                'walk': [5.75, -1.5],
#                'walking': [0.25, 0],
#                'wall': [0, -0.5],
#                'wardrobe': [0.625, 0],
#                'wasn t': [0.25, -1.0],
#                'water damage': [7.0, -9.25],
#                'water pressure': [0.25, -1.75],
#                'water problem': [0, 0],
#                'way': [3.625, -1.375],
#                'website': [0.25, 0],
#                'wedding': [0.625, 0],
#                'week': [0.625, -0.625],
#                'white furniture': [2.75, -8.25],
#                'whole': [0.75, -0.625],
#                'wife': [0.375, -1.375],
#                'wifi': [0.5, 0],
#                'window': [1.5, -0.625],
#                'window mechanism': [5.25, -4.75],
#                'wing': [2.625, -2.375],
#                'wood': [0.25, 0],
#                'work': [0.875, -0.5],
#                'wrap': [2.875, -1.375]}),
#   218],
#  ['K K Hotel George',
#   defaultdict(list,
#               {'a': [1.5, 0],
#                'ac': [0.625, -0.5],
#                'access': [3.875, -1.25],
#                'air con': [0.5, 0],
#                'airport': [1.0, 0],
#                'airport friendly': [2.5, 0],
#                'ambience': [0, 0],
#                'amenity': [0, -1.875],
#                'area': [4.25, -0.75],
#                'area breakfast': [3.25, 0],
#                'area sauna': [3.125, -4.0],
#                'arrival': [0, -0.25],
#                'as': [3.25, -1.5],
#                'aspect fantastic location': [5.25, 0],
#                'assistance': [0, 0],
#                'attitude': [0.5, -0.625],
#                'b b': [2.0, -6.25],
#                'back': [0.75, 0],
#                'bacon': [0.375, -1.375],
#                'bakery': [1.625, -1.5],
#                'bar': [2.625, -0.5],
#                'bar area': [7.25, -3.0],
#                'bar wasn': [0, 0],
#                'basement room': [0.5, 0],
#                'bath': [2.125, -0.75],
#                'bath lethal combination': [4.5, -8.25],
#                'bath tub': [3.0, -5.5],
#                'bathroom': [5.125, -4.625],
#                'bathroom shower': [4.25, -2.75],
#                'bathroom sink': [4.75, -0.25],
#                'beautiful': [2.125, -1.375],
#                'beautiful garden': [0, 0],
#                'beautiful garden area': [1.0, 0],
#                'bed': [6.375, -5.5],
#                'beds': [3.125, -2.0],
#                'beer': [2.375, -1.0],
#                'beforehand': [0.125, 0],
#                'billowing': [1.0, 0],
#                'bit': [0.375, -0.75],
#                'block': [0, 0],
#                'boarding': [0, 0],
#                'bonus': [2.25, 0],
#                'book breakfast': [0.25, -3.5],
#                'booking': [0.125, -1.75],
#                'breakfast': [23.0, -9.75],
#                'breakfast buffet': [4.25, -2.75],
#                'breakfast enough': [2.5, -3.75],
#                'breakfast staff': [1.25, -1.875],
#                'breakfast table': [0.625, -0.75],
#                'buffet': [2.625, -0.125],
#                'business centre everyone': [3.375, -3.75],
#                'can t review': [7.375, -3.25],
#                'car': [2.125, -3.125],
#                'carpet': [0, -0.625],
#                'case': [0, 0],
#                'central london': [1.0, 0],
#                'chair': [0.5, -0.625],
#                'charge': [0.125, 0],
#                'check': [1.5, -5.5],
#                'choice': [4.375, -1.5],
#                'city': [2.5, -1.375],
#                'clean bathroom nice shower': [2.5, -3.0],
#                'cleanness': [2.125, -0.75],
#                'clineanliness': [1.0, 0],
#                'closeness': [0, 0],
#                'closet': [0.625, -0.75],
#                'coffee': [1.125, 0],
#                'comfy': [1.0, -0.125],
#                'comfy room': [0, 0],
#                'complaint': [0.5, -1.125],
#                'consideration': [0, -0.625],
#                'convenience': [0, 0],
#                'corner': [0.5, 0],
#                'cost': [1.875, -0.5],
#                'couldn t work': [1.5, 0],
#                'course': [0.375, -1.875],
#                'court': [0, 0],
#                'court paul s': [8.25, 0],
#                'court rd staff': [6.375, -4.125],
#                'court station': [3.25, -1.25],
#                'court tube': [5.75, -1.5],
#                'court tube station': [4.875, -1.5],
#                'court underground station clean quiet breakfast': [6.75, -3.0],
#                'court underground very': [5.25, 0],
#                'cozy': [1.125, -1.25],
#                'credit card': [1.25, -0.75],
#                'cross contamination': [0.75, -2.75],
#                'cutlery': [1.125, -1.25],
#                'daughter': [0.625, -0.75],
#                'day': [5.0, -5.875],
#                'delight': [1.125, -1.625],
#                'deposit': [0.125, 0],
#                'did': [0, -0.125],
#                'didn t': [0.125, -3.0],
#                'diet': [0.5, -0.625],
#                'difference': [0.5, -0.625],
#                'difficult': [0, 0],
#                'disgust': [0, -0.625],
#                'distance': [1.125, 0],
#                'diverse breakfast': [1.875, -3.5],
#                'division': [1.25, 0],
#                'door': [0.625, 0],
#                'drink': [0.5, 0],
#                'drink etc': [1.5, 0],
#                'drink secure parking': [2.25, 0],
#                'drinking water': [2.625, -1.5],
#                'earl': [13.875, -3.75],
#                'earls court': [3.0, 0],
#                'easy': [1.25, 0],
#                'end': [0, 0],
#                'english style': [4.75, -2.0],
#                'english tv': [3.25, -3.0],
#                'equipment': [0, 0],
#                'erls court london': [0, 0],
#                'espresso cappucino': [5.5, 0],
#                'evening': [0.625, -0.75],
#                'excellent': [3.625, -1.5],
#                'experience': [0.75, 0],
#                'explanation': [0.75, 0],
#                'fab experience': [3.625, -1.5],
#                'fab fluffy': [0, 0],
#                'fact': [0.375, -1.875],
#                'family': [2.375, -1.0],
#                'fan': [0, 0],
#                'fast': [0, 0],
#                'fault someone': [0, 0],
#                'firmer pillow': [3.0, -0.25],
#                'fitness area': [3.5, -1.75],
#                'fitness center': [2.25, -1.25],
#                'floor': [2.625, -4.875],
#                'food': [0.75, 0],
#                'food supermarket': [3.25, -3.0],
#                'friend s recommendation': [1.5, 0],
#                'front desk': [0.75, 0],
#                'front desk staff': [1.5, -1.875],
#                'front desk staff would love': [6.25, -1.25],
#                'future': [1.75, -0.875],
#                'garden': [6.125, -1.625],
#                'gentleman': [1.625, -1.5],
#                'get': [0, 0],
#                'glass': [2.375, -1.0],
#                'good location': [3.5, 0],
#                'great choice': [3.0, -0.25],
#                'great location': [3.5, -1.5],
#                'great position': [2.0, 0],
#                'ground floor room l01': [0, -2.0],
#                'gym': [2.25, -2.25],
#                'gym has': [1.75, -1.5],
#                'hadn t': [5.75, -3.625],
#                'hair': [0.75, 0],
#                'hair dryer didn t work': [3.75, 0],
#                'hdmi cable': [2.25, -2.5],
#                'heathrow': [2.25, 0],
#                'heating': [0.5, 0],
#                'hello': [0.5, -0.625],
#                'hilton bankside': [0, 0],
#                'hotel': [35.125, -15.875],
#                'hotel no': [0, 0],
#                'hotel very': [5.375, -2.75],
#                'hour': [0.375, -0.5],
#                'housekeeping': [0.625, -0.75],
#                'husband': [0.875, -1.125],
#                'i': [0.25, -0.625],
#                'idea': [0.625, 0],
#                'inquiry': [2.375, 0],
#                'internet': [0.5, 0],
#                'issue': [0.5, -0.75],
#                'job': [0, -0.125],
#                'k i': [6.25, -8.0],
#                'k k hotel george': [4.5, -5.0],
#                'kensington palace albert hall knightsbridge': [0, -1.25],
#                'kind': [7.125, -6.25],
#                'kind breakfast': [2.75, 0],
#                'knocking noise': [0.75, 0],
#                'lady': [2.125, 0],
#                'laundrette': [0.5, 0],
#                'laundry': [1.25, -0.5],
#                'leanne': [1.375, 0],
#                'leeds': [0, -0.25],
#                'level': [3.125, -4.0],
#                'lighting': [0.625, -2.125],
#                'line': [1.25, 0],
#                'line check': [0, 0],
#                'lobby': [0.875, -0.75],
#                'location': [28.75, -3.875],
#                'location major shopping': [5.25, -2.25],
#                'london': [9.25, -5.125],
#                'london day great shower': [2.0, -0.25],
#                'london great': [2.25, 0],
#                'london hotel': [1.0, 0],
#                'london older facility': [3.75, 0],
#                'london rooms': [3.5, 0],
#                'london s': [1.25, -0.5],
#                'lot': [0, -0.125],
#                'lounge area': [3.0, -1.75],
#                'machine': [1.125, -0.625],
#                'man': [0.875, -1.125],
#                'mashine': [0, 0],
#                'mattress': [1.625, -1.5],
#                'mattress wasn t': [0, -3.75],
#                'maximum': [0.375, -1.875],
#                'meager': [0, 0],
#                'min walk': [0, -1.25],
#                'mini bar': [1.25, 0],
#                'mint chocolate': [1.0, 0],
#                'minute walk': [15.75, -0.5],
#                'mirror': [0, 0],
#                'mistake': [0.375, 0],
#                'month': [0.125, 0],
#                'morning': [0.5, -0.625],
#                'neck': [0, 0],
#                'need': [3.5, -2.25],
#                'neighbourhood': [0.75, 0],
#                'nice': [1.375, -0.75],
#                'night': [6.125, -1.75],
#                'noise': [0.375, 0],
#                'nothing': [4.125, -2.375],
#                'office': [0.125, 0],
#                'one': [0, 0],
#                'opportunity': [0, -0.625],
#                'order': [0.75, 0],
#                'oven': [0.375, -1.375],
#                'parking': [1.75, 0],
#                'perfect location': [1.5, 0],
#                'person': [0.125, 0],
#                'phone': [0.125, 0],
#                'piccadilly line': [0, 0],
#                'place': [0.625, 0],
#                'place underground': [0.25, -3.5],
#                'pleasant': [1.5, -0.875],
#                'plenty': [2.625, -1.375],
#                'position': [2.125, -0.125],
#                'potato': [0.375, -1.375],
#                'power socket': [0, 0],
#                'price': [3.125, -5.125],
#                'probably': [0.625, -0.5],
#                'problem': [3.125, -1.625],
#                'promotion': [1.375, -3.125],
#                'property': [1.25, -0.625],
#                'proximity': [0.5, -0.75],
#                'quality': [5.0, -2.5],
#                'quality breakfast food': [1.875, 0],
#                'railway': [1.25, 0],
#                'ranging': [0.25, -0.875],
#                'rat': [0, -1.5],
#                're': [0, 0],
#                'rear': [2.125, -1.375],
#                'reception': [6.0, -5.125],
#                'reception area': [1.0, -1.25],
#                'request': [2.375, 0],
#                'restaurant': [4.25, -1.25],
#                'restaurants': [1.75, 0],
#                'road nice': [4.0, -1.5],
#                'room': [20.5, -16.0],
#                'room bar': [0, 0],
#                'room bathroom': [1.0, 0],
#                'room bed': [4.0, -1.5],
#                'room desk': [1.0, 0],
#                'room key': [3.0, -5.5],
#                'room location': [0, -1.25],
#                'room nice': [1.5, 0],
#                'room pillows': [1.0, -1.25],
#                'room size': [1.25, -4.25],
#                'room someone': [2.75, 0],
#                'room space': [3.25, -3.0],
#                'room wasn': [1.0, -0.25],
#                'rooms': [1.5, -2.75],
#                'route': [1.0, 0],
#                'rude receptionist': [0, -0.5],
#                'safety requirement': [1.0, 0],
#                'seat': [0.875, -0.125],
#                'security': [1.625, -2.75],
#                'selection': [0, -0.625],
#                'selection nice': [2.25, -1.0],
#                'service': [0.5, 0],
#                'serving': [0.625, -0.625],
#                'shower': [1.5, -2.75],
#                'shower lovely': [2.25, -3.25],
#                'shower temp control': [1.5, -1.875],
#                'site': [1.0, 0],
#                'size': [0.5, -0.75],
#                'slate bathroom mini fridge': [2.0, 0],
#                'slip mat': [3.0, -5.5],
#                'slip shower': [0, -3.75],
#                'small': [0.75, 0],
#                'sofa bed': [1.5, 0],
#                'solo': [0, -0.625],
#                'something': [1.75, -0.875],
#                'space': [1.75, -0.875],
#                'space cost money': [0, 0],
#                'spite': [2.125, -1.375],
#                'spot': [2.125, -0.75],
#                'staff': [30.625, -9.875],
#                'staff excellent location': [7.125, 0],
#                'staff member speak': [0, -1.875],
#                'star room': [0.5, 0],
#                'station': [2.625, -0.5],
#                'stay': [3.25, -1.25],
#                'storage': [1.125, -2.875],
#                'street': [2.0, -0.625],
#                'structure': [1.375, -3.125],
#                'stuffy': [0.625, -0.5],
#                'sub': [1.5, -2.75],
#                'suit': [3.25, -1.75],
#                'suitcase': [1.5, -2.75],
#                'summer': [0.5, 0],
#                'summer period i': [5.875, -10.25],
#                'sunshine': [0.75, 0],
#                'super location': [2.5, 0],
#                'superb': [0.625, -0.75],
#                't': [0.125, -2.375],
#                'table': [1.0, -2.0],
#                'take': [1.875, -1.25],
#                'tax': [0, 0],
#                'taxi': [1.0, -0.375],
#                'taxi service': [1.5, -0.375],
#                'tea': [0.5, -0.625],
#                'temperature': [0, -0.75],
#                'term': [0.5, 0],
#                'th': [1.25, -0.5],
#                'thank': [1.125, -1.25],
#                'thing': [0, -0.625],
#                'time': [2.625, -1.75],
#                'toaster': [0, 0],
#                'today s': [0, 0],
#                'toilet': [0.625, 0],
#                'tourist bustle': [3.5, 0],
#                'transport': [2.25, -0.75],
#                'trouble': [3.125, -1.0],
#                'tube': [2.125, -0.75],
#                'tube friendly': [2.5, -0.5],
#                'tube station': [3.5, 0],
#                'tv': [1.625, -1.5],
#                'underground': [2.125, 0],
#                'underground station': [9.75, -0.25],
#                'upgrade': [2.0, -0.75],
#                'value': [0.5, -0.625],
#                'ventilation': [0, 0],
#                'very': [5.25, -2.625],
#                'view': [0.125, -3.25],
#                'visit special': [4.75, 0],
#                'walk': [4.0, -3.375],
#                'wall': [0, -0.625],
# ...
#                'suitcase': [1.625, -3.125],
#                'suite': [0.625, -0.875],
#                'surrounding': [0.875, -0.75],
#                't': [7.0, -1.75],
#                'tap': [0.5, 0],
#                'tasty': [1.625, -1.375],
#                'taxi': [0.875, -0.625],
#                'tea': [0.875, 0],
#                'teapot': [0.5, -1.25],
#                'television upstairs': [0.75, 0],
#                'temperature': [0, 0],
#                'terrace building': [1.75, -1.5],
#                'theatre': [1.625, -0.25],
#                'think': [1.0, -0.25],
#                'time': [0.375, -0.875],
#                'tiny': [0, 0],
#                'toilet': [2.75, -1.75],
#                'toilet bath area': [1.5, 0],
#                'toilet bathroom': [4.5, -0.75],
#                'toilet floor': [0, -1.75],
#                'top': [0.375, -3.75],
#                'touch': [1.625, -0.5],
#                'transfer': [0.375, 0],
#                'transport': [0, 0],
#                'tricky': [0.375, 0],
#                'trip': [0, -0.25],
#                'tube': [1.875, 0],
#                'tv': [0, 0],
#                'tv didn t work': [0, -0.625],
#                'twin bed': [1.25, -1.25],
#                'underfloor heating': [0, 0],
#                'use': [2.5, -3.125],
#                'valet': [1.0, 0],
#                'value': [0.5, 0],
#                'vicinity': [0, 0],
#                'view': [0.5, -0.25],
#                'visit': [0.25, 0],
#                'vital': [0, 0],
#                'waitrose': [0, 0],
#                'walk': [2.0, -1.875],
#                'wall': [0.375, 0],
#                'wardrobe': [0.75, -0.625],
#                'wardrobe didn t mark sense': [5.875, -0.875],
#                'wardrobe space': [4.0, -3.75],
#                'wardrobe view wasn': [3.75, -4.875],
#                'was': [2.125, 0],
#                'wasn': [0, 0],
#                'wasn t': [3.25, -1.75],
#                'waste': [0.5, 0],
#                'water': [5.0, -2.0],
#                'way': [1.75, -0.25],
#                'week': [0, 0],
#                'weird': [1.75, -0.875],
#                'wet room shower glass door': [8.75, -1.25],
#                'wi': [0.375, -2.875],
#                'wider': [0.5, -0.625],
#                'wife': [0.625, 0],
#                'wifi': [0.375, -0.25],
#                'window': [2.125, -0.875],
#                'wine': [0.5, 0],
#                'wood': [4.125, -1.875],
#                'work': [2.875, -3.125]}),
#   440],
#  ['The Principal London',
#   defaultdict(list,
#               {'addition': [0, 0],
#                'air': [2.25, -1.5],
#                'air con': [1.0, 0],
#                'air con system': [1.75, -3.5],
#                'air conditioner': [0, -1.5],
#                'air conditioning': [3.25, -2.5],
#                'aircon': [0.75, -0.375],
#                'airport': [0, 0],
#                'always': [1.25, -0.75],
#                'appearance': [0, 0],
#                'architecture': [2.5, -0.5],
#                'area': [2.625, -1.25],
#                'area character': [4.125, -1.625],
#                'awesome': [0.625, -0.5],
#                'awful sandwich': [4.0, -3.75],
#                'bacon': [0, 0],
#                'baggage': [1.5, -0.625],
#                'bar shame': [4.0, -3.75],
#                'bath': [2.75, -2.375],
#                'bath tap': [2.25, -4.5],
#                'bathroom': [7.375, -2.5],
#                'bathroom floor': [1.0, 0],
#                'bay': [0.125, 0],
#                'beautiful': [0, 0],
#                'bed': [2.875, -4.125],
#                'bedroom': [0.5, -0.25],
#                'bedroom suite': [3.75, -1.5],
#                'birthday': [0.5, 0],
#                'bit': [3.875, -0.375],
#                'blocked bath drain': [3.375, -6.75],
#                'bloomsbury': [0, 0],
#                'bonus': [1.625, 0],
#                'booking': [1.125, -2.25],
#                'bother': [0.25, 0],
#                'bottle': [0.75, 0],
#                'breakfast': [7.0, -6.25],
#                'breakfast use': [2.0, -1.25],
#                'brilliant': [0, 0],
#                'buffet food': [2.25, -0.25],
#                'building': [6.0, -1.375],
#                'building work': [0, 0],
#                'bummer': [0.625, -1.25],
#                'bus': [0.5, 0],
#                'bus tour': [1.0, -0.625],
#                'bygone era': [0.5, 0],
#                'caf s': [2.5, -2.0],
#                'cancellation': [1.125, -2.25],
#                'cap shower gel': [1.5, -3.75],
#                'card': [0.75, 0],
#                'ceiling': [1.75, -1.25],
#                'chair': [0.5, -0.75],
#                'champagne': [1.375, 0],
#                'character': [1.5, 0],
#                'character breakfast': [1.0, 0],
#                'cheaper': [1.0, -0.625],
#                'check': [2.5, 0],
#                'choice': [2.75, -0.625],
#                'circle line': [6.25, 0],
#                'city': [0.625, 0],
#                'city centre': [0, 0],
#                'clean room': [1.0, -0.625],
#                'client': [0, 0],
#                'clockwork': [0.875, 0],
#                'coffee': [3.5, -0.625],
#                'coffee air': [2.0, -2.5],
#                'cohen': [1.25, 0],
#                'combination': [0.125, -0.625],
#                'comfort': [1.5, -1.375],
#                'concern': [0, 0],
#                'concierge': [1.875, -1.0],
#                'concierge service': [6.25, 0],
#                'conditioner insufficient milk': [1.5, -3.75],
#                'consideration': [1.75, -0.625],
#                'convenient a': [3.5, -0.375],
#                'conversation': [0.75, 0],
#                'corner': [2.0, 0],
#                'cost': [0.5, -1.125],
#                'course': [0, -0.25],
#                'courtyard windows': [2.25, -1.5],
#                'cramped': [0.625, -0.75],
#                'customer service': [0, 0],
#                'day': [3.0, -1.5],
#                'deal': [0.5, 0],
#                'decor': [0.125, 0],
#                'decor good location great': [1.875, -0.25],
#                'decorating': [1.375, 0],
#                'designer': [0, 0],
#                'desk': [3.625, -0.75],
#                'didn': [0, 0],
#                'didn t work': [1.375, 0],
#                'didnt': [0.625, 0],
#                'distance': [3.375, -0.625],
#                'door': [0.5, -1.125],
#                'door chain': [1.375, -2.0],
#                'door frame': [0, -2.25],
#                'door staff': [2.0, 0],
#                'doorman': [1.375, -1.0],
#                'doorman every day': [4.125, -2.625],
#                'downside': [0.5, 0],
#                'dozen': [0, 0],
#                'dragon sculpture': [3.0, -1.25],
#                'dresser': [0.625, -1.25],
#                'drink': [0, 0],
#                'elevator': [0.625, 0],
#                'engineer': [0.875, -0.625],
#                'english': [2.75, -0.625],
#                'enjoyed room service': [1.5, 0],
#                'etc': [1.5, -0.625],
#                'eurostar room': [4.25, 0],
#                'euston': [0, -0.25],
#                'euston hilton hotel': [3.0, -9.375],
#                'euston station': [2.25, 0],
#                'everything': [0.5, 0],
#                'example': [1.125, -0.125],
#                'exhaust': [1.125, -2.25],
#                'exit right': [2.25, -0.25],
#                'experience': [0.5, -0.625],
#                'extreme noise': [2.25, -4.5],
#                'fact': [3.0, 0],
#                'fault': [0.5, 0],
#                'faulty water': [2.25, -4.5],
#                'feed': [1.375, 0],
#                'fire drill': [0, 0],
#                'flight': [0, 0],
#                'floor': [3.75, -1.25],
#                'floor air': [2.25, -4.5],
#                'floor windows': [2.25, -4.5],
#                'food': [0.5, -1.25],
#                'food comfy': [0.5, 0],
#                'fortune': [1.0, -0.625],
#                'free wifi breakfast': [4.125, 0],
#                'freshen': [0, 0],
#                'fridge': [0.5, -1.25],
#                'front': [0.5, 0],
#                'front desk': [0, 0],
#                'front desk staff': [0, 0],
#                'fruit': [1.375, -0.875],
#                'function': [0, 0],
#                'future': [1.625, 0],
#                'generator': [0, 0],
#                'grandeur': [0, 0],
#                'gratuity': [0, 0],
#                'great': [0, 0],
#                'great access': [0, -0.75],
#                'great location': [0.75, 0],
#                'great ormond street hospital': [0, 0],
#                'ground floor': [0, 0],
#                'had': [2.0, -1.875],
#                'hair conditioner': [1.75, 0],
#                'heart': [0.875, 0],
#                'heathrow': [2.25, -0.625],
#                'historic': [0.875, 0],
#                'hole': [0, -1.125],
#                'holiday': [1.375, 0],
#                'hong kong': [2.75, 0],
#                'hotel': [18.5, -10.75],
#                'hotel closing': [1.625, 0],
#                'hotel excellent value': [1.875, 0],
#                'hotel interior': [2.75, 0],
#                'hotel location': [0, 0],
#                'hotel manager': [0.625, 0],
#                'hotel russell': [7.0, -2.0],
#                'hotel russell station': [2.25, 0],
#                'husband': [0, 0],
#                'impact': [0, -0.5],
#                'incredibly': [0.625, -0.75],
#                'interior': [0.5, -1.125],
#                'issue': [1.0, -1.625],
#                'kind': [0.625, -1.25],
#                'kind gesture': [1.5, 0],
#                'kings cross': [2.25, -0.25],
#                'lack': [0.5, 0],
#                'lift': [0, 0],
#                'light outside': [0, -2.25],
#                'line': [3.125, 0],
#                'lobby': [0, 0],
#                'location': [19.625, -2.75],
#                'location breakfast': [4.0, -1.5],
#                'location perfect': [2.25, -1.75],
#                'london': [5.25, -0.75],
#                'london close': [1.625, 0],
#                'lots': [0.5, 0],
#                'lounge': [0.125, -0.75],
#                'lovely park': [3.75, -2.125],
#                'luggage': [1.375, -0.5],
#                'machine': [0, 0],
#                'man': [1.375, 0],
#                'mattress': [1.125, -1.125],
#                'middle': [0.5, -0.25],
#                'miles': [0.75, -1.25],
#                'milk': [2.0, -1.875],
#                'minute walk': [2.25, 0],
#                'mistake': [0, 0],
#                'monday': [0, 0],
#                'money': [1.125, -1.75],
#                'monument': [0, 0],
#                'morn': [0, 0],
#                'morning': [0, -0.625],
#                'move': [0.75, -0.375],
#                'museum': [0.375, 0],
#                'musty smell': [0, 0],
#                'my room': [0.25, 0],
#                'need': [2.875, -1.5],
#                'nice': [1.5, -0.375],
#                'nicer': [1.0, -0.625],
#                'night': [1.75, -2.875],
#                'nobody': [0.5, -0.625],
#                'noise': [0.125, -0.625],
#                'note': [0, 0],
#                'old': [1.125, -2.25],
#                'opinion': [1.75, -0.625],
#                'option': [0.125, -0.75],
#                'opulence': [0, 0],
#                'outside': [2.0, 0],
#                'park': [1.0, -0.625],
#                'part': [0.375, 0],
#                'period': [1.5, -0.625],
#                'person': [0.875, -0.5],
#                'phone': [0.5, 0],
#                'photos': [0.5, 0],
#                'picadilly': [3.125, 0],
#                'picadilly tube': [6.25, 0],
#                'piccadilly line': [0, 0],
#                'pillow': [0, -1.0],
#                'place': [0.625, -0.75],
#                'platform': [0, 0],
#                'plenty': [3.375, -2.25],
#                'pm': [0, 0],
#                'point': [0.5, -0.25],
#                'potatoes': [1.0, -3.125],
#                'price': [1.0, 0],
#                'progress': [0, 0],
#                'quality': [0.5, -1.25],
#                'quieter': [0.875, -0.625],
#                'rate': [0.125, -0.75],
#                'reception': [0.125, -0.75],
#                'reception staff': [6.25, -1.5],
#                'reception staff excellent': [3.0, 0],
#                'receptionist': [1.25, 0],
#                'receptionist cohen': [0.25, -1.25],
#                'reflection': [0, 0],
#                'refurbishment': [0, 0],
#                'renovation': [0, 0],
#                'requested room change given room': [5.625, -11.25],
#                'resection': [2.0, 0],
#                'restaurant': [0.5, -1.5],
#                'return': [0, 0],
#                'road': [0, -0.75],
#                'road dining room': [1.875, -1.875],
#                'road side': [1.25, -1.25],
#                'room': [22.875, -17.0],
#                'room bill': [4.25, -3.0],
#                'room breakfast': [0.625, -1.25],
#                'room didn t work': [4.375, -1.5],
#                'room service': [5.625, -3.0],
#                'rooms': [0, -0.75],
#                'russell': [0.375, -0.625],
#                'russell hotel': [0.5, 0],
#                'russell hotel breakfast buffet': [4.0, -12.5],
#                'selection left': [1.0, 0],
#                'service charge': [0, 0],
#                'service gorgeous': [1.75, 0],
#                'service location': [6.25, 0],
#                'shop': [2.0, -1.875],
#                'shower': [5.5, -2.25],
#                'side': [0.375, 0],
#                'sink': [0.875, 0],
#                'size': [2.125, 0],
#                'sleeping': [0.5, -0.25],
#                'smartphone': [0.5, 0],
#                'smell': [0.625, -0.75],
#                'something': [0.625, -1.25],
#                'space': [1.625, 0],
#                'spot': [1.125, -1.5],
#                'st pancras': [0, -0.75],
#                'st pancras station': [0.875, -0.75],
#                'staff': [12.375, -4.0],
#                'staff polite': [3.0, -0.75],
#                'stair case': [3.0, 0],
#                'staircase': [1.5, -0.625],
#                'stairway': [0, 0],
#                'standard': [1.0, -3.125],
#                'station': [5.5, -1.125],
#                'statuesque grandeur': [0, 0],
#                'stay': [2.0, -0.75],
#                'street': [0, 0],
#                'style': [1.5, -0.625],
#                'suitcase': [0, 0],
#                'summer air conditioning': [3.0, -4.875],
#                'superb': [0.375, 0],
#                'survivor': [0.25, 0],
#                'system': [1.125, -2.25],
#                't': [6.0, -3.0],
#                'tap': [1.625, -0.125],
#                'taste': [1.0, -3.125],
#                'tea': [2.75, -0.625],
#                'thank': [0, 0],
#                'tiles': [1.125, -0.75],
#                'time': [1.5, -1.875],
#                'titanic': [2.375, -1.125],
#                'titanic located': [2.75, 0],
#                'today': [0, 0],
#                'tour': [0.5, -0.625],
#                'tours': [0.5, 0],
#                'traffic': [0, 0],
#                'transportation': [0, 0],
#                'travel': [0.75, 0],
#                'tube': [5.75, 0],
#                'tube station': [1.5, 0],
#                'tube stop': [3.0, -1.25],
#                'twin': [2.625, -1.375],
#                'twin room': [0.75, 0],
#                'underground': [1.375, -0.5],
#                'upgrade': [0.125, -0.625],
#                'value': [1.0, 0],
#                'very': [0.5, -1.25],
#                'victorianlandmark hotel': [1.75, 0],
#                'view': [0.5, -1.125],
#                'visit': [0, 0],
#                'waitress': [0, 0],
#                'walk': [2.0, 0],
#                'walking': [3.125, 0],
#                'water': [1.375, -0.875],
#                'way': [1.125, -0.625],
#                'wedding anniversary': [1.5, 0],
#                'week': [1.375, 0],
#                'wifi': [0.5, 0],
#                'windows weren t closing': [2.0, -4.5],
#                'woke': [0, -0.75],
#                'work': [0.875, -0.25],
#                'world': [1.125, -1.5],
#                'world charm modem': [2.625, 0],
#                'worst sleep': [2.25, -4.5],
#                'would': [1.375, 0]}),
#   546]]

# %%
def unify_aspects(hotels_w_aspects):
    dict_aspect = {}
    
    for hotel in hotels_w_aspects:
        for key, value in hotel[1].items():
            
            if key in dict_aspect:
                dict_aspect[key] += [[value[0], hotel[0]]]
                dict_aspect[key] = sorted(dict_aspect[key])[::-1]
            else:
                dict_aspect.setdefault(key, [[value[0], hotel[0]]])
                
    return dict_aspect

aspects_info = unify_aspects(hotel_info)
aspects_info
# Out:
# {'inquiry': [[2.375, 'K K Hotel George']],
#  'wardrobe didn t mark sense': [[5.875, 'The Park Grand London Paddington']],
#  'weather': [[1.25, 'Apex Temple Court Hotel']],
#  'anything': [[4.125, 'Hotel Arena'],
#   [1.625, 'The Park Grand London Paddington'],
#   [0.875, 'Apex Temple Court Hotel']],
#  'bar variety': [[0, 'Apex Temple Court Hotel']],
#  'night s sleep': [[6.75, 'Apex Temple Court Hotel']],
#  'bathtub': [[0, 'Hotel Arena']],
#  'covent garden': [[3.0, 'Apex Temple Court Hotel']],
#  'covent garden soho': [[0, 'Apex Temple Court Hotel']],
#  'excellent': [[3.625, 'K K Hotel George'],
#   [1.625, 'Apex Temple Court Hotel'],
#   [1.5, 'The Park Grand London Paddington']],
#  'room hidden courtyard view': [[5.0, 'Apex Temple Court Hotel']],
#  'selection left': [[1.0, 'The Principal London']],
#  'bath tap': [[2.25, 'The Principal London']],
#  'microwave': [[0, 'The Park Grand London Paddington']],
#  'label club lounge': [[5.5, 'The Park Grand London Paddington']],
#  'safety requirement': [[1.0, 'K K Hotel George']],
#  'station': [[5.5, 'The Principal London'],
#   [3.0, 'Hotel Arena'],
#   [2.625, 'K K Hotel George'],
#   [0, 'The Park Grand London Paddington']],
#  'bathroom door': [[1.25, 'The Park Grand London Paddington']],
#  'money': [[2.625, 'The Park Grand London Paddington'],
#   [1.125, 'The Principal London'],
#   [0.375, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'next morning': [[1.25, 'The Park Grand London Paddington']],
#  'mistake': [[0.375, 'K K Hotel George'],
#   [0.375, 'Hotel Arena'],
#   [0, 'The Principal London']],
#  'pad': [[1.25, 'Hotel Arena']],
#  'middle': [[1.0, 'Hotel Arena'], [0.5, 'The Principal London']],
#  'im i': [[1.75, 'The Park Grand London Paddington']],
#  'view temporary reception area': [[0, 'Hotel Arena']],
#  't forget': [[3.25, 'Apex Temple Court Hotel']],
#  'park grand london paddington': [[3.5, 'The Park Grand London Paddington']],
#  'lovely park': [[3.75, 'The Principal London']],
#  'standard room': [[2.25, 'Apex Temple Court Hotel']],
#  'view': [[5.625, 'Hotel Arena'],
#   [0.875, 'Apex Temple Court Hotel'],
#   [0.5, 'The Principal London'],
#   [0.5, 'The Park Grand London Paddington'],
#   [0.125, 'K K Hotel George']],
#  'elevator': [[0.625, 'The Principal London']],
#  'move': [[0.75, 'The Principal London'],
#   [0.375, 'The Park Grand London Paddington']],
#  'winter nothing': [[2.75, 'K K Hotel George']],
#  'wardrobe': [[0.75, 'The Park Grand London Paddington'],
#   [0.625, 'Hotel Arena']],
#  'morn': [[0, 'The Principal London']],
#  'convenient': [[1.125, 'Apex Temple Court Hotel']],
#  'underground tube': [[5.5, 'Apex Temple Court Hotel']],
#  'russell hotel breakfast buffet': [[4.0, 'The Principal London']],
#  'bakery': [[1.625, 'K K Hotel George'], [1.625, 'Hotel Arena']],
#  'clock': [[0.5, 'Hotel Arena']],
#  'company': [[0.375, 'Hotel Arena']],
#  'disatisfaction': [[0, 'The Park Grand London Paddington']],
#  'booking': [[1.75, 'Apex Temple Court Hotel'],
#   [1.125, 'The Principal London'],
#   [0.125, 'K K Hotel George']],
#  'front entrance': [[2.5, 'Apex Temple Court Hotel']],
#  'website': [[0.25, 'Hotel Arena']],
#  'super location': [[2.5, 'K K Hotel George']],
#  'desk': [[3.625, 'The Principal London'],
#   [1.125, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'hall': [[0, 'Hotel Arena']],
#  'structure': [[2.25, 'Hotel Arena'], [1.375, 'K K Hotel George']],
#  'beautiful': [[2.125, 'K K Hotel George'],
#   [0.25, 'Hotel Arena'],
#   [0, 'The Principal London']],
#  'oosterpark': [[3.125, 'Hotel Arena']],
#  'english': [[2.75, 'The Principal London'], [1.625, 'Hotel Arena']],
#  'didn t work': [[1.375, 'The Principal London']],
#  'i': [[9.0, 'Hotel Arena'],
#   [1.375, 'Apex Temple Court Hotel'],
#   [0.25, 'K K Hotel George']],
#  'menu': [[3.25, 'Apex Temple Court Hotel']],
#  'handrail was kind': [[2.25, 'Hotel Arena']],
#  'aircondition': [[0, 'Hotel Arena']],
#  'innercourt': [[0.875, 'Apex Temple Court Hotel']],
#  'bacon': [[0.625, 'Apex Temple Court Hotel'],
#   [0.375, 'K K Hotel George'],
#   [0, 'The Principal London'],
#   [0, 'Hotel Arena']],
#  'bed': [[19.0, 'Hotel Arena'],
#   [10.0, 'Apex Temple Court Hotel'],
#   [6.75, 'The Park Grand London Paddington'],
#   [6.375, 'K K Hotel George'],
#   [2.875, 'The Principal London']],
#  'eu': [[1.875, 'Apex Temple Court Hotel']],
#  'suitcase': [[1.625, 'The Park Grand London Paddington'],
#   [1.5, 'K K Hotel George'],
#   [0, 'The Principal London']],
#  'decor': [[0.125, 'The Principal London']],
#  'daylight': [[0.5, 'The Park Grand London Paddington']],
#  'building meeting': [[0, 'Hotel Arena']],
#  'mess shouldn t': [[0, 'Hotel Arena']],
#  'tea coffee': [[0.5, 'Hotel Arena']],
#  'level': [[4.625, 'Hotel Arena'], [3.125, 'K K Hotel George']],
#  'setting': [[3.375, 'Hotel Arena']],
#  'patch': [[1.0, 'The Park Grand London Paddington']],
#  'usb port': [[0, 'Hotel Arena']],
#  'bottle opener': [[3.75, 'Apex Temple Court Hotel']],
#  'assistance': [[0, 'K K Hotel George']],
#  'location major shopping': [[5.25, 'K K Hotel George']],
#  'order': [[2.5, 'The Park Grand London Paddington'],
#   [1.375, 'Hotel Arena'],
#   [0.75, 'K K Hotel George'],
#   [0.625, 'Apex Temple Court Hotel']],
#  'make': [[2.25, 'Apex Temple Court Hotel']],
#  'shampoo body': [[1.25, 'Hotel Arena']],
#  'restaurant food': [[0.5, 'Apex Temple Court Hotel']],
#  'city river': [[1.0, 'Apex Temple Court Hotel']],
#  'hotel manager': [[2.5, 'Hotel Arena'], [0.625, 'The Principal London']],
#  'problem': [[3.125, 'K K Hotel George'],
#   [2.625, 'Hotel Arena'],
#   [2.125, 'The Park Grand London Paddington'],
#   [1.25, 'Apex Temple Court Hotel']],
#  'extreme noise': [[2.25, 'The Principal London']],
#  'room door': [[1.25, 'The Park Grand London Paddington']],
#  'variety': [[2.25, 'Hotel Arena'], [0.875, 'Apex Temple Court Hotel']],
#  'great ormond street hospital': [[0, 'The Principal London']],
#  'porter staff': [[1.25, 'The Park Grand London Paddington']],
#  'room spacious bathroom': [[1.5, 'Apex Temple Court Hotel']],
#  'front desk': [[3.75, 'Hotel Arena'],
#   [1.5, 'The Park Grand London Paddington'],
#   [0.75, 'K K Hotel George'],
#   [0, 'The Principal London']],
#  'water damage': [[7.0, 'Hotel Arena']],
#  'adapter': [[0, 'Apex Temple Court Hotel']],
#  'paddington train': [[0, 'The Park Grand London Paddington']],
#  'underfloor heating': [[0, 'The Park Grand London Paddington']],
#  'receptionist': [[1.25, 'The Principal London'], [0.625, 'Hotel Arena']],
#  'apex': [[3.25, 'Apex Temple Court Hotel']],
#  'customer service': [[0, 'The Principal London']],
#  'plaster': [[2.625, 'Hotel Arena']],
#  'great location': [[3.5, 'K K Hotel George'],
#   [1.75, 'Apex Temple Court Hotel'],
#   [1.25, 'Hotel Arena'],
#   [0.75, 'The Principal London']],
#  'nightmare': [[1.375, 'The Park Grand London Paddington']],
#  'vital': [[0, 'The Park Grand London Paddington']],
#  'did': [[0, 'K K Hotel George']],
#  'theater district': [[5.5, 'Apex Temple Court Hotel']],
#  'request': [[2.375, 'K K Hotel George'],
#   [1.375, 'Hotel Arena'],
#   [0.125, 'The Park Grand London Paddington']],
#  'front desk staff would love': [[6.25, 'K K Hotel George']],
#  'mint chocolate': [[1.0, 'K K Hotel George']],
#  'show': [[2.75, 'Apex Temple Court Hotel']],
#  'waste': [[0.5, 'The Park Grand London Paddington']],
#  'ground floor room': [[2.625, 'The Park Grand London Paddington']],
#  'sub': [[1.5, 'K K Hotel George']],
#  'health food': [[1.5, 'Hotel Arena']],
#  'bathroom shower': [[4.25, 'K K Hotel George']],
#  'fault checking': [[2.75, 'The Park Grand London Paddington']],
#  'boiler': [[2.5, 'The Park Grand London Paddington'], [1.625, 'Hotel Arena']],
#  'staff room': [[2.75, 'The Park Grand London Paddington']],
#  'court paul s': [[8.25, 'K K Hotel George']],
#  'hand': [[0.125, 'Hotel Arena']],
#  'toilet': [[2.75, 'The Park Grand London Paddington'],
#   [1.25, 'Hotel Arena'],
#   [0.625, 'K K Hotel George'],
#   [0.625, 'Apex Temple Court Hotel']],
#  'choc': [[1.375, 'Apex Temple Court Hotel']],
#  'tv s': [[0.75, 'Hotel Arena']],
#  'metro close': [[4.5, 'Hotel Arena']],
#  'airport friendly': [[2.5, 'K K Hotel George']],
#  'visit': [[0.25, 'The Park Grand London Paddington'],
#   [0, 'The Principal London']],
#  'site restaurant': [[5.75, 'Hotel Arena']],
#  'search': [[0.5, 'Hotel Arena']],
#  'monument': [[0, 'The Principal London']],
#  'entrance': [[3.25, 'The Park Grand London Paddington'],
#   [1.875, 'Apex Temple Court Hotel'],
#   [0.75, 'Hotel Arena']],
#  'ideal': [[0, 'Apex Temple Court Hotel']],
#  'refund discount': [[0, 'The Park Grand London Paddington']],
#  'beautiful garden': [[0, 'K K Hotel George']],
#  'pillows super stiff': [[0.75, 'Hotel Arena']],
#  'everyone': [[3.75, 'The Park Grand London Paddington'],
#   [0.625, 'Hotel Arena'],
#   [0.625, 'Apex Temple Court Hotel']],
#  'club lounge': [[1.75, 'Apex Temple Court Hotel']],
#  'beforehand': [[0.125, 'K K Hotel George']],
#  'closet': [[0.625, 'K K Hotel George']],
#  'term': [[0.5, 'K K Hotel George']],
#  'paddinton station': [[1.25, 'The Park Grand London Paddington']],
#  'a c control': [[0, 'The Park Grand London Paddington']],
#  'room bathroom': [[1.0, 'K K Hotel George']],
#  'couple': [[2.625, 'Hotel Arena'], [0.625, 'Apex Temple Court Hotel']],
#  'probably': [[0.625, 'K K Hotel George']],
#  'office': [[2.875, 'Apex Temple Court Hotel'], [0.125, 'K K Hotel George']],
#  'milk': [[2.0, 'The Principal London']],
#  'weird': [[1.75, 'The Park Grand London Paddington']],
#  'rooms': [[1.5, 'K K Hotel George'], [0, 'The Principal London']],
#  'son': [[0, 'Apex Temple Court Hotel']],
#  'today': [[0, 'The Principal London']],
#  'requested room change given room': [[5.625, 'The Principal London']],
#  'beautiful garden area': [[1.0, 'K K Hotel George']],
#  'manner': [[0.625, 'The Park Grand London Paddington']],
#  'rent': [[1.375, 'Hotel Arena']],
#  'first night': [[2.25, 'Apex Temple Court Hotel']],
#  'kind': [[7.125, 'K K Hotel George'],
#   [0.75, 'Apex Temple Court Hotel'],
#   [0.625, 'The Principal London']],
#  'hotel public transportation': [[5.375, 'Hotel Arena']],
#  'board': [[3.5, 'The Park Grand London Paddington'],
#   [0.375, 'Apex Temple Court Hotel']],
#  'junior suite': [[0, 'Apex Temple Court Hotel']],
#  'something wet': [[1.25, 'Hotel Arena']],
#  'a la carte': [[0, 'Apex Temple Court Hotel']],
#  'omg': [[0, 'The Park Grand London Paddington']],
#  'woke': [[0, 'The Principal London']],
#  'cleaning lady': [[1.875, 'Hotel Arena']],
#  'reception staff excellent': [[3.0, 'The Principal London']],
#  'hotel restaurant': [[2.0, 'Hotel Arena']],
#  'would': [[1.5, 'K K Hotel George'], [1.375, 'The Principal London']],
#  'rude receptionist': [[0, 'K K Hotel George']],
#  'case': [[0, 'K K Hotel George']],
#  'hello': [[0.5, 'K K Hotel George']],
#  'bath carpet': [[1.5, 'The Park Grand London Paddington']],
#  'railway': [[1.25, 'K K Hotel George']],
#  'birthday present please': [[1.0, 'Hotel Arena']],
#  'english tv': [[3.25, 'K K Hotel George']],
#  'tube': [[5.75, 'The Principal London'],
#   [2.125, 'K K Hotel George'],
#   [1.875, 'The Park Grand London Paddington'],
#   [1.375, 'Apex Temple Court Hotel']],
#  'sleeping': [[0.5, 'The Principal London']],
#  'notch quality': [[0, 'Apex Temple Court Hotel']],
#  'man': [[1.375, 'The Principal London'], [0.875, 'K K Hotel George']],
#  'privacy location temple': [[1.5, 'Apex Temple Court Hotel']],
#  'student': [[0, 'Apex Temple Court Hotel']],
#  'musty smell': [[0, 'The Principal London']],
#  'band': [[1.0, 'Apex Temple Court Hotel']],
#  'job': [[0.25, 'Apex Temple Court Hotel'], [0, 'K K Hotel George']],
#  'badge': [[0, 'Apex Temple Court Hotel']],
#  'soft': [[1.125, 'Apex Temple Court Hotel']],
#  'my room': [[2.0, 'The Park Grand London Paddington'],
#   [0.25, 'The Principal London']],
#  'inside': [[2.75, 'Apex Temple Court Hotel'], [2.125, 'Hotel Arena']],
#  'taxi service': [[1.5, 'K K Hotel George']],
#  'water soda wine': [[2.625, 'Apex Temple Court Hotel']],
#  'tv': [[2.375, 'Apex Temple Court Hotel'],
#   [1.625, 'K K Hotel George'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'Hotel Arena']],
#  'cappuccino room': [[2.5, 'Hotel Arena']],
#  'kensington': [[0.875, 'The Park Grand London Paddington']],
#  'element': [[0.75, 'Hotel Arena']],
#  'amazing building park location amazing bobby gin': [[0, 'Hotel Arena']],
#  'park cool': [[0, 'Hotel Arena']],
#  'court underground very': [[5.25, 'K K Hotel George']],
#  'awesome': [[0.625, 'The Principal London']],
#  'wrap': [[2.875, 'Hotel Arena']],
#  'value': [[3.875, 'Apex Temple Court Hotel'],
#   [1.0, 'The Principal London'],
#   [0.5, 'The Park Grand London Paddington'],
#   [0.5, 'K K Hotel George']],
#  'didn': [[0, 'The Principal London']],
#  'name': [[0.5, 'The Park Grand London Paddington']],
#  'hotel russell': [[7.0, 'The Principal London']],
#  'mood': [[1.625, 'Hotel Arena']],
#  'hotel closing': [[1.625, 'The Principal London']],
#  'volume': [[0.625, 'Hotel Arena']],
#  'didn t': [[0.125, 'K K Hotel George'], [0, 'Apex Temple Court Hotel']],
#  'london': [[9.75, 'The Park Grand London Paddington'],
#   [9.25, 'K K Hotel George'],
#   [5.875, 'Apex Temple Court Hotel'],
#   [5.25, 'The Principal London'],
#   [4.125, 'Hotel Arena']],
#  'mattress': [[1.625, 'K K Hotel George'],
#   [1.125, 'The Principal London'],
#   [0.75, 'Hotel Arena'],
#   [0.5, 'The Park Grand London Paddington']],
#  'good indian': [[3.25, 'The Park Grand London Paddington']],
#  'street': [[3.0, 'The Park Grand London Paddington'],
#   [2.0, 'K K Hotel George'],
#   [1.375, 'Apex Temple Court Hotel'],
#   [0.5, 'Hotel Arena'],
#   [0, 'The Principal London']],
#  'construction renovation': [[0, 'Hotel Arena']],
#  'floor': [[6.5, 'Hotel Arena'],
#   [3.75, 'The Principal London'],
#   [3.75, 'The Park Grand London Paddington'],
#   [2.625, 'K K Hotel George']],
#  'bar wasn': [[0, 'K K Hotel George']],
#  'room service': [[5.625, 'The Principal London'],
#   [4.0, 'The Park Grand London Paddington'],
#   [2.0, 'Apex Temple Court Hotel']],
#  'sight': [[0.5, 'Apex Temple Court Hotel']],
#  'soho oxford st nice': [[0.5, 'Apex Temple Court Hotel']],
#  'dam square': [[0.75, 'Hotel Arena']],
#  'clineanliness': [[1.0, 'K K Hotel George']],
#  'sue': [[0, 'Apex Temple Court Hotel']],
#  'signal': [[0.375, 'The Park Grand London Paddington']],
#  'space cost money': [[0, 'K K Hotel George']],
#  'someone': [[1.25, 'Hotel Arena'],
#   [0.375, 'The Park Grand London Paddington']],
#  'smartphone': [[0.5, 'The Principal London']],
#  'room bar': [[0, 'K K Hotel George']],
#  'meant': [[0.625, 'Hotel Arena']],
#  'feed': [[1.375, 'The Principal London']],
#  'make tea': [[1.0, 'The Park Grand London Paddington']],
#  'baggage': [[1.5, 'The Principal London']],
#  'toilet seat': [[1.25, 'Apex Temple Court Hotel']],
#  'thing': [[2.75, 'Apex Temple Court Hotel'],
#   [1.625, 'Hotel Arena'],
#   [0, 'K K Hotel George']],
#  'fridge': [[1.25, 'The Park Grand London Paddington'],
#   [0.875, 'Hotel Arena'],
#   [0.5, 'The Principal London']],
#  'lift': [[0.5, 'The Park Grand London Paddington'],
#   [0, 'The Principal London']],
#  'cafes': [[2.25, 'The Park Grand London Paddington']],
#  'hold': [[0, 'The Park Grand London Paddington']],
#  'hospital': [[0.875, 'Hotel Arena']],
#  'run': [[2.0, 'The Park Grand London Paddington']],
#  'hassle': [[2.25, 'Apex Temple Court Hotel']],
#  'hold church': [[3.5, 'Hotel Arena']],
#  'water': [[5.0, 'The Park Grand London Paddington'],
#   [1.5, 'K K Hotel George'],
#   [1.375, 'The Principal London'],
#   [0, 'Apex Temple Court Hotel']],
#  'star room': [[0.5, 'K K Hotel George']],
#  'waitrose': [[0, 'The Park Grand London Paddington']],
#  'security': [[1.625, 'K K Hotel George']],
#  'internet': [[0.5, 'K K Hotel George']],
#  'tram': [[4.0, 'Hotel Arena']],
#  'stuffy': [[0.625, 'K K Hotel George']],
#  'london day great shower': [[2.0, 'K K Hotel George']],
#  'upgrade': [[3.875, 'Apex Temple Court Hotel'],
#   [2.0, 'K K Hotel George'],
#   [0.125, 'The Principal London']],
#  'difficult': [[0, 'K K Hotel George'], [0, 'Apex Temple Court Hotel']],
#  'hotel excellent value': [[1.875, 'The Principal London']],
#  'feel': [[1.5, 'Hotel Arena'], [0, 'The Park Grand London Paddington']],
#  'hallway wall': [[3.75, 'Apex Temple Court Hotel']],
#  'need': [[3.5, 'K K Hotel George'],
#   [3.5, 'Hotel Arena'],
#   [2.875, 'The Principal London'],
#   [2.5, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'broken window': [[1.25, 'Hotel Arena']],
#  'coffee machine': [[1.75, 'Apex Temple Court Hotel']],
#  'hotel': [[45.625, 'Hotel Arena'],
#   [35.125, 'K K Hotel George'],
#   [30.625, 'Apex Temple Court Hotel'],
#   [21.375, 'The Park Grand London Paddington'],
#   [18.5, 'The Principal London']],
#  'fab fluffy': [[0, 'K K Hotel George']],
#  'lot': [[3.125, 'Apex Temple Court Hotel'],
#   [2.375, 'Hotel Arena'],
#   [0, 'K K Hotel George']],
#  'option': [[2.875, 'Hotel Arena'], [0.125, 'The Principal London']],
#  'water boiler': [[3.75, 'K K Hotel George']],
#  'worst sleep': [[2.25, 'The Principal London']],
#  'soulless': [[0, 'Apex Temple Court Hotel']],
#  'window mechanism': [[5.25, 'Hotel Arena']],
#  'incredibly': [[0.625, 'The Principal London']],
#  'apex hotel': [[1.75, 'Apex Temple Court Hotel']],
#  'week uk vacation': [[1.5, 'K K Hotel George']],
#  'clean': [[3.375, 'Hotel Arena'], [0, 'The Park Grand London Paddington']],
#  'wi fi': [[0, 'Apex Temple Court Hotel']],
#  'product': [[0.125, 'Hotel Arena']],
#  'room key': [[3.0, 'K K Hotel George'], [2.25, 'Apex Temple Court Hotel']],
#  'happening': [[0, 'Apex Temple Court Hotel']],
#  'direction': [[0, 'Hotel Arena']],
#  'transaction': [[0.625, 'Hotel Arena']],
#  'being': [[0.5, 'Apex Temple Court Hotel']],
#  'brilliant': [[0, 'The Principal London']],
#  'adult': [[0.125, 'The Park Grand London Paddington']],
#  'laundry': [[1.25, 'K K Hotel George']],
#  'great choice': [[3.0, 'K K Hotel George']],
#  'room fit': [[0.125, 'The Park Grand London Paddington']],
#  'table': [[1.375, 'Apex Temple Court Hotel'], [1.0, 'K K Hotel George']],
#  'comfy room': [[0, 'K K Hotel George']],
#  'box': [[1.125, 'Apex Temple Court Hotel'],
#   [0.625, 'The Park Grand London Paddington']],
#  'bio weapon': [[0, 'Hotel Arena']],
#  'annoying': [[0, 'Hotel Arena']],
#  'challenge': [[0, 'The Park Grand London Paddington']],
#  'free wifi breakfast': [[4.125, 'The Principal London']],
#  'place': [[5.625, 'Hotel Arena'],
#   [1.0, 'Apex Temple Court Hotel'],
#   [0.625, 'The Principal London'],
#   [0.625, 'K K Hotel George']],
#  'slip shower': [[0, 'K K Hotel George']],
#  'lounge': [[0.875, 'Apex Temple Court Hotel'],
#   [0.125, 'The Principal London']],
#  'rubber duck': [[0, 'Apex Temple Court Hotel']],
#  'guest svc manager francesco': [[15.5, 'Apex Temple Court Hotel']],
#  'perfect location': [[1.5, 'K K Hotel George']],
#  'acknowledgement': [[0, 'Apex Temple Court Hotel']],
#  'future': [[1.75, 'K K Hotel George'], [1.625, 'The Principal London']],
#  'curtain': [[0.375, 'The Park Grand London Paddington'], [0, 'Hotel Arena']],
#  'supplement': [[0, 'Apex Temple Court Hotel']],
#  'staff shampoo': [[1.75, 'Hotel Arena']],
#  'hotel yesterday': [[0, 'Apex Temple Court Hotel']],
#  'tube station': [[3.5, 'K K Hotel George'], [1.5, 'The Principal London']],
#  'family': [[3.0, 'Apex Temple Court Hotel'],
#   [2.375, 'K K Hotel George'],
#   [0.5, 'The Park Grand London Paddington']],
#  'doorman every day': [[4.125, 'The Principal London']],
#  'mix': [[0, 'Hotel Arena']],
#  'bar area': [[7.25, 'K K Hotel George'],
#   [6.75, 'Hotel Arena'],
#   [1.0, 'Apex Temple Court Hotel']],
#  'none': [[1.0, 'Apex Temple Court Hotel']],
#  'dining': [[0, 'Hotel Arena']],
#  'room service menu': [[4.875, 'The Park Grand London Paddington']],
#  'air con system': [[1.75, 'The Principal London']],
#  'aircon comfy': [[1.0, 'The Park Grand London Paddington']],
#  'instruction': [[0, 'The Park Grand London Paddington']],
#  'iphone': [[1.875, 'Apex Temple Court Hotel']],
#  'court rd staff': [[6.375, 'K K Hotel George']],
#  'interior': [[0.5, 'The Principal London']],
#  'distance temple area': [[9.0, 'Apex Temple Court Hotel']],
#  'wet room shower glass door': [[8.75, 'The Park Grand London Paddington']],
#  'disaster room': [[1.75, 'Hotel Arena']],
#  'take': [[1.875, 'K K Hotel George']],
#  'location': [[28.75, 'K K Hotel George'],
#   [19.625, 'The Principal London'],
#   [16.75, 'Apex Temple Court Hotel'],
#   [14.75, 'The Park Grand London Paddington'],
#   [12.875, 'Hotel Arena']],
#  'fault': [[2.625, 'Hotel Arena'],
#   [1.125, 'Apex Temple Court Hotel'],
#   [0.5, 'The Principal London']],
#  'price': [[3.5, 'The Park Grand London Paddington'],
#   [3.125, 'K K Hotel George'],
#   [2.125, 'Apex Temple Court Hotel'],
#   [1.5, 'Hotel Arena'],
#   [1.0, 'The Principal London']],
#  'winter warmer': [[0.5, 'K K Hotel George']],
#  'court underground station clean quiet breakfast': [[6.75,
#    'K K Hotel George']],
#  'power socket': [[0, 'K K Hotel George']],
#  'charge': [[0.125, 'K K Hotel George'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'london great': [[2.25, 'K K Hotel George']],
#  'am': [[0.25, 'Hotel Arena']],
#  'paddington station good': [[1.875, 'The Park Grand London Paddington']],
#  'story': [[0, 'Hotel Arena']],
#  'ground floor': [[0, 'The Principal London']],
#  'lots': [[0.5, 'The Principal London']],
#  'ceiling room': [[0, 'The Park Grand London Paddington']],
#  'cool': [[0, 'Hotel Arena']],
#  'transformer': [[2.625, 'Hotel Arena']],
#  'tricky': [[0.375, 'The Park Grand London Paddington']],
#  'tourist trap': [[2.0, 'Hotel Arena']],
#  'amsterdam room': [[1.25, 'Hotel Arena']],
#  'twin': [[2.625, 'The Principal London']],
#  'coffee air': [[2.0, 'The Principal London']],
#  'tube friendly': [[2.5, 'K K Hotel George']],
#  'oven': [[0.375, 'K K Hotel George']],
#  'lancaster gate': [[2.25, 'The Park Grand London Paddington']],
#  'wing': [[2.625, 'Hotel Arena']],
#  'fitness center': [[2.25, 'K K Hotel George']],
#  'bathroom': [[14.375, 'Apex Temple Court Hotel'],
#   [7.375, 'The Principal London'],
#   [7.25, 'Hotel Arena'],
#   [5.125, 'K K Hotel George'],
#   [3.375, 'The Park Grand London Paddington']],
#  'room broken': [[3.75, 'Apex Temple Court Hotel']],
#  'westminster': [[0, 'Apex Temple Court Hotel']],
#  'share': [[0.625, 'The Park Grand London Paddington']],
#  'food comfy': [[0.5, 'The Principal London']],
#  'choice': [[4.375, 'K K Hotel George'], [2.75, 'The Principal London']],
#  'point': [[0.625, 'The Park Grand London Paddington'],
#   [0.625, 'Hotel Arena'],
#   [0.5, 'The Principal London']],
#  'easy': [[1.25, 'K K Hotel George'], [0.875, 'Apex Temple Court Hotel']],
#  'mini fridge': [[0, 'Hotel Arena']],
#  'subway station': [[0.5, 'Apex Temple Court Hotel']],
#  'holiday': [[1.375, 'The Principal London'], [0.25, 'Hotel Arena']],
#  'course': [[0.625, 'Hotel Arena'],
#   [0.375, 'K K Hotel George'],
#   [0.25, 'Apex Temple Court Hotel'],
#   [0, 'The Principal London']],
#  'buffet': [[2.625, 'K K Hotel George'],
#   [0.75, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'minute': [[1.125, 'The Park Grand London Paddington']],
#  'quality': [[5.0, 'K K Hotel George'],
#   [1.875, 'Hotel Arena'],
#   [0.5, 'The Principal London'],
#   [0.5, 'Apex Temple Court Hotel']],
#  'relaxing soak': [[2.75, 'Apex Temple Court Hotel']],
#  'business': [[3.0, 'Apex Temple Court Hotel'],
#   [0.5, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington']],
#  'light outside': [[0, 'The Principal London']],
#  'bright': [[0.75, 'Hotel Arena']],
#  'paddington quiet location': [[3.375, 'The Park Grand London Paddington']],
#  'row': [[1.0, 'The Park Grand London Paddington']],
#  'invoice': [[0, 'Apex Temple Court Hotel']],
#  'stair case': [[3.0, 'The Principal London']],
#  'doorman': [[1.375, 'The Principal London']],
#  'design disaster': [[1.25, 'Hotel Arena']],
#  'amsterdam would': [[1.0, 'Hotel Arena']],
#  'cause': [[0.5, 'Hotel Arena'], [0, 'The Park Grand London Paddington']],
#  'tomato': [[0.625, 'Apex Temple Court Hotel']],
#  'mini holiday': [[0, 'The Park Grand London Paddington']],
#  'someone drilling concrete': [[2.25, 'Hotel Arena']],
#  'manky': [[0, 'The Park Grand London Paddington']],
#  'platform': [[0, 'The Principal London']],
#  'cable jack': [[1.5, 'Apex Temple Court Hotel']],
#  'bath lethal combination': [[4.5, 'K K Hotel George']],
#  'luck': [[0, 'The Park Grand London Paddington']],
#  'home': [[0, 'Apex Temple Court Hotel']],
#  'pot': [[0.375, 'The Park Grand London Paddington']],
#  'proud': [[1.625, 'Hotel Arena']],
#  'bedroom suite': [[3.75, 'The Principal London']],
#  'hairdryer': [[0.25, 'The Park Grand London Paddington']],
#  'room temperature': [[0, 'The Park Grand London Paddington']],
#  'sofa': [[0.125, 'The Park Grand London Paddington']],
#  'transportation': [[2.75, 'Hotel Arena'], [0, 'The Principal London']],
#  'permission': [[0, 'Apex Temple Court Hotel']],
#  'london hotel': [[1.0, 'K K Hotel George']],
#  'ticket machine': [[3.875, 'Hotel Arena']],
#  'key everyday': [[0, 'Hotel Arena']],
#  'consisting': [[0.625, 'Apex Temple Court Hotel']],
#  'as': [[3.25, 'K K Hotel George']],
#  'connoisseur': [[0, 'Hotel Arena']],
#  'glass wall': [[0, 'Hotel Arena']],
#  'hair conditioner': [[1.75, 'The Principal London']],
#  'slip mat': [[3.0, 'K K Hotel George']],
#  'didnt': [[0.625, 'The Principal London']],
#  'bank': [[0.625, 'Hotel Arena']],
#  'hotel room stank': [[1.125, 'Apex Temple Court Hotel']],
#  'lack': [[0.5, 'The Principal London']],
#  'room didn t work': [[4.375, 'The Principal London']],
#  'euston station': [[2.25, 'The Principal London']],
#  'today s': [[0, 'K K Hotel George']],
#  'space': [[2.625, 'The Park Grand London Paddington'],
#   [2.0, 'Hotel Arena'],
#   [1.75, 'K K Hotel George'],
#   [1.625, 'The Principal London']],
#  'dog my shower drain': [[5.5, 'Hotel Arena']],
#  'breakfast staff': [[2.5, 'Hotel Arena'], [1.25, 'K K Hotel George']],
#  'location right': [[2.5, 'Apex Temple Court Hotel']],
#  'breakfast selection': [[1.0, 'Hotel Arena']],
#  'expense': [[0.5, 'Apex Temple Court Hotel']],
#  'basement room': [[0.5, 'K K Hotel George'],
#   [0, 'The Park Grand London Paddington']],
#  'care': [[3.125, 'Hotel Arena']],
#  'garage door': [[0, 'Hotel Arena']],
#  'convenience': [[0.625, 'Hotel Arena'], [0, 'K K Hotel George']],
#  'cab': [[1.0, 'The Park Grand London Paddington']],
#  'connection': [[0.75, 'Apex Temple Court Hotel']],
#  'resection': [[2.0, 'The Principal London']],
#  'dressing gowns': [[1.0, 'The Park Grand London Paddington']],
#  'system': [[1.125, 'The Principal London'], [0, 'Hotel Arena']],
#  'renovation': [[0.875, 'Hotel Arena'], [0, 'The Principal London']],
#  'hotel ornate': [[4.25, 'The Park Grand London Paddington']],
#  'centre': [[1.875, 'Hotel Arena'],
#   [1.125, 'Apex Temple Court Hotel'],
#   [0.25, 'The Park Grand London Paddington']],
#  'housekeeping': [[0.625, 'K K Hotel George']],
#  'monday': [[0, 'The Principal London']],
#  'cap shower gel': [[1.5, 'The Principal London']],
#  'tram stop': [[1.0, 'Hotel Arena']],
#  'non adult': [[0.125, 'The Park Grand London Paddington']],
#  'shower door': [[0, 'Apex Temple Court Hotel']],
#  'dragon sculpture': [[3.0, 'The Principal London']],
#  'aways': [[0, 'Apex Temple Court Hotel']],
#  'bus tour': [[1.0, 'The Principal London']],
#  'nicer': [[1.0, 'The Principal London']],
#  'heating': [[1.25, 'Hotel Arena'], [0.5, 'K K Hotel George']],
#  'one office chair': [[7.625, 'Apex Temple Court Hotel']],
#  'good location': [[3.5, 'K K Hotel George'],
#   [2.5, 'Apex Temple Court Hotel']],
#  'apex duck would': [[2.625, 'Apex Temple Court Hotel']],
#  'fire drill': [[0, 'The Principal London']],
#  'sleep': [[1.125, 'Hotel Arena']],
#  'paddington area': [[4.25, 'The Park Grand London Paddington']],
#  'a c controller': [[4.125, 'The Park Grand London Paddington']],
#  'court tube': [[5.75, 'K K Hotel George']],
#  'counter': [[0, 'The Park Grand London Paddington']],
#  'cozy bath': [[3.5, 'Apex Temple Court Hotel']],
#  'walk': [[5.75, 'Hotel Arena'],
#   [4.0, 'K K Hotel George'],
#   [2.875, 'Apex Temple Court Hotel'],
#   [2.0, 'The Principal London'],
#   [2.0, 'The Park Grand London Paddington']],
#  'o clock': [[4.75, 'Hotel Arena']],
#  'propert': [[1.25, 'The Park Grand London Paddington']],
#  'heathrow express': [[4.25, 'The Park Grand London Paddington']],
#  'minimalistic': [[1.875, 'Apex Temple Court Hotel']],
#  'basement': [[0.625, 'The Park Grand London Paddington']],
#  'hair dryer': [[1.25, 'Hotel Arena']],
#  'door chain': [[1.375, 'The Principal London']],
#  'london s': [[1.25, 'K K Hotel George']],
#  'desk chairs': [[0, 'Hotel Arena']],
#  'wedding anniversary': [[1.5, 'The Principal London']],
#  'traffic noise': [[1.0, 'Apex Temple Court Hotel']],
#  'room someone': [[2.75, 'K K Hotel George']],
#  'courtyard windows': [[2.25, 'The Principal London']],
#  'reason': [[1.75, 'Apex Temple Court Hotel'],
#   [0.625, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington']],
#  'access': [[3.875, 'K K Hotel George'],
#   [1.75, 'Hotel Arena'],
#   [0.375, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'diverse breakfast': [[1.875, 'K K Hotel George']],
#  'plan': [[0, 'Apex Temple Court Hotel']],
#  'state': [[1.125, 'Hotel Arena']],
#  'winter': [[0, 'K K Hotel George']],
#  'background': [[2.875, 'Hotel Arena']],
#  'destination': [[0, 'Hotel Arena']],
#  'staff excellent location': [[7.125, 'K K Hotel George']],
#  'place closer': [[2.0, 'Apex Temple Court Hotel']],
#  'bid': [[0.5, 'Hotel Arena']],
#  'very': [[5.25, 'K K Hotel George'],
#   [0.75, 'Apex Temple Court Hotel'],
#   [0.5, 'The Principal London'],
#   [0, 'Hotel Arena']],
#  'arrival': [[0.875, 'Hotel Arena'],
#   [0.625, 'The Park Grand London Paddington'],
#   [0, 'K K Hotel George']],
#  'combination': [[0.125, 'The Principal London']],
#  'toilet bathroom': [[4.5, 'The Park Grand London Paddington']],
#  'stuff': [[0.875, 'Apex Temple Court Hotel']],
#  'small': [[0.75, 'K K Hotel George']],
#  'orphanage': [[0.25, 'Hotel Arena']],
#  'dozen': [[0, 'The Principal London']],
#  'greenery': [[0.5, 'Hotel Arena']],
#  'city centre': [[5.5, 'Hotel Arena'], [0, 'The Principal London']],
#  'drink secure parking': [[2.25, 'K K Hotel George']],
#  'advance': [[1.5, 'Apex Temple Court Hotel'], [0, 'Hotel Arena']],
#  'room nice': [[1.5, 'K K Hotel George']],
#  're': [[0, 'K K Hotel George']],
#  'disgusting': [[0, 'The Park Grand London Paddington']],
#  'promotion': [[1.375, 'K K Hotel George']],
#  'conversation': [[0.75, 'The Principal London']],
#  'segregation': [[0.5, 'The Park Grand London Paddington']],
#  'handrail': [[0, 'Hotel Arena']],
#  'euston': [[0, 'The Principal London']],
#  'link': [[0, 'The Park Grand London Paddington']],
#  'my standard room': [[5.25, 'Apex Temple Court Hotel']],
#  'tea': [[2.75, 'The Principal London'],
#   [0.875, 'The Park Grand London Paddington'],
#   [0.5, 'K K Hotel George'],
#   [0, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'pointless': [[0.625, 'Hotel Arena']],
#  'twist staircase': [[0.75, 'Hotel Arena']],
#  'twin room': [[0.75, 'The Principal London']],
#  'tiles': [[1.125, 'The Principal London']],
#  'wider': [[0.5, 'The Park Grand London Paddington']],
#  'design flaw': [[1.25, 'Apex Temple Court Hotel']],
#  'location my': [[1.0, 'Hotel Arena']],
#  'tram system': [[12.25, 'Hotel Arena']],
#  'travel': [[0.75, 'The Principal London']],
#  'district': [[0, 'Apex Temple Court Hotel']],
#  'cozy': [[1.125, 'K K Hotel George']],
#  'seat': [[0.875, 'K K Hotel George']],
#  'concession': [[0.5, 'Apex Temple Court Hotel']],
#  'line check': [[0, 'K K Hotel George']],
#  'floor air': [[2.25, 'The Principal London']],
#  'voucher': [[1.5, 'Apex Temple Court Hotel']],
#  't experience': [[5.5, 'Apex Temple Court Hotel']],
#  'coffee milk': [[0, 'Apex Temple Court Hotel']],
#  'terrace': [[0.75, 'Hotel Arena']],
#  'invitation': [[0, 'Apex Temple Court Hotel']],
#  'afternoon': [[0.875, 'Apex Temple Court Hotel']],
#  'paddington station lots': [[0, 'The Park Grand London Paddington']],
#  'hotel inside': [[4.375, 'Hotel Arena']],
#  'vicinity': [[0, 'The Park Grand London Paddington']],
#  'bathroom floor': [[1.0, 'The Principal London']],
#  'forth': [[1.125, 'The Park Grand London Paddington']],
#  'pleasant': [[1.5, 'K K Hotel George']],
#  'titanic': [[2.375, 'The Principal London']],
#  'thank you': [[0, 'Apex Temple Court Hotel']],
#  'robe': [[2.5, 'The Park Grand London Paddington']],
#  'rainfall': [[1.375, 'Hotel Arena']],
#  'concierge desk': [[4.25, 'The Park Grand London Paddington']],
#  'staff member speak': [[0, 'K K Hotel George']],
#  'traffic': [[0, 'The Principal London']],
#  'staff easy access': [[3.375, 'The Park Grand London Paddington']],
#  'feeling': [[0.875, 'Hotel Arena']],
#  'night room': [[1.25, 'Hotel Arena']],
#  'room price': [[0, 'Apex Temple Court Hotel']],
#  'duty': [[1.375, 'Apex Temple Court Hotel']],
#  'diet': [[0.5, 'K K Hotel George']],
#  'amenity': [[0, 'K K Hotel George']],
#  'glad': [[0, 'Apex Temple Court Hotel']],
#  'get': [[0, 'K K Hotel George']],
#  'position': [[2.125, 'K K Hotel George'],
#   [1.75, 'The Park Grand London Paddington']],
#  'shop': [[2.0, 'The Principal London']],
#  'airy': [[0.75, 'Hotel Arena']],
#  'staff food': [[2.0, 'Hotel Arena']],
#  'tourist bustle': [[3.5, 'K K Hotel George']],
#  'lighting': [[0.625, 'K K Hotel George'], [0.5, 'Hotel Arena']],
#  'booking com': [[0, 'Apex Temple Court Hotel']],
#  'difference': [[2.75, 'The Park Grand London Paddington'],
#   [0.5, 'K K Hotel George']],
#  'ac': [[0.875, 'The Park Grand London Paddington'],
#   [0.625, 'K K Hotel George']],
#  'hotel no': [[0, 'K K Hotel George']],
#  'group': [[0.375, 'The Park Grand London Paddington']],
#  'staff': [[30.625, 'K K Hotel George'],
#   [24.625, 'Hotel Arena'],
#   [19.25, 'The Park Grand London Paddington'],
#   [12.375, 'The Principal London'],
#   [11.625, 'Apex Temple Court Hotel']],
#  'carbon paper': [[0, 'The Park Grand London Paddington']],
#  'drink etc': [[1.5, 'K K Hotel George']],
#  'tax': [[0, 'K K Hotel George']],
#  'blocked bath drain': [[3.375, 'The Principal London']],
#  'change complimentary fruit water': [[6.5,
#    'The Park Grand London Paddington']],
#  'suit': [[3.25, 'K K Hotel George']],
#  'circle line': [[6.25, 'The Principal London']],
#  'building': [[15.0, 'Hotel Arena'],
#   [6.0, 'The Principal London'],
#   [0.375, 'The Park Grand London Paddington']],
#  'decoration': [[1.25, 'Apex Temple Court Hotel']],
#  'wardrobe space': [[4.0, 'The Park Grand London Paddington'],
#   [3.25, 'Apex Temple Court Hotel']],
#  'survivor': [[0.25, 'The Principal London']],
#  'earl': [[13.875, 'K K Hotel George']],
#  'generator': [[0, 'The Principal London']],
#  'toaster': [[0, 'K K Hotel George']],
#  'breakfast buffet': [[4.25, 'K K Hotel George'],
#   [3.25, 'The Park Grand London Paddington']],
#  'sized bathroom': [[7.75, 'Apex Temple Court Hotel']],
#  'russell hotel': [[0.5, 'The Principal London']],
#  'face': [[0, 'Apex Temple Court Hotel']],
#  'staff didn t': [[2.5, 'Apex Temple Court Hotel']],
#  'bathroom sink': [[4.75, 'K K Hotel George']],
#  'hole': [[0, 'The Principal London']],
#  'bayswater station everyday staff': [[0.875,
#    'The Park Grand London Paddington']],
#  'heathrow': [[2.25, 'The Principal London'], [2.25, 'K K Hotel George']],
#  'bathroom mirror': [[1.25, 'Apex Temple Court Hotel']],
#  'friendliness': [[0.25, 'The Park Grand London Paddington']],
#  'chair room service hair dryer fridge kettle': [[5.125, 'Hotel Arena']],
#  'tiny': [[0, 'The Park Grand London Paddington']],
#  'bar restaurant area': [[4.125, 'Hotel Arena']],
#  'potato': [[0.375, 'K K Hotel George']],
#  'taste': [[1.125, 'Hotel Arena'], [1.0, 'The Principal London']],
#  'paddington': [[3.125, 'The Park Grand London Paddington']],
#  'budget room': [[2.25, 'The Park Grand London Paddington']],
#  'picadilly tube': [[6.25, 'The Principal London']],
#  'spaciousness': [[2.625, 'Apex Temple Court Hotel']],
#  'wife': [[0.625, 'The Park Grand London Paddington'], [0.375, 'Hotel Arena']],
#  'location very': [[3.5, 'The Park Grand London Paddington']],
#  'complain': [[0, 'Hotel Arena']],
#  'conceierge service': [[2.75, 'Apex Temple Court Hotel']],
#  'road side': [[1.25, 'The Principal London']],
#  'discreet': [[0, 'Apex Temple Court Hotel']],
#  'repairman': [[2.125, 'Hotel Arena']],
#  'lay': [[0.625, 'Hotel Arena']],
#  'music': [[0.375, 'Apex Temple Court Hotel']],
#  'corner': [[2.0, 'The Principal London'],
#   [0.625, 'The Park Grand London Paddington'],
#   [0.5, 'K K Hotel George'],
#   [0, 'Apex Temple Court Hotel']],
#  'tram ride': [[1.75, 'Hotel Arena']],
#  'order shower': [[2.25, 'Hotel Arena']],
#  'ease': [[2.5, 'The Park Grand London Paddington']],
#  'visit special': [[4.75, 'K K Hotel George']],
#  'building work': [[7.25, 'Hotel Arena'], [0, 'The Principal London']],
#  'bus': [[0.5, 'The Principal London']],
#  'plug': [[0, 'The Park Grand London Paddington']],
#  'concierge': [[1.875, 'The Principal London'],
#   [1.375, 'Apex Temple Court Hotel']],
#  'standard hotel': [[0, 'Apex Temple Court Hotel']],
#  'hotel location': [[2.0, 'The Park Grand London Paddington'],
#   [0, 'The Principal London']],
#  'selection nice': [[2.25, 'K K Hotel George']],
#  'slate bathroom mini fridge': [[2.0, 'K K Hotel George']],
#  'fan': [[0.375, 'Apex Temple Court Hotel'], [0, 'K K Hotel George']],
#  'return': [[0.25, 'The Park Grand London Paddington'],
#   [0, 'The Principal London']],
#  'shower': [[6.375, 'Apex Temple Court Hotel'],
#   [5.5, 'The Principal London'],
#   [3.125, 'The Park Grand London Paddington'],
#   [1.5, 'K K Hotel George'],
#   [1.375, 'Hotel Arena']],
#  'nice room modern': [[0.5, 'Apex Temple Court Hotel']],
#  'check': [[4.625, 'Hotel Arena'],
#   [2.5, 'The Principal London'],
#   [2.375, 'The Park Grand London Paddington'],
#   [1.5, 'K K Hotel George'],
#   [0.875, 'Apex Temple Court Hotel']],
#  'summer': [[0.75, 'Apex Temple Court Hotel'], [0.5, 'K K Hotel George']],
#  'pharmacy': [[0, 'The Park Grand London Paddington']],
#  'erls court london': [[0, 'K K Hotel George']],
#  'vibe': [[2.5, 'Apex Temple Court Hotel']],
#  'comfy': [[1.875, 'Apex Temple Court Hotel'],
#   [1.0, 'K K Hotel George'],
#   [0.5, 'Hotel Arena']],
#  'equipment': [[0, 'K K Hotel George']],
#  'bar staff': [[0, 'Hotel Arena']],
#  'fond': [[0.5, 'The Park Grand London Paddington']],
#  'situation': [[0.25, 'Hotel Arena']],
#  'extras': [[0.5, 'Apex Temple Court Hotel']],
#  'door staff': [[2.0, 'The Principal London']],
#  'tube room': [[2.25, 'Apex Temple Court Hotel']],
#  'outside': [[2.0, 'The Principal London'], [1.25, 'Hotel Arena']],
#  'service gorgeous': [[1.75, 'The Principal London']],
#  'end room': [[1.5, 'Apex Temple Court Hotel']],
#  'hair parking': [[0.5, 'The Park Grand London Paddington']],
#  'door frame': [[0, 'The Principal London']],
#  'consumer': [[0.375, 'Hotel Arena']],
#  'roof': [[1.375, 'Hotel Arena']],
#  'room hotel': [[3.0, 'Apex Temple Court Hotel']],
#  'court station': [[3.25, 'K K Hotel George']],
#  'wardrobe view wasn': [[3.75, 'The Park Grand London Paddington']],
#  'eye contact': [[1.25, 'Hotel Arena']],
#  'hdmi cable': [[2.25, 'K K Hotel George']],
#  'hotel first': [[1.0, 'The Park Grand London Paddington']],
#  'axcess': [[0, 'Hotel Arena']],
#  'compact': [[2.0, 'The Park Grand London Paddington']],
#  'proximity': [[0.5, 'K K Hotel George'],
#   [0.375, 'The Park Grand London Paddington']],
#  'airport': [[1.0, 'K K Hotel George'],
#   [0, 'The Principal London'],
#   [0, 'Hotel Arena']],
#  'wasn': [[1.0, 'K K Hotel George'], [0, 'The Park Grand London Paddington']],
#  'eurostar room': [[4.25, 'The Principal London']],
#  'night shift manager': [[6.375, 'Hotel Arena']],
#  'bonus gift': [[0.5, 'The Park Grand London Paddington']],
#  'australia': [[0, 'The Park Grand London Paddington']],
#  'hotel room': [[1.625, 'Hotel Arena']],
#  'dust': [[0.875, 'Hotel Arena']],
#  'morning': [[2.5, 'Hotel Arena'],
#   [1.75, 'The Park Grand London Paddington'],
#   [0.5, 'K K Hotel George'],
#   [0, 'The Principal London']],
#  'ambience': [[1.75, 'Apex Temple Court Hotel'], [0, 'K K Hotel George']],
#  'room decoration': [[2.25, 'Hotel Arena']],
#  'impact': [[0, 'The Principal London']],
#  'dinner bar': [[0, 'Hotel Arena']],
#  'continental breakfast': [[4.25, 'Apex Temple Court Hotel']],
#  'brunch': [[0.5, 'Hotel Arena']],
#  'opinion': [[1.75, 'The Principal London'], [0.5, 'Hotel Arena']],
#  'credit card': [[1.25, 'K K Hotel George'],
#   [0, 'The Park Grand London Paddington']],
#  'london close': [[1.625, 'The Principal London']],
#  'book': [[0.375, 'The Park Grand London Paddington'], [0.375, 'Hotel Arena']],
#  'water pressure': [[0.25, 'Hotel Arena']],
#  'glass box': [[1.25, 'Hotel Arena']],
#  'pm': [[0, 'The Principal London']],
#  'britain': [[0.5, 'Apex Temple Court Hotel']],
#  'food supermarket': [[3.25, 'K K Hotel George']],
#  'reservation': [[1.25, 'Apex Temple Court Hotel']],
#  'st paul s tate modern': [[2.5, 'Apex Temple Court Hotel']],
#  'com': [[0.375, 'Hotel Arena']],
#  'king': [[1.125, 'Apex Temple Court Hotel']],
#  'info': [[0.25, 'Apex Temple Court Hotel']],
#  'room nothing': [[3.75, 'Apex Temple Court Hotel']],
#  'opulence': [[0, 'The Principal London']],
#  'mobility': [[0, 'Apex Temple Court Hotel']],
#  'decorating': [[1.375, 'The Principal London']],
#  'touch': [[1.625, 'The Park Grand London Paddington']],
#  'bummer': [[0.625, 'The Principal London']],
#  'use': [[2.5, 'The Park Grand London Paddington'], [0, 'Hotel Arena']],
#  'spoonful': [[0.625, 'Apex Temple Court Hotel']],
#  'wedding': [[0.625, 'Hotel Arena']],
#  'bathroom tiny': [[1.0, 'The Park Grand London Paddington']],
#  'period': [[1.5, 'The Principal London']],
#  'breakfast table': [[0.625, 'K K Hotel George']],
#  'solo': [[0, 'K K Hotel George']],
#  'couldn t work': [[1.5, 'K K Hotel George']],
#  'mattress wasn t': [[0, 'K K Hotel George']],
#  'mine': [[0.625, 'Apex Temple Court Hotel']],
#  'tram subway': [[1.25, 'Hotel Arena']],
#  'duvet': [[0.75, 'Hotel Arena']],
#  'room desk': [[1.0, 'K K Hotel George']],
#  'quality apples': [[2.5, 'The Park Grand London Paddington']],
#  'beautiful building': [[2.75, 'The Park Grand London Paddington']],
#  'room was': [[2.5, 'Hotel Arena']],
#  'kettle': [[1.25, 'The Park Grand London Paddington']],
#  'trip': [[0, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'room balcony': [[0.5, 'Apex Temple Court Hotel']],
#  'possibility': [[1.875, 'Apex Temple Court Hotel']],
#  'fortune': [[1.0, 'The Principal London']],
#  'water location': [[4.25, 'K K Hotel George']],
#  'pringles': [[0, 'Apex Temple Court Hotel']],
#  'picadilly': [[3.125, 'The Principal London']],
#  'reception area': [[2.0, 'Hotel Arena'], [1.0, 'K K Hotel George']],
#  'book breakfast': [[0.25, 'K K Hotel George']],
#  'room': [[40.5, 'The Park Grand London Paddington'],
#   [37.375, 'Hotel Arena'],
#   [23.5, 'Apex Temple Court Hotel'],
#   [22.875, 'The Principal London'],
#   [20.5, 'K K Hotel George']],
#  'fitness area': [[3.5, 'K K Hotel George']],
#  'a': [[1.5, 'K K Hotel George'], [0.5, 'Apex Temple Court Hotel']],
#  'windows weren t closing': [[2.0, 'The Principal London']],
#  'euros': [[0.375, 'Hotel Arena']],
#  'spot': [[2.875, 'Hotel Arena'],
#   [2.125, 'K K Hotel George'],
#   [1.125, 'The Principal London']],
#  'city': [[8.375, 'Hotel Arena'],
#   [2.5, 'K K Hotel George'],
#   [1.25, 'Apex Temple Court Hotel'],
#   [0.625, 'The Principal London']],
#  'front': [[2.25, 'The Park Grand London Paddington'],
#   [0.5, 'The Principal London'],
#   [0.25, 'Hotel Arena']],
#  'break': [[4.125, 'Hotel Arena']],
#  'mashine': [[0, 'K K Hotel George']],
#  'nothing': [[4.125, 'K K Hotel George'],
#   [0.625, 'Hotel Arena'],
#   [0.375, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'anyone': [[2.875, 'Hotel Arena'], [0.5, 'The Park Grand London Paddington']],
#  'night guard': [[0, 'Hotel Arena']],
#  'soap': [[0.875, 'Hotel Arena']],
#  'quality food': [[5.75, 'Hotel Arena']],
#  'pillow': [[0, 'The Principal London']],
#  'offer': [[0.625, 'Hotel Arena'], [0, 'The Park Grand London Paddington']],
#  'tour': [[0.5, 'The Principal London'], [0.25, 'Hotel Arena']],
#  'food': [[6.375, 'The Park Grand London Paddington'],
#   [4.75, 'Apex Temple Court Hotel'],
#   [1.625, 'Hotel Arena'],
#   [0.75, 'K K Hotel George'],
#   [0.5, 'The Principal London']],
#  'hair': [[0.75, 'K K Hotel George'],
#   [0, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'boyfriend': [[0.875, 'Apex Temple Court Hotel']],
#  'back': [[1.875, 'The Park Grand London Paddington'],
#   [0.75, 'K K Hotel George']],
#  'rome': [[2.125, 'The Park Grand London Paddington']],
#  'inconvenience': [[0, 'The Park Grand London Paddington']],
#  'balcony': [[0.125, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'city center': [[0.25, 'Hotel Arena']],
#  'plate': [[1.75, 'The Park Grand London Paddington']],
#  'best': [[0, 'Apex Temple Court Hotel']],
#  't use': [[3.5, 'Apex Temple Court Hotel']],
#  'reception': [[6.0, 'K K Hotel George'],
#   [4.375, 'Apex Temple Court Hotel'],
#   [3.75, 'The Park Grand London Paddington'],
#   [3.125, 'Hotel Arena'],
#   [0.125, 'The Principal London']],
#  'neck room service': [[1.0, 'Hotel Arena']],
#  'wood': [[4.125, 'The Park Grand London Paddington'], [0.25, 'Hotel Arena']],
#  'service': [[5.875, 'Hotel Arena'],
#   [0.5, 'K K Hotel George'],
#   [0, 'Apex Temple Court Hotel']],
#  'affair': [[2.625, 'Hotel Arena']],
#  'clean bathroom nice shower': [[2.5, 'K K Hotel George']],
#  'whole': [[0.75, 'Hotel Arena']],
#  'bar shame': [[4.0, 'The Principal London']],
#  'kind breakfast': [[2.75, 'K K Hotel George']],
#  'practice': [[0, 'Hotel Arena']],
#  'nice room': [[0, 'Apex Temple Court Hotel']],
#  'rooftop room': [[1.75, 'The Park Grand London Paddington']],
#  'boiler unit': [[0.75, 'The Park Grand London Paddington']],
#  'superb': [[0.625, 'K K Hotel George'], [0.375, 'The Principal London']],
#  'transport': [[2.25, 'K K Hotel George'],
#   [0.875, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington']],
#  'banging': [[0.5, 'Hotel Arena']],
#  'hotel s chapel': [[3.375, 'Hotel Arena']],
#  'post': [[0.375, 'Hotel Arena']],
#  'mile': [[4.125, 'Hotel Arena'], [0, 'Apex Temple Court Hotel']],
#  'theatre': [[1.625, 'The Park Grand London Paddington']],
#  'tap': [[1.625, 'The Principal London'],
#   [0.5, 'The Park Grand London Paddington']],
#  'bottles': [[0.5, 'The Park Grand London Paddington']],
#  'was': [[2.125, 'The Park Grand London Paddington']],
#  'club room': [[11.25, 'The Park Grand London Paddington']],
#  'carpet': [[1.875, 'Apex Temple Court Hotel'], [0, 'K K Hotel George']],
#  'work': [[2.875, 'The Park Grand London Paddington'],
#   [0.875, 'The Principal London'],
#   [0.875, 'Hotel Arena']],
#  'hidden wardrobe drop': [[3.375, 'The Park Grand London Paddington']],
#  'car': [[2.125, 'K K Hotel George'], [0.5, 'Apex Temple Court Hotel']],
#  'extra': [[0, 'Hotel Arena'], [0, 'Apex Temple Court Hotel']],
#  'selection': [[3.125, 'The Park Grand London Paddington'],
#   [2.0, 'Apex Temple Court Hotel'],
#   [0.75, 'Hotel Arena'],
#   [0, 'K K Hotel George']],
#  'tourist': [[2.125, 'Hotel Arena']],
#  'park room': [[6.75, 'Hotel Arena']],
#  'park ca': [[1.125, 'Hotel Arena']],
#  'meal': [[1.875, 'The Park Grand London Paddington'], [0.25, 'Hotel Arena']],
#  'terrace building': [[1.75, 'The Park Grand London Paddington']],
#  'white furniture': [[2.75, 'Hotel Arena']],
#  'toilet floor': [[0, 'The Park Grand London Paddington']],
#  'character breakfast': [[1.0, 'The Principal London']],
#  'cleaning': [[1.75, 'Hotel Arena']],
#  'site': [[1.0, 'K K Hotel George'],
#   [0, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'billowing': [[1.0, 'K K Hotel George']],
#  'showering': [[0.25, 'Hotel Arena']],
#  't seem': [[2.875, 'Hotel Arena']],
#  'design': [[2.0, 'Hotel Arena'],
#   [0.625, 'Apex Temple Court Hotel'],
#   [0.5, 'The Park Grand London Paddington']],
#  'respond': [[0, 'The Park Grand London Paddington']],
#  'statuesque grandeur': [[0, 'The Principal London']],
#  'staff polite': [[3.0, 'The Principal London']],
#  'fab experience': [[3.625, 'K K Hotel George']],
#  'power walk': [[2.5, 'The Park Grand London Paddington']],
#  'day': [[9.0, 'Hotel Arena'],
#   [5.0, 'K K Hotel George'],
#   [3.0, 'The Principal London'],
#   [2.25, 'Apex Temple Court Hotel'],
#   [2.125, 'The Park Grand London Paddington']],
#  'novello': [[0, 'Apex Temple Court Hotel']],
#  'aspect fantastic location': [[5.25, 'K K Hotel George']],
#  'way': [[3.625, 'Hotel Arena'],
#   [2.75, 'K K Hotel George'],
#   [1.875, 'Apex Temple Court Hotel'],
#   [1.75, 'The Park Grand London Paddington'],
#   [1.125, 'The Principal London']],
#  'fault someone': [[0, 'K K Hotel George']],
#  'euston hilton hotel': [[3.0, 'The Principal London']],
#  'world': [[1.125, 'The Principal London'], [0, 'K K Hotel George']],
#  'breakfast range': [[1.0, 'Hotel Arena']],
#  'monastery building': [[3.25, 'Hotel Arena']],
#  'room wasn': [[1.0, 'K K Hotel George']],
#  'breakfast check': [[2.5, 'Hotel Arena']],
#  'bonus': [[2.25, 'K K Hotel George'],
#   [1.625, 'The Principal London'],
#   [0.875, 'Apex Temple Court Hotel']],
#  'jug': [[0, 'Apex Temple Court Hotel']],
#  'bedroom': [[0.875, 'Hotel Arena'],
#   [0.5, 'The Principal London'],
#   [0.25, 'Apex Temple Court Hotel']],
#  'nice restaurant': [[2.125, 'Hotel Arena']],
#  'time': [[4.75, 'Apex Temple Court Hotel'],
#   [2.625, 'K K Hotel George'],
#   [2.625, 'Hotel Arena'],
#   [1.5, 'The Principal London'],
#   [0.375, 'The Park Grand London Paddington']],
#  'cost': [[1.875, 'K K Hotel George'], [0.5, 'The Principal London']],
#  'trafalgar square': [[0, 'Apex Temple Court Hotel']],
#  'flight': [[0, 'The Principal London'],
#   [0, 'The Park Grand London Paddington']],
#  'pipe work': [[1.0, 'The Park Grand London Paddington']],
#  'closeness': [[0, 'K K Hotel George']],
#  'answer': [[0, 'Hotel Arena']],
#  'fruit': [[1.375, 'The Principal London'],
#   [0.875, 'Apex Temple Court Hotel']],
#  'friend s recommendation': [[1.5, 'K K Hotel George']],
#  'stay': [[3.625, 'Hotel Arena'],
#   [3.25, 'K K Hotel George'],
#   [2.0, 'The Principal London'],
#   [1.875, 'The Park Grand London Paddington'],
#   [1.625, 'Apex Temple Court Hotel']],
#  'backyard': [[0, 'Hotel Arena']],
#  'start': [[1.5, 'Apex Temple Court Hotel'],
#   [0.5, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington']],
#  'temple': [[0.5, 'Apex Temple Court Hotel']],
#  'telephone huge price difference': [[0, 'Hotel Arena']],
#  'toilet bath area': [[1.5, 'The Park Grand London Paddington']],
#  'window didn t': [[0, 'K K Hotel George']],
#  'breakfast enough': [[2.5, 'K K Hotel George']],
#  'room very convenient': [[5.25, 'The Park Grand London Paddington']],
#  'ceiling': [[1.75, 'The Principal London'],
#   [1.0, 'Hotel Arena'],
#   [0.5, 'The Park Grand London Paddington']],
#  'lady': [[2.125, 'K K Hotel George'],
#   [0.875, 'The Park Grand London Paddington']],
#  'champagne': [[1.375, 'The Principal London']],
#  'appreciation': [[0.5, 'Hotel Arena']],
#  'cheaper': [[1.0, 'The Principal London']],
#  'club room bar': [[7.125, 'The Park Grand London Paddington']],
#  'disgust': [[0, 'K K Hotel George']],
#  'area': [[6.75, 'The Park Grand London Paddington'],
#   [5.375, 'Apex Temple Court Hotel'],
#   [4.25, 'K K Hotel George'],
#   [2.625, 'The Principal London'],
#   [1.75, 'Hotel Arena']],
#  'bose speaker': [[3.75, 'Apex Temple Court Hotel']],
#  'bar space': [[1.0, 'Apex Temple Court Hotel']],
#  'duck': [[0.25, 'Apex Temple Court Hotel']],
#  'great position': [[2.0, 'K K Hotel George']],
#  'hour': [[0.625, 'Hotel Arena'], [0.375, 'K K Hotel George']],
#  'manager': [[0, 'The Park Grand London Paddington'], [0, 'Hotel Arena']],
#  'restaurants': [[1.75, 'K K Hotel George']],
#  'refurbishment': [[0, 'The Principal London']],
#  'cancellation': [[1.125, 'The Principal London']],
#  'concierge service': [[6.25, 'The Principal London']],
#  'room size': [[1.25, 'K K Hotel George']],
#  'consideration': [[1.75, 'The Principal London'], [0, 'K K Hotel George']],
#  'bose sound system': [[4.0, 'Apex Temple Court Hotel']],
#  'reduction coupon': [[1.75, 'Apex Temple Court Hotel']],
#  'exit right': [[2.25, 'The Principal London']],
#  'air con didn t work': [[8.75, 'The Park Grand London Paddington']],
#  'btw': [[0.625, 'Hotel Arena']],
#  'service charge': [[0, 'The Principal London']],
#  'underground station': [[9.75, 'K K Hotel George']],
#  'apex duck': [[7.75, 'Apex Temple Court Hotel']],
#  'reception staff': [[6.25, 'The Principal London']],
#  'card': [[0.75, 'The Principal London'],
#   [0.625, 'Hotel Arena'],
#   [0.625, 'Apex Temple Court Hotel'],
#   [0, 'The Park Grand London Paddington']],
#  'perfect launch pad': [[0.75, 'Hotel Arena']],
#  'meager': [[0, 'K K Hotel George']],
#  'road dining room': [[1.875, 'The Principal London']],
#  'decor good location great': [[1.875, 'The Principal London']],
#  'sofa bed': [[1.5, 'K K Hotel George']],
#  'historic': [[0.875, 'The Principal London']],
#  'valet': [[1.0, 'The Park Grand London Paddington']],
#  'alley': [[0, 'The Park Grand London Paddington']],
#  'picture': [[1.0, 'The Park Grand London Paddington']],
#  'court tube station': [[4.875, 'K K Hotel George']],
#  'room breakfast': [[0.625, 'The Principal London']],
#  'big window': [[2.25, 'The Park Grand London Paddington']],
#  'architecture': [[2.5, 'The Principal London'], [1.0, 'Hotel Arena']],
#  'sure': [[1.75, 'Hotel Arena']],
#  'juice': [[0.625, 'Hotel Arena']],
#  'waitress': [[0, 'The Principal London']],
#  'restaurant': [[6.75, 'Hotel Arena'],
#   [4.25, 'K K Hotel George'],
#   [2.75, 'The Park Grand London Paddington'],
#   [0.5, 'The Principal London'],
#   [0.5, 'Apex Temple Court Hotel']],
#  'room pic dose': [[0.125, 'The Park Grand London Paddington']],
#  'gentleman': [[1.625, 'K K Hotel George'], [0.625, 'Hotel Arena']],
#  'negligence': [[2.125, 'Hotel Arena']],
#  'set': [[1.5, 'Hotel Arena']],
#  'kensington palace albert hall knightsbridge': [[0, 'K K Hotel George']],
#  'parking': [[1.75, 'K K Hotel George'], [1.5, 'Apex Temple Court Hotel']],
#  'room decor': [[0, 'Hotel Arena']],
#  'approx': [[0, 'The Park Grand London Paddington']],
#  'communication': [[0, 'The Park Grand London Paddington']],
#  'wasn t': [[3.25, 'The Park Grand London Paddington'],
#   [1.25, 'K K Hotel George'],
#   [0.25, 'Hotel Arena']],
#  'paddington station': [[5.5, 'The Park Grand London Paddington']],
#  'trash lorry': [[0, 'Hotel Arena']],
#  'corridor': [[1.75, 'Apex Temple Court Hotel'],
#   [0.5, 'The Park Grand London Paddington'],
#   [0.5, 'Hotel Arena']],
#  'reference': [[0, 'Apex Temple Court Hotel']],
#  'staff hyde parks': [[6.125, 'The Park Grand London Paddington']],
#  'block': [[0, 'K K Hotel George']],
#  'waist': [[1.125, 'Hotel Arena']],
#  'room bed': [[7.75, 'Apex Temple Court Hotel'], [4.0, 'K K Hotel George']],
#  'st pancras station': [[0.875, 'The Principal London']],
#  'espresso cappucino': [[5.5, 'K K Hotel George']],
#  'paddngton station': [[1.75, 'The Park Grand London Paddington']],
#  'wednesday thursday': [[2.25, 'Apex Temple Court Hotel']],
#  'spent': [[0, 'Apex Temple Court Hotel']],
#  'difficulty': [[2.25, 'Hotel Arena']],
#  'main street': [[0.25, 'The Park Grand London Paddington']],
#  'room fridge': [[0, 'Hotel Arena']],
#  'division': [[1.25, 'K K Hotel George']],
#  'furniture': [[4.5, 'The Park Grand London Paddington']],
#  'courtyard': [[4.125, 'Hotel Arena']],
#  'surrounding': [[0.875, 'The Park Grand London Paddington']],
#  'pain': [[0, 'Hotel Arena']],
#  'think': [[1.0, 'The Park Grand London Paddington']],
#  'bed didn': [[1.25, 'Hotel Arena']],
#  'month': [[0.125, 'K K Hotel George']],
#  'london eye': [[0.625, 'Apex Temple Court Hotel']],
#  'shut': [[0.25, 'Apex Temple Court Hotel']],
#  'twin bed': [[1.25, 'The Park Grand London Paddington']],
#  'mr francis': [[2.75, 'Apex Temple Court Hotel']],
#  'refrigerator': [[0, 'Hotel Arena']],
#  'lobby need attention': [[0, 'The Park Grand London Paddington']],
#  'training': [[0.625, 'Hotel Arena']],
#  'cell wifi': [[0, 'The Park Grand London Paddington']],
#  'tea making': [[3.25, 'Apex Temple Court Hotel']],
#  'night room temperature control': [[4.5, 'Apex Temple Court Hotel']],
#  'bother': [[0.25, 'The Principal London']],
#  'teapot': [[0.5, 'The Park Grand London Paddington']],
#  'their': [[4.125, 'Hotel Arena']],
#  'cleanliness': [[1.75, 'Apex Temple Court Hotel']],
#  'route': [[1.0, 'K K Hotel George'], [0, 'Hotel Arena']],
#  'trouble': [[3.125, 'K K Hotel George']],
#  'walkway': [[0, 'Apex Temple Court Hotel']],
#  'top': [[3.5, 'Hotel Arena'],
#   [0.625, 'Apex Temple Court Hotel'],
#   [0.375, 'The Park Grand London Paddington']],
#  'gym': [[2.25, 'K K Hotel George']],
#  'disruption': [[0.875, 'Hotel Arena']],
#  'water problem': [[0, 'Hotel Arena']],
#  'upon arrival': [[1.75, 'Apex Temple Court Hotel']],
#  'restaurant neither': [[0, 'Apex Temple Court Hotel']],
#  'public': [[0.25, 'Hotel Arena']],
#  'quality breakfast food': [[1.875, 'K K Hotel George']],
#  'sink': [[0.875, 'The Principal London'], [0, 'Apex Temple Court Hotel']],
#  'downside': [[0.5, 'The Principal London']],
#  'tidy': [[1.75, 'Apex Temple Court Hotel']],
#  'front desk staff': [[1.5, 'K K Hotel George'], [0, 'The Principal London']],
#  'audio recording': [[0.75, 'Hotel Arena']],
#  'beer': [[2.375, 'K K Hotel George'], [0.875, 'Apex Temple Court Hotel']],
#  'russell': [[0.375, 'The Principal London']],
#  'weekend': [[2.875, 'Apex Temple Court Hotel']],
#  'garden': [[6.125, 'K K Hotel George']],
#  'room location': [[0, 'K K Hotel George']],
#  'area character': [[4.125, 'The Principal London']],
#  'room bill': [[4.25, 'The Principal London']],
#  'earls court': [[3.0, 'K K Hotel George']],
#  'wi': [[0.375, 'The Park Grand London Paddington']],
#  'explanation': [[0.75, 'K K Hotel George']],
#  'hotel russell station': [[2.25, 'The Principal London']],
#  'remodeling': [[0, 'Hotel Arena']],
#  'world charm modem': [[2.625, 'The Principal London']],
#  'drink': [[0.5, 'K K Hotel George'],
#   [0, 'The Principal London'],
#   [0, 'The Park Grand London Paddington']],
#  'progress': [[0, 'The Principal London']],
#  'cleaner': [[2.0, 'The Park Grand London Paddington'],
#   [1.375, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'stairway': [[0, 'The Principal London']],
#  'room pillows': [[1.0, 'K K Hotel George']],
#  'map': [[0, 'The Park Grand London Paddington']],
#  'room service food': [[2.875, 'Apex Temple Court Hotel']],
#  'ground floor room l01': [[0, 'K K Hotel George']],
#  'tv didn t work': [[0, 'The Park Grand London Paddington']],
#  'payment': [[2.875, 'Hotel Arena']],
#  'breakfast room': [[3.5, 'Apex Temple Court Hotel']],
#  'neighbourhood': [[0.75, 'K K Hotel George']],
#  'dirty': [[4.875, 'Hotel Arena']],
#  'leanne': [[1.375, 'K K Hotel George']],
#  'seal': [[0, 'Apex Temple Court Hotel']],
#  'cold': [[0.75, 'Apex Temple Court Hotel']],
#  'property': [[2.125, 'Hotel Arena'], [1.25, 'K K Hotel George']],
#  'bay': [[0.125, 'The Principal London']],
#  'handful': [[0.125, 'The Park Grand London Paddington']],
#  'freezing cold': [[3.25, 'The Park Grand London Paddington']],
#  'london older facility': [[3.75, 'K K Hotel George']],
#  'enjoyed room service': [[1.5, 'The Principal London']],
#  'slab third night': [[3.375, 'Apex Temple Court Hotel']],
#  'evening': [[0.625, 'K K Hotel George'],
#   [0.5, 'The Park Grand London Paddington'],
#   [0, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'kinky amsterdam window': [[2.25, 'Hotel Arena']],
#  'really': [[1.375, 'Apex Temple Court Hotel']],
#  'note': [[4.5, 'Apex Temple Court Hotel'], [0, 'The Principal London']],
#  'function': [[0, 'The Principal London']],
#  'speed': [[1.375, 'Hotel Arena']],
#  'hotel very': [[5.375, 'K K Hotel George']],
#  'fact': [[3.0, 'The Principal London'],
#   [3.0, 'Apex Temple Court Hotel'],
#   [0.375, 'K K Hotel George'],
#   [0.375, 'Hotel Arena']],
#  'th': [[1.25, 'K K Hotel George']],
#  'chain': [[1.25, 'The Park Grand London Paddington']],
#  'faulty water': [[2.25, 'The Principal London']],
#  'fast': [[0, 'K K Hotel George']],
#  'bottle': [[0.75, 'The Principal London']],
#  'suburb': [[1.625, 'The Park Grand London Paddington']],
#  'ranging': [[0.25, 'K K Hotel George']],
#  'caf s': [[2.5, 'The Principal London']],
#  'hair dryer didn t work': [[3.75, 'K K Hotel George']],
#  'hilton bankside': [[0, 'K K Hotel George']],
#  'tasty': [[1.625, 'The Park Grand London Paddington']],
#  'great location room': [[4.125, 'Apex Temple Court Hotel']],
#  'hong kong': [[2.75, 'The Principal London']],
#  'distance': [[3.375, 'The Principal London'],
#   [3.375, 'Apex Temple Court Hotel'],
#   [3.0, 'The Park Grand London Paddington'],
#   [1.125, 'K K Hotel George'],
#   [0.5, 'Hotel Arena']],
#  'breakfast system': [[4.25, 'Apex Temple Court Hotel']],
#  'spite': [[2.125, 'K K Hotel George']],
#  'bath': [[8.0, 'Apex Temple Court Hotel'],
#   [2.75, 'The Principal London'],
#   [2.125, 'K K Hotel George'],
#   [1.375, 'Hotel Arena']],
#  'impression': [[0, 'The Park Grand London Paddington']],
#  'star': [[0.125, 'The Park Grand London Paddington']],
#  'comfort': [[1.5, 'The Principal London']],
#  'beds': [[3.125, 'K K Hotel George'], [3.0, 'Apex Temple Court Hotel']],
#  'reflection': [[0, 'The Principal London']],
#  'english breakfast': [[3.25, 'The Park Grand London Paddington']],
#  'sunday': [[0, 'Apex Temple Court Hotel']],
#  'discount': [[0, 'Apex Temple Court Hotel']],
#  'wth': [[1.75, 'Apex Temple Court Hotel']],
#  'neck': [[0, 'K K Hotel George']],
#  'mother': [[0.625, 'The Park Grand London Paddington']],
#  'dresser': [[0.625, 'The Principal London']],
#  'place great park': [[2.625, 'Hotel Arena']],
#  'st pancras fairly': [[1.0, 'Apex Temple Court Hotel']],
#  'serving': [[0.625, 'K K Hotel George']],
#  'shard half hour walk': [[0, 'Apex Temple Court Hotel']],
#  'everything': [[5.75, 'Apex Temple Court Hotel'],
#   [0.75, 'Hotel Arena'],
#   [0.625, 'The Park Grand London Paddington'],
#   [0.5, 'The Principal London']],
#  'laundrette': [[0.5, 'K K Hotel George']],
#  'com price': [[0, 'Hotel Arena']],
#  'drinking water': [[2.625, 'K K Hotel George']],
#  'pricing': [[0.25, 'Hotel Arena']],
#  'section': [[0.5, 'Apex Temple Court Hotel']],
#  'road nice': [[4.0, 'K K Hotel George']],
#  'min walk': [[0, 'K K Hotel George']],
#  'wheelchair': [[0, 'Apex Temple Court Hotel']],
#  'construction work': [[0, 'Hotel Arena']],
#  'hotel didn': [[0, 'The Park Grand London Paddington']],
#  'system outage': [[1.5, 'Apex Temple Court Hotel']],
#  'aside': [[2.875, 'Hotel Arena']],
#  ...}

# %%
# Store the hotel data
outfile = open("Stored Data/sample_hotel_info.pickle", "wb")
pk.dump(hotel_info, outfile)
outfile.close()

# Store the aspect data
outfile = open("Stored Data/sample_aspect_info.pickle", "wb")
pk.dump(aspects_info, outfile)
outfile.close()
