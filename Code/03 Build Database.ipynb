# %%
# Import Libraries
import pandas as pd
import pickle as pk
import numpy as np
from collections import defaultdict
import time

# %%
# Import processed sample data from folder
infile = open("Stored Data/sample_review_w_aspects.pickle", "rb")
data = pk.load(infile)
infile.close()

data.head(3)
# Out:
#          Hotel                                            Reviews  \
# 0  Hotel Arena   Only the park outside of the hotel was beauti...
# 1  Hotel Arena   No real complaints the hotel was great great ...
# 2  Hotel Arena   Location was good and staff were ok It is cut...
#
#                                     Aspect_Sentiment
# 0                                {'park': [0.75, 0]}
# 1  {'spot': [0.375, 0], 'check': [0.875, -0.5], '...
# 2  {'hotel': [0.5, 0], 'staff': [0.5, 0], 'locati...

# %%
# Merges two dictionary into one, combines the values of its corresponding keys
def merge_dictionies(dict1, dict2):

    dict_merge = defaultdict(list)

    for d in (dict1, dict2):
        for key, value in d.items():
            dict_merge.setdefault(key, [0,0])
            dict_merge[key][0] += value[0]
            dict_merge[key][1] += value[1]
    
    return dict_merge

# merge_dictionies({"a":[5,4]},{"a":[5,4]})

# %%
# Convert pandas DataFrame to python List
array = sorted(data.values.tolist())

# Get all the hotel(unique) names
hotels = data['Hotel'].tolist()
hotels = np.unique(hotels)

hotels
# Out:
# array(['Apex Temple Court Hotel', 'Hotel Arena', 'K K Hotel George',
#        'The Park Grand London Paddington', 'The Principal London'],
#       dtype='<U32')

# %%
def unify_hotels(hotels, cluster_data):
    count = 0
    hotel_single = []
    for hotel in hotels:
        
        dict1 = {}
        while hotel == cluster_data[count][0]:
            dict1 = merge_dictionies(dict1, cluster_data[count][2])
            if count == len(cluster_data)-1:
                break
            else:
                count += 1
            
        hotel_single.append([cluster_data[count-1][0], dict1, count])
        dict1 = {}
        
    return hotel_single

hotel_info = unify_hotels(hotels, array)
hotel_info
# Out:
# [['Apex Temple Court Hotel',
#   defaultdict(list,
#               {'access': [0, 0],
#                'acknowledgement': [0, -0.625],
#                'adapter': [0, -0.625],
#                'advance': [1.0, -0.625],
#                'afternoon': [0, 0],
#                'age': [1.875, -0.875],
#                'air': [1.125, -0.125],
#                'aldwych theatre': [0, 0],
#                'alex hotel': [0, 0],
#                'ambience': [0.5, -0.5],
#                'anything': [0, 0],
#                'apex': [3.625, 0],
#                'apex duck would': [0, 0],
#                'apex hotel': [1.75, 0],
#                'area': [3.5, -0.25],
#                'atmosphere': [1.0, -2.0],
#                'aways': [0, -0.25],
#                'backdrop': [1.25, 0],
#                'bacon': [1.0, -1.5],
#                'badge': [0, 0],
#                'balcony': [0.5, -1.5],
#                'band': [0.5, 0],
#                'bar': [0.125, -2.625],
#                'bar area': [1.0, 0],
#                'bar room': [2.5, -0.25],
#                'bar space': [1.0, 0],
#                'bar super': [1.0, 0],
#                'bath': [7.0, -5.0],
#                'bath quiet': [0.5, 0],
#                'bath tub': [1.0, 0],
#                'bathroom': [10.5, -4.125],
#                'bathroom excellent really': [0, -2.625],
#                'bathroom mirror': [1.0, 0],
#                'bed': [6.25, -7.375],
#                'bedroom': [0.25, -0.625],
#                'beer': [0, 0],
#                'being': [0, 0],
#                'birthday': [0, -0.25],
#                'bit': [0.625, -0.25],
#                'board': [0.375, -0.75],
#                'board iron': [0.75, 0],
#                'boat': [0, -0.625],
#                'bonus': [0.875, 0],
#                'booking': [0, 0],
#                'bose sound system': [3.375, -1.875],
#                'bose speaker': [0, 0],
#                'bottle opener': [3.75, -1.75],
#                'box': [1.375, -0.25],
#                'boyfriend': [0.875, 0],
#                'breakfast': [7.375, -7.875],
#                'breakfast buffet continental': [0, 0],
#                'breakfast room': [0, -0.75],
#                'breakfast system': [3.125, -1.5],
#                'britain': [0.5, -0.625],
#                'buffet': [0, -0.25],
#                'business': [1.0, -1.125],
#                'cable jack': [1.25, -0.5],
#                'car': [0, 0],
#                'card': [0.875, 0],
#                'carpet': [1.875, -0.875],
#                'center': [0, -0.25],
#                'centre': [1.125, -0.125],
#                'change': [0, 0],
#                'charge': [0, -0.625],
#                'check': [0.875, -0.75],
#                'choc': [0.375, 0],
#                'chocolate': [0.25, -0.625],
#                'city': [1.25, -0.625],
#                'city river': [0, 0],
#                'cleaner': [0, 0],
#                'cleanliness': [0.5, -0.5],
#                'close': [1.125, -0.125],
#                'club lounge': [1.375, -1.5],
#                'coffee': [0.875, -0.625],
#                'coffee machine': [0.5, -1.25],
#                'coffee milk': [0, 0],
#                'colleague': [0, -0.5],
#                'com': [1.0, -1.5],
#                'com cost': [0, 0],
#                'comfy': [1.625, -1.125],
#                'conceierge service': [2.75, 0],
#                'concession': [0, 0],
#                'concierge': [0, 0],
#                'connection': [0.75, 0],
#                'consisting': [1.0, -1.5],
#                'continental breakfast': [3.125, -2.125],
#                'convenient': [1.125, -0.125],
#                'cool': [0, 0],
#                'corner': [0, 0],
#                'corridor': [1.75, -1.0],
#                'couple': [1.0, -2.75],
#                'course': [0.125, 0],
#                'court': [1.5, 0],
#                'courtyard terrace': [2.5, 0],
#                'covent garden': [0, -1.25],
#                'covent garden soho': [0, 0],
#                'cozy bath': [1.25, 0],
#                'cute': [3.375, -0.75],
#                'day': [0, -0.5],
#                'decoration': [1.25, 0],
#                'design': [0, 0],
#                'design flaw': [0.25, 0],
#                'desk': [0, 0],
#                'difficult': [0, -0.75],
#                'discount': [0, 0],
#                'discreet': [0, -0.875],
#                'distance': [2.5, 0],
#                'distance temple area': [2.25, 0],
#                'district': [0, -0.625],
#                'door': [0, 0],
#                'doorway': [0.875, -1.0],
#                'duck': [0.125, -0.25],
#                'duty': [0, -0.5],
#                'easy': [0.875, -0.75],
#                'edge': [0, 0],
#                'elephant': [0.875, -1.0],
#                'email': [0, 0],
#                'end': [1.25, -0.375],
#                'end room': [1.5, -1.25],
#                'entrance': [2.125, -1.25],
#                'eu': [1.875, -0.875],
#                'everyone': [0.625, -0.25],
#                'everything': [2.875, -0.25],
#                'excellent': [1.0, 0],
#                'expense': [0.5, 0],
#                'extra': [0.375, -0.75],
#                'extras': [0, 0],
#                'face': [0, 0],
#                'fact': [1.0, -1.125],
#                'family': [0.625, -0.875],
#                'fan': [0, -1.25],
#                'fault': [0, -0.625],
#                'fi': [0, -0.625],
#                'food': [3.625, -3.125],
#                'food menu': [1.75, -3.0],
#                'francis': [0, -0.5],
#                'friday': [0, 0],
#                'front entrance': [2.5, -0.5],
#                'fruit': [0, 0],
#                'fussy': [0, 0],
#                'glad': [0, 0],
#                'gorgeous': [1.125, 0],
#                'great location': [1.75, -1.5],
#                'great location room': [4.125, -2.25],
#                'guest svc manager francesco': [9.5, -3.0],
#                'had': [0, 0],
#                'hair': [1.0, -1.5],
#                'half': [0, 0],
#                'hallway': [1.0, -1.5],
#                'hallway wall': [3.75, -1.75],
#                'happening': [0, -0.625],
#                'hassle': [0.625, 0],
#                'heart': [0.625, 0],
#                'home': [2.5, -1.25],
#                'hotel': [24.75, -9.125],
#                'hotel bar': [4.5, 0],
#                'hotel room stank': [1.0, -4.25],
#                'hotel wifi': [0, 0],
#                'hotel yesterday': [0, 0],
#                'husband': [0.125, -0.625],
#                'i': [1.375, -2.125],
#                'idea': [0, -0.25],
#                'info': [0.875, -1.0],
#                'innercourt': [0.875, -0.625],
#                'inside': [0.875, 0],
#                'invitation': [0, -0.875],
#                'invoice': [0, 0],
#                'iphone': [0, -0.625],
#                'issue': [0, 0],
#                'jack': [0.25, -0.25],
#                'job': [0.75, -0.25],
#                'jug': [0, -0.25],
#                'junior suite': [0, 0],
#                'kind': [1.375, 0],
#                'location': [9.25, -2.25],
#                'location right': [2.5, -0.375],
#                'london': [2.375, -1.0],
#                'london eye': [0, 0],
#                'look': [0.875, -1.0],
#                'lot': [1.625, -2.0],
#                'lot staff': [3.25, -0.5],
#                'lounge': [0.625, 0],
#                'luca': [0.5, 0],
#                'machine': [0, 0],
#                'menu': [1.125, -0.625],
#                'mile': [0.5, 0],
#                'mine': [0.875, -0.875],
#                'minimalistic': [2.5, -1.0],
#                'mobility': [0, 0],
#                'money': [0, -1.25],
#                'mr': [0, 0],
#                'music': [0.25, -0.25],
#                'need': [0, -0.5],
#                'nice': [0, 0],
#                'nice bathroom': [0.5, 0],
#                'nice room': [0, 0],
#                'nice room modern': [0, 0],
#                'night': [3.5, -2.125],
#                'night room temperature control': [1.5, -5.75],
#                'none': [1.0, -2.25],
#                'notch quality': [0, -2.5],
#                'note': [1.0, -1.375],
#                'nothing': [0, 0],
#                'novello': [0, 0],
#                'office': [2.5, -1.0],
#                'office window': [0, -0.75],
#                'one': [0.5, -0.625],
#                'one office chair': [8.5, -3.0],
#                'order': [0.125, 0],
#                'packet': [0, -0.625],
#                'parking': [1.0, 0],
#                'part': [0, 0],
#                'party': [0.5, -0.625],
#                'permission': [0, 0],
#                'person': [0.5, 0],
#                'phone': [0.125, -2.0],
#                'place': [1.0, 0],
#                'place closer': [1.0, 0],
#                'plan': [0, -0.625],
#                'plane': [0, 0],
#                'possibility': [2.5, -1.0],
#                'presentation': [0, 0],
#                'price': [1.125, -0.875],
#                'privacy location temple': [1.5, -0.375],
#                'problem': [1.25, -0.375],
#                'proof': [1.125, 0],
#                'pudding': [1.0, -1.5],
#                'quality': [0.5, 0],
#                'question': [0.375, 0],
#                'reason': [0, 0],
#                'reception': [1.875, -0.5],
#                'reception greeting': [1.0, 0],
#                'reduction coupon': [3.25, -0.5],
#                'reference': [0, 0],
#                'relaxing soak': [2.75, -2.75],
#                'reservation': [0.625, 0],
#                'restaurant': [0.5, 0],
#                'restaurant food': [0, -3.75],
#                'restaurant neither': [0, 0],
#                'river': [0, 0],
#                'road': [0, 0],
#                'room': [15.25, -15.625],
#                'room balcony': [1.0, -2.0],
#                'room bed': [4.75, -1.5],
#                'room being': [0, -1.0],
#                'room broken': [3.75, -1.75],
#                'room everything': [0.625, -0.5],
#                'room hidden courtyard view': [5.0, 0],
#                'room hotel': [1.0, -2.75],
#                'room key': [1.25, -2.75],
#                'room nothing': [5.0, -2.0],
#                'room price': [0, -0.5],
#                'room service': [1.0, -3.0],
#                'room service food': [3.375, -0.25],
#                'rubber duck': [0, 0],
#                'sausage': [1.0, -1.5],
#                'seal': [1.0, -1.5],
#                'seating': [0.5, 0],
#                'section': [0, -0.625],
#                'selection': [1.0, -1.5],
#                'service': [0, -1.25],
#                'shard half hour walk': [0, -0.5],
#                'show': [0, -0.75],
#                'shower': [5.125, -4.0],
#                'shower cabin': [1.25, 0],
#                'shower door': [2.0, -3.0],
#                'shut': [0.25, -0.625],
#                'side': [1.125, -1.375],
#                'sight': [0, 0],
#                'sink': [1.0, -1.5],
#                'site': [0, 0],
#                'size': [1.875, -0.75],
#                'sized bathroom': [4.75, -1.5],
#                'sky': [0, 0],
#                'slab': [0, 0],
#                'sleep': [1.25, -0.375],
#                'soft': [0, -0.25],
#                'soho oxford st': [0, -1.0],
#                'son': [0, -0.5],
#                'soulless': [0, 0],
#                'spaciousness': [1.5, 0],
#                'spent': [0, 0],
#                'spoonful': [1.0, -1.5],
#                'st pancras fairly': [0.5, -2.25],
#                'st paul': [0, -0.75],
#                'staff': [11.875, -4.0],
#                'staff walking': [1.0, -1.25],
#                'standard': [2.0, -0.75],
#                'standard hotel': [0, -2.5],
#                'standard room': [2.25, 0],
#                'start': [0, -0.25],
#                'stay': [1.0, 0],
#                'street': [0, 0],
#                'student': [0, 0],
#                'stuff': [0.875, 0],
#                'subway station customers': [2.625, -3.0],
#                'sue': [1.0, -1.5],
#                'suite': [0.875, 0],
#                'summer': [1.75, 0],
#                'sunday': [0, 0],
#                'supplement': [0, 0],
#                'system outage': [2.75, 0],
#                'table': [0, 0],
#                'tate modern': [0, 0],
#                'taxi': [0, -0.625],
#                'tea': [0, 0],
#                'tea making': [1.0, 0],
#                'temple': [0.5, -0.375],
#                'thank': [0, 0],
#                'theater district': [0, 0],
#                'theatre district': [0, 0],
#                'thing': [1.625, -0.875],
#                'thursday': [0, 0],
#                'tidy': [0, -0.375],
#                'time': [0, -1.0],
#                'toilet': [0.625, 0],
#                'toilet bowl': [1.125, 0],
#                'toilet seat': [0.75, 0],
#                'tomato': [1.0, -1.5],
#                'tooth': [0, -0.625],
#                'top': [0.5, 0],
#                'trafalgar square': [0, -0.25],
#                'traffic noise': [1.0, -0.5],
#                'transport blackfriars tube station': [0, 0],
#                'tray charge': [2.0, -4.5],
#                'trip': [0, -0.625],
#                'tube': [0, 0],
#                'tube room': [2.25, 0],
#                'tv': [1.375, -2.25],
#                'underground': [1.875, 0],
#                'understand': [0, 0],
#                'upgrade': [1.375, -0.375],
#                'upon arrival': [3.25, -0.5],
#                'value': [1.125, -1.0],
#                'variety': [0.25, -0.875],
#                'ventilation': [0, -1.625],
#                'very': [0.75, -1.125],
#                'vibe': [2.125, -0.25],
#                'view': [0.875, -2.125],
#                'voucher': [0.5, -0.625],
#                'walk': [0, -0.875],
#                'walkway': [0, 0],
#                'wardrobe space': [1.0, 0],
#                'water': [0.5, 0],
#                'water soda wine': [0, 0],
#                'way': [2.5, -1.0],
#                'weather': [1.25, -0.25],
#                'wednesday': [0, 0],
#                'week': [1.0, -1.125],
#                'weekend': [2.875, 0],
#                'westminster': [0, -0.625],
#                'westminster room': [1.5, -2.25],
#                'wheelchair': [0, 0],
#                'whenever': [1.625, -0.25],
#                'wi': [0, 0],
#                'wth': [0.5, 0],
#                'you': [0, 0]}),
#   109],
#  ['Hotel Arena',
#   defaultdict(list,
#               {'a. saturday night': [0, -1.875],
#                'a. slam': [1.25, -0.5],
#                'access': [1.875, 0],
#                'advance': [0, -1.25],
#                'advertising': [0.875, -0.75],
#                'affair': [0.375, -0.625],
#                'aircondition': [0, -0.75],
#                'airconditioning': [0, -0.75],
#                'airport': [0.875, -1.25],
#                'airy': [0, 0],
#                'am': [0.25, 0],
#                'amount': [0.375, -0.625],
#                'amsterdam': [1.625, -2.125],
#                'amsterdam room': [2.0, -1.5],
#                'amsterdam would': [1.0, -2.0],
#                'annoying': [0, 0],
#                'answer': [0, 0],
#                'anyone': [1.625, -0.875],
#                'anything': [0.875, 0],
#                'anything door': [1.0, -2.5],
#                'appreciation': [0.375, 0],
#                'architecture': [0.75, 0],
#                'area': [1.75, -1.75],
#                'area shower': [0.5, -1.25],
#                'arrival': [0, -0.375],
#                'arrive': [0.625, 0],
#                'asleep': [0, -1.375],
#                'attention': [1.5, 0],
#                'audio recording': [0.75, -1.25],
#                'awesome park': [2.625, -1.625],
#                'axcess': [0, 0],
#                'background': [1.625, -0.875],
#                'backyard': [0, 0],
#                'bacon': [0, -0.5],
#                'bakery': [0, 0],
#                'banging': [0.5, -1.5],
#                'bank': [0.375, -0.625],
#                'bar': [2.0, -1.875],
#                'bar area': [6.75, -1.5],
#                'bar restaurant area': [4.125, 0],
#                'bar staff': [0, -2.5],
#                'barefoot': [0, -2.125],
#                'bath': [0.5, 0],
#                'bath tub': [0, 0],
#                'bathroom': [3.125, -6.375],
#                'bathroom lighting': [0.25, 0],
#                'bathroom smelt': [0.5, 0],
#                'bathtub': [0, 0],
#                'beautiful': [0, 0],
#                'beauty': [0.875, 0],
#                'bed': [9.5, -5.0],
#                'bedroom': [0.875, -0.875],
#                'bid': [0.5, -2.125],
#                'bike': [0, -0.25],
#                'bio weapon': [0, -1.25],
#                'birthday present': [0.75, 0],
#                'bit': [3.125, -4.875],
#                'bobby gin': [0, -0.5],
#                'boiler': [1.625, 0],
#                'book': [0.875, -0.75],
#                'booking process': [0, -1.25],
#                'break': [2.25, -1.75],
#                'breakfast': [6.875, -8.625],
#                'breakfast check': [0.75, -2.625],
#                'breakfast food': [3.5, 0],
#                'breakfast selection': [0.25, 0],
#                'breakfast spread perfect': [0.75, 0],
#                'breakfast staff': [0.75, -2.625],
#                'brit': [0, 0],
#                'broken window': [1.25, -1.25],
#                'brunch': [0.5, 0],
#                'btw': [0.625, 0],
#                'buffet': [0.5, 0],
#                'building': [8.75, -4.625],
#                'building meeting': [0, 0],
#                'building park location': [0, 0],
#                'building work': [4.75, -3.375],
#                'business': [0.5, 0],
#                'ca': [0.625, -0.625],
#                'cafe': [0, 0],
#                'cappuccino room': [1.5, -0.875],
#                'card': [0.375, -0.625],
#                'care': [1.875, 0],
#                'cause': [0.5, -0.75],
#                'ceiling': [1.0, 0],
#                'celcius': [0, -0.75],
#                'center': [0, 0],
#                'center train': [2.5, 0],
#                'centre': [1.25, -1.625],
#                'chair': [0.25, -1.0],
#                'chair room service hair dryer fridge kettle': [4.625, -0.75],
#                'change': [0, 0],
#                'chapel': [0.625, 0],
#                'check': [1.0, -4.625],
#                'chill': [1.375, 0],
#                'city': [4.5, -2.625],
#                'city center': [0.125, -0.625],
#                'city centre': [6.25, -3.5],
#                'city tax': [0, 0],
#                'clean': [3.375, -0.75],
#                'cleaner': [1.375, -0.625],
#                'cleaning': [1.125, -4.25],
#                'cleaning lady': [0.625, -2.125],
#                'clock': [0, -0.875],
#                'coffee': [3.25, -0.125],
#                'cold': [0.5, -0.125],
#                'com': [0, -0.625],
#                'com price': [0, 0],
#                'comfy': [0.75, 0],
#                'company': [0, 0],
#                'complain': [0, -0.5],
#                'connoisseur': [0, 0],
#                'construction': [0, -3.625],
#                'construction renovation': [0, -1.25],
#                'construction work': [0, -2.5],
#                'consumer': [0.375, 0],
#                'continental breakfast selection quiet': [2.0, 0],
#                'convenience': [0.625, 0],
#                'corridor': [0.5, -1.5],
#                'couple': [0.25, -0.625],
#                'course': [0, 0],
#                'courtyard': [0.375, 0],
#                'curtain': [0, 0],
#                'dam square': [0.75, 0],
#                'damp': [0.25, -0.625],
#                'day': [6.0, -3.25],
#                'deal': [0.625, -0.625],
#                'debris': [0.375, 0],
#                'deposit': [0.875, -0.5],
#                'design': [2.25, 0],
#                'design disaster': [1.5, -5.75],
#                'desk chairs': [0, -1.0],
#                'destination': [0, -0.25],
#                'difficulty': [0, 0],
#                'dining': [0, 0],
#                'dinner bar': [0, 0],
#                'direction': [0, -0.75],
#                'dirt': [1.375, -4.375],
#                'dirty': [1.375, -5.875],
#                'disaster room': [2.375, -8.0],
#                'disruption': [0.875, 0],
#                'distance': [0.5, -1.0],
#                'dog': [0, -2.125],
#                'door': [0.5, -2.75],
#                'double bed': [1.75, -1.75],
#                'dust': [0.5, -2.125],
#                'duvet': [0.75, -0.625],
#                'element': [0.5, 0],
#                'entrance': [0.375, 0],
#                'euros': [0.375, -0.75],
#                'evening': [1.75, -0.5],
#                'everyone': [0.625, -0.5],
#                'everything': [0.75, -1.25],
#                'existent': [0, 0],
#                'extra': [0, 0],
#                'eye contact': [1.25, 0],
#                'fact': [0.375, -1.25],
#                'fault': [0.5, -1.125],
#                'feeling': [0, 0],
#                'first': [0, -0.625],
#                'first room': [4.0, -2.375],
#                'floor': [2.75, -4.0],
#                'floor corridor': [1.625, -1.25],
#                'food': [1.0, -1.0],
#                'forget': [0, 0],
#                'fridge': [0.5, -0.625],
#                'front': [0, -0.25],
#                'front desk': [2.5, 0],
#                'garage door': [0, 0],
#                'garden view': [1.75, 0],
#                'gentleman': [0.625, -0.625],
#                'glass bathroom': [1.25, -1.25],
#                'glass box': [0.875, -2.0],
#                'glass wall': [0, -0.125],
#                'glass window': [0, -1.5],
#                'great': [0.5, 0],
#                'great hotel': [0, 0],
#                'great location': [0.75, 0],
#                'greenery': [0, -0.75],
#                'guess': [0.5, -1.125],
#                'guest': [0.625, -0.625],
#                'gutter': [0.5, -2.125],
#                'hair': [0, 0],
#                'hair dryer': [1.25, 0],
#                'half': [0.375, 0],
#                'hall': [0, -1.0],
#                'hallway': [0, -0.625],
#                'hand': [0.25, -0.75],
#                'handrail': [0.5, -0.75],
#                'head': [0.5, 0],
#                'health food': [1.0, 0],
#                'hell': [0, -1.125],
#                'help': [2.75, -0.75],
#                'history': [0.75, 0],
#                'hold church': [0, -0.5],
#                'holiday': [0.875, -1.25],
#                'hospital': [0, 0],
#                'hot': [0.625, -2.5],
#                'hotel': [27.75, -12.5],
#                'hotel all': [3.25, -0.875],
#                'hotel bar': [0, -1.25],
#                'hotel dirty dusty': [0.875, -2.25],
#                'hotel inside': [4.375, -2.25],
#                'hotel manager': [2.25, -0.25],
#                'hotel restaurant': [1.375, -1.25],
#                'hotel room': [1.25, -2.5],
#                'hour': [0.625, 0],
#                'i': [9.625, -10.875],
#                'idea': [0.75, -0.125],
#                'information': [0, 0],
#                'inside': [0.625, -0.25],
#                'interest': [0, -0.5],
#                'issue': [0.875, -1.25],
#                'juice': [0.625, -0.375],
#                'july': [0, 0],
#                'key everyday': [0, 0],
#                'kinky amsterdam window': [1.125, 0],
#                'lay': [0.625, -0.25],
#                'level': [1.375, 0],
#                'light': [0, -1.0],
#                'lighting': [0.5, -2.125],
#                'line': [0, 0],
#                'little privacy': [0, -2.0],
#                'lobby': [0.375, 0],
#                'location': [8.875, -2.75],
#                'london': [0.125, 0],
#                'lot': [0.75, -2.625],
#                'love': [0, 0],
#                'luggage': [0, 0],
#                'mail': [0.375, -0.625],
#                'manager': [0, 0],
#                'mattress': [0.75, -0.75],
#                'meal': [0, 0],
#                'meant': [0, 0],
#                'mess': [0, 0],
#                'meter': [0.5, -0.125],
#                'metro close': [1.75, 0],
#                'middle': [1.0, -0.5],
#                'midnight': [2.0, -0.625],
#                'mile': [0.875, 0],
#                'mini fridge': [0, -1.25],
#                'minute walk': [1.0, -2.0],
#                'mirror': [0.5, -2.5],
#                'mistake': [0.375, 0],
#                'mix': [0, -0.5],
#                'moment': [0, -0.75],
#                'monastery building': [1.5, 0],
#                'money': [0.375, 0],
#                'mood': [0.75, 0],
#                'morning': [1.75, -0.625],
#                'morning water': [0.25, -2.5],
#                'nail': [0.375, 0],
#                'neck room service': [1.5, -3.75],
#                'need': [2.375, 0],
#                'negligence': [0, 0],
#                'nice restaurant': [1.375, -1.0],
#                'night': [3.0, -0.5],
#                'night guard': [0, 0],
#                'night room': [2.0, -1.5],
#                'night shift manager': [5.0, 0],
#                'noise': [1.125, -1.25],
#                'nothing': [0, -0.625],
#                'novelty': [0.875, 0],
#                'occurrence': [1.375, -0.625],
#                'offer': [0.625, -0.5],
#                'one': [1.875, -1.375],
#                'online': [0, 0],
#                'oosterpark': [0.75, 0],
#                'oostpark': [0, 0],
#                'opinion': [2.5, -0.625],
#                'option': [1.625, -0.875],
#                'order': [1.125, 0],
#                'order shower': [1.25, -1.0],
#                'orphanage': [0, 0],
#                'oth': [0, 0],
#                'outside': [0.625, -0.25],
#                'ownership': [0, 0],
#                'pad': [0.25, -1.0],
#                'pain': [0, -0.25],
#                'park': [12.375, -3.375],
#                'park cool': [0, 0],
#                'park room': [6.75, -1.5],
#                'parking place': [0, 0],
#                'part': [0, 0],
#                'party': [0.625, 0],
#                'payment': [0.875, -0.5],
#                'perfect': [0, -1.25],
#                'perfect launch pad': [0.25, 0],
#                'phone': [0.375, -1.375],
#                'photos': [0.625, 0],
#                'pillows super stiff': [1.5, -3.75],
#                'place': [3.125, -0.25],
#                'place great park': [4.125, 0],
#                'plaster': [0.25, -0.625],
#                'please': [0.25, 0],
#                'point': [0.375, -0.625],
#                'pointless': [0.375, -0.625],
#                'pond': [0.25, -0.375],
#                'pop': [0.375, -0.625],
#                'post': [0.375, 0],
#                'practice': [0, -1.0],
#                'price': [1.125, -0.625],
#                'pricing': [0.25, 0],
#                'problem': [0.5, -1.125],
#                'product': [0.125, 0],
#                'property': [0, -0.25],
#                'proud': [1.125, -0.25],
#                'public': [0.25, 0],
#                'quality': [1.375, 0],
#                'quality food': [3.25, -1.75],
#                'question': [0.625, 0],
#                'rain': [0, -0.625],
#                'rainfall': [1.375, -0.625],
#                'reason': [0.625, 0],
#                'reception': [0.375, -2.0],
#                'reception area': [2.0, -3.25],
#                'receptionist': [0, 0],
#                'refrigerator': [0, -0.625],
#                'relaxing stay': [1.0, 0],
#                'remodeling': [0, 0],
#                'renovation': [0.875, 0],
#                'rent': [1.125, -0.25],
#                'repairman': [0.5, 0],
#                'request': [0, -0.625],
#                'restaurant': [9.0, -1.5],
#                'restaurant downstairs': [0.5, -0.75],
#                'restaurant menu': [1.0, -2.0],
#                'ride': [0.625, 0],
#                'right': [0.25, 0],
#                'roof': [1.375, -0.625],
#                'room': [25.375, -25.375],
#                'room decor': [0, -0.125],
#                'room decoration': [1.125, -1.125],
#                'room fridge': [0.5, -1.25],
#                'room i': [8.0, -7.625],
#                'room perfect hotel': [2.375, -1.125],
#                'route': [0, -0.25],
#                'scaffolding': [0, 0],
#                'search': [0, -0.75],
#                'selection': [0.5, 0],
#                'service': [1.75, -0.875],
#                'service horrible': [0.5, -1.25],
#                'set': [1.25, 0],
#                'setting': [3.375, -0.75],
#                'shampoo body': [1.25, 0],
#                'shampoo shower gel dispenser': [0, -5.0],
#                'sheet': [0.75, -0.625],
#                'shower': [1.0, -2.25],
#                'shower drain': [0, -1.25],
#                'site': [0, -0.875],
#                'site restaurant': [3.25, -1.75],
#                'situation': [0, 0],
#                'slam': [0.625, -0.25],
#                'sleep': [1.125, 0],
#                'smell': [1.25, -4.625],
#                'soap': [0.875, 0],
#                'solution': [0, 0],
#                'someone': [1.25, 0],
#                'someone drilling concrete': [1.125, 0],
#                'something': [1.25, -1.75],
#                'sort': [0, -0.625],
#                'sound': [0.875, -0.75],
#                'space': [1.375, -2.75],
#                'spacious': [0.75, 0],
#                'speed': [0, 0],
#                'split level room': [1.875, -0.125],
#                'spot': [0.375, 0],
#                'staff': [19.875, -8.25],
#                'staff food': [1.0, 0],
#                'staff offer': [1.75, -1.0],
#                'staff shampoo': [1.75, 0],
#                'staircase': [1.5, -2.375],
#                'standard': [0.5, 0],
#                'start': [0.5, 0],
#                'state': [1.125, 0],
#                'station': [1.625, -0.75],
#                'stay': [1.5, -1.625],
#                'story': [0, -0.75],
#                'street': [0.5, 0],
#                'structure': [0.375, -0.25],
#                'stupid room': [0.5, 0],
#                'style': [0, 0],
#                'system': [0.25, 0],
#                'taste': [0.875, 0],
#                'taxi': [0, 0],
#                'tea': [0, -0.125],
#                'tea coffee': [0, 0],
#                'telephone huge price difference': [0, 0],
#                'temperature': [0.125, -1.25],
#                'tennis court': [0.5, -0.75],
#                'terrace': [0.25, -0.625],
#                'thermostat': [0, -0.625],
#                'thing': [0.5, 0],
#                'ticket': [1.0, 0],
#                'ticket machine': [1.0, 0],
#                'time': [2.0, 0],
#                'toilet': [1.375, -0.5],
#                'top': [1.875, -1.0],
#                'tour': [0, -0.25],
#                'tourist': [0.375, -1.0],
#                'tourist trap': [0.75, -1.25],
#                'town': [1.375, -0.375],
#                'training': [0.625, -0.625],
#                'tram': [2.125, -0.25],
#                'tram ride': [2.5, 0],
#                'tram stop': [1.0, -2.0],
#                'tram subway': [2.0, -1.5],
#                'tram system': [9.75, -1.5],
#                'transaction': [0.375, -0.625],
#                'transaction charge': [0.75, -1.25],
#                'transformer': [0.5, -1.125],
#                'transport': [0.625, 0],
#                'transportation': [2.75, -1.0],
#                'trash lorry': [0, -0.75],
#                'trip': [0.25, 0],
#                'tv': [0.375, -2.0],
#                'twice': [0, 0],
#                'twist staircase no': [1.5, -1.375],
#                'usb port': [0.75, -2.75],
#                'use': [0, -1.25],
#                'variety': [0.75, 0],
#                'view': [1.125, -2.25],
#                'villa suite': [1.75, -1.5],
#                'volume': [0.625, 0],
#                'waist': [1.125, 0],
#                'walk': [2.625, 0],
#                'walking': [0, 0],
#                'wall': [0, 0],
#                'wardrobe': [0.625, 0],
#                'was': [0.75, -3.25],
#                'was kind': [0.5, -0.75],
#                'water damage': [5.75, -1.25],
#                'water pressure': [0, 0],
#                'water problem': [0, 0],
#                'way': [3.625, -1.375],
#                'website': [0.25, 0],
#                'wedding': [0.625, 0],
#                'week': [0.625, -0.625],
#                'which': [0.875, -0.75],
#                'white furniture': [0, -4.25],
#                'whole': [0.25, -0.625],
#                'wife': [0.375, -1.375],
#                'wifi': [0.5, 0],
#                'window': [2.125, -1.25],
#                'window mechanism': [0.5, -1.25],
#                'wing': [0.375, -0.625],
#                'wonderful': [0.25, -0.75],
#                'wood': [0.25, 0],
#                'work': [0.875, -1.125],
#                'wrap': [1.625, -0.875]}),
#   218],
#  ['K K Hotel George',
#   defaultdict(list,
#               {'ac': [0.25, 0],
#                'access': [2.375, -0.5],
#                'air con': [0.5, 0],
#                'airport': [2.0, 0],
#                'ambience': [0, 0],
#                'amenity': [0, -1.875],
#                'area': [2.25, 0],
#                'area breakfast': [1.0, 0],
#                'area sauna': [2.5, -5.5],
#                'arrival': [0, -0.25],
#                'aspect fantastic location': [5.25, 0],
#                'assistance': [0, 0],
#                'attitude': [0.5, -0.625],
#                'awful': [0, 0],
#                'b': [1.0, -3.125],
#                'back': [0.75, -0.625],
#                'bacon': [0.375, 0],
#                'bakery': [0.5, 0],
#                'bar': [2.0, -0.25],
#                'bar area': [1.0, -1.5],
#                'basement room': [0.5, 0],
#                'bath': [1.125, -0.75],
#                'bath lethal combination': [0, -4.125],
#                'bath tub': [0, -2.75],
#                'bathroom': [5.625, -4.375],
#                'bathroom shower': [1.5, -1.25],
#                'bathroom sink': [4.75, -0.25],
#                'beat': [0, -0.625],
#                'beautiful': [1.5, 0],
#                'beautiful garden': [0, -1.25],
#                'bed': [3.25, -4.75],
#                'beer': [0.75, -0.125],
#                'beforehand': [0, 0],
#                'billowing': [1.0, 0],
#                'bit': [0.5, 0],
#                'block': [1.25, 0],
#                'boarding': [0, 0],
#                'bonus': [1.5, 0],
#                'book breakfast': [0.25, -2.5],
#                'breakfast': [14.875, -5.625],
#                'breakfast buffet': [0, 0],
#                'breakfast staff': [0.875, -1.875],
#                'breakfast table': [0.625, -3.75],
#                'buffet': [2.625, -0.125],
#                'business centre': [0, 0],
#                "but'o k i": [5.625, -9.5],
#                'ca': [1.375, -1.0],
#                'car': [1.625, -1.125],
#                'carpet': [0.25, -0.625],
#                'case': [0, 0],
#                'central london': [0, 0],
#                'chair': [0, -0.625],
#                'charge': [0.125, 0],
#                'check': [1.25, -3.375],
#                'choice': [2.375, -0.25],
#                'city': [0.5, -0.625],
#                'clean bathroom nice shower': [0.625, -2.25],
#                'cleanness': [1.125, -0.75],
#                'clineanliness': [1.0, 0],
#                'closeness': [0, 0],
#                'closet': [0.625, -0.75],
#                'coffee': [1.125, 0],
#                'com': [0, -1.0],
#                'comfy': [1.0, -0.125],
#                'comfy room': [0, 0],
#                'complaint': [0, -0.5],
#                'consideration': [0, -0.625],
#                'convenience': [0, 0],
#                'convenient': [0.5, 0],
#                'corner': [0.5, 0],
#                'cost': [1.125, -0.5],
#                'course': [0.375, -1.875],
#                'court': [1.625, -1.25],
#                'court paul': [1.25, 0],
#                'court station': [3.25, -1.25],
#                'cozy': [0, 0],
#                'credit card': [2.25, -0.75],
#                'cross contamination': [0, -1.5],
#                'cutlery': [0, 0],
#                'daughter': [0.625, -0.75],
#                'day': [3.75, -3.5],
#                'delight': [0.375, -0.25],
#                'deposit': [0, 0],
#                'did': [0, -0.125],
#                'diet': [0.5, -0.625],
#                'difference': [0.5, -0.625],
#                'difficult': [0, 0],
#                'disgust': [0, -0.625],
#                'distance': [1.125, 0],
#                'diverse breakfast': [1.0, -1.875],
#                'division': [1.25, 0],
#                'door': [0, 0],
#                'drink': [1.125, -0.5],
#                'drink etc': [1.5, 0],
#                'drinking water': [1.0, -0.75],
#                'earl': [3.875, -1.875],
#                'earl s. court tube': [5.0, 0],
#                'earl s. court tube station': [3.125, -2.5],
#                'earls court': [3.75, 0],
#                'earls court station': [1.875, 0],
#                'easy': [1.0, 0],
#                'end': [0, 0],
#                'english': [0.375, 0],
#                'english style': [1.5, -0.25],
#                'enough': [0.25, 0],
#                'equipment': [0, 0],
#                'erls court': [0, 0],
#                'espresso cappucino': [4.25, 0],
#                'evening': [0, 0],
#                'everyone': [0.5, 0],
#                'excellent': [2.125, -0.75],
#                'experience': [0.75, 0],
#                'explanation': [0, 0],
#                'fab': [1.625, 0],
#                'fab experience': [1.625, 0],
#                'fab fluffy': [2.0, -0.25],
#                'fact': [0.375, -1.875],
#                'family': [1.625, -0.875],
#                'fan': [1.25, 0],
#                'fault someone': [0, -0.5],
#                'firmer pillow': [3.0, -0.25],
#                'fitness area': [2.5, -5.5],
#                'fitness center': [2.25, -1.25],
#                'floor': [1.0, -0.75],
#                'food': [0.75, -0.25],
#                'food supermarket': [1.0, 0],
#                'friend': [0, 0],
#                'front': [1.0, 0],
#                'front desk': [0, 0],
#                'front desk staff': [1.5, -1.875],
#                'front desk staff would love': [1.875, -1.25],
#                'future': [1.25, -2.75],
#                'garden': [3.75, -1.625],
#                'generally': [0.75, 0],
#                'gentleman': [0.75, 0],
#                'glass': [0.75, -0.125],
#                'great choice': [3.0, -0.25],
#                'great location': [3.75, -1.0],
#                'great position': [2.0, 0],
#                'ground floor room l01': [0, -2.0],
#                'gym': [0.5, -1.375],
#                'hair': [0.75, 0],
#                'hair dryer': [1.5, 0],
#                'has': [0, 0],
#                'hdmi cable': [0, 0],
#                'heathrow': [1.25, 0],
#                'heating': [0, 0],
#                'hello': [0.5, -0.625],
#                'hilton bankside': [0, 0],
#                'hotel': [21.0, -8.625],
#                'hotel no': [0, 0],
#                'hour': [0.875, -0.75],
#                'housekeeping': [0.625, -0.75],
#                'husband': [0, 0],
#                'i': [0.25, -0.625],
#                'idea': [0.625, 0],
#                'inquiry': [0.625, 0],
#                'internet': [0, 0],
#                'issue': [0.5, -0.75],
#                'job': [0, -0.125],
#                'k. k. hotel george': [0, -2.5],
#                'kensington palace albert hall knightsbridge': [5.0, -3.75],
#                'kind': [3.375, -3.625],
#                'kind breakfast': [1.0, 0],
#                'knocking noise': [0.75, 0],
#                'lady': [1.125, 0],
#                'laundrette': [0.5, 0],
#                'laundry': [0.5, -0.5],
#                'leanne': [0, 0],
#                'leeds': [0, -0.25],
#                'leeds very kind': [4.5, 0],
#                'level': [1.625, -4.0],
#                'lighting': [0.625, -1.375],
#                'line': [1.25, 0],
#                'line check': [0, 0],
#                'lobby': [0.875, -0.75],
#                'location': [20.0, -1.625],
#                'location major shopping': [3.75, 0],
#                'london': [4.75, -2.625],
#                'london day great shower': [4.0, -0.5],
#                'london great': [2.75, 0],
#                'london hotel': [1.0, 0],
#                'london older facility': [3.75, 0],
#                'london rooms': [3.5, 0],
#                'lot': [0, -0.125],
#                'lounge area': [3.0, -1.75],
#                'machine': [1.125, -0.625],
#                'man': [0.25, 0],
#                'mashine': [1.125, -0.375],
#                'mattress': [0, -2.0],
#                'maximum': [0.375, -1.875],
#                'meager': [0, 0],
#                'min walk': [0, 0],
#                'mini bar': [1.25, 0],
#                'mini fridge': [0, 0],
#                'miniscule': [0, 0],
#                'mint chocolate': [1.0, 0],
#                'minute walk': [11.0, 0],
#                'mirror': [0, 0],
#                'mistake': [0.375, 0],
#                'month': [1.125, -0.375],
#                'morning': [0.5, -0.625],
#                'neck': [0, 0],
#                'need': [1.625, -0.875],
#                'neighbourhood': [0.5, 0],
#                'nice': [2.125, -2.25],
#                'night': [5.25, -1.375],
#                'noise': [0.375, 0],
#                'nothing': [2.125, -1.125],
#                'office': [1.125, -0.375],
#                'one': [0, 0],
#                'opportunity': [0, -1.5],
#                'order': [0.75, 0],
#                'oven': [0.375, 0],
#                'parking': [1.75, 0],
#                'perfect location': [0, 0],
#                'person': [0.125, 0],
#                'phone': [1.125, -0.375],
#                'piccadilly line': [0, 0],
#                'place': [1.375, -1.0],
#                'pleasant': [1.5, -0.875],
#                'plenty': [1.25, -0.625],
#                'position': [1.0, 0],
#                'potato': [0.375, 0],
#                'power socket': [0, 0],
#                'price': [2.875, -5.0],
#                'problem': [1.5, -0.875],
#                'promotion': [1.25, -2.75],
#                'property': [1.25, -0.625],
#                'proximity': [0.5, -0.75],
#                'quality': [2.375, 0],
#                'quality breakfast food': [1.875, 0],
#                'railway': [1.0, 0],
#                'ranging': [0.25, -0.625],
#                'rat': [0, -0.625],
#                'rd': [0.5, 0],
#                'rear': [0.5, 0],
#                'reception': [2.75, -1.5],
#                'reception area': [0, 0],
#                'recommendation': [0, 0],
#                'relax': [0, 0],
#                'request': [0.625, 0],
#                'restaurant': [3.75, -0.625],
#                'road nice': [1.25, 0],
#                'room': [11.5, -13.875],
#                'room bar': [0, 0],
#                'room bathroom': [0, 0],
#                'room bed': [2.0, -1.5],
#                'room desk': [1.0, 0],
#                'room key': [0.5, -2.0],
#                'room location': [0, -1.25],
#                'room pillows': [0.5, -1.25],
#                'room size': [0.25, -3.75],
#                'room someone': [1.75, 0],
#                'room space': [0, -2.25],
#                'rooms': [0.5, -0.75],
#                'route': [1.0, 0],
#                'rude receptionist': [0, -0.5],
#                'safety requirement': [0, 0],
#                'satisfactory': [0, 0],
#                'seat': [0, 0],
#                'secure parking': [1.0, 0],
#                'security': [1.125, -1.0],
#                'selection': [0.5, -0.625],
#                'service': [1.125, 0],
#                'serving': [0.625, -0.625],
#                'shower': [1.0, -2.75],
#                'shower temp control': [1.5, 0],
#                'site': [1.0, 0],
#                'size': [0.5, -0.75],
#                'slate bathroom': [0, 0],
#                'slip mat': [0, -2.75],
#                'slip shower': [0, -3.75],
#                'small': [0.75, 0],
#                'sofa bed': [0, 0],
#                'solo': [0, -0.625],
#                'something': [1.25, -2.75],
#                'space': [1.25, -3.0],
#                'space cost money': [0, 0],
#                'spite': [0.5, 0],
#                'spot': [1.125, -0.75],
#                'staff': [17.0, -3.875],
#                'staff good breakfast': [3.75, 0],
#                'staff member speak': [0, -1.875],
#                'star room': [0.5, 0],
#                'station': [4.75, -0.5],
#                'station clean quiet breakfast': [2.0, 0],
#                'stay': [1.0, 0],
#                'storage': [0.625, -2.125],
#                'street': [1.875, -0.625],
#                'structure': [1.25, -2.75],
#                'stuffy': [0, -0.25],
#                'sub': [0.5, -0.75],
#                'suit': [2.5, -1.625],
#                'suitcase': [0.5, -0.75],
#                'summer': [0.5, 0],
#                'summer period i': [5.625, -9.5],
#                'sunshine': [0.75, 0],
#                'super location': [0, 0],
#                'superb': [0.625, -0.75],
#                'table': [0, -0.75],
#                'take': [0, 0],
#                'tax': [0, 0],
#                'taxi': [1.125, -0.375],
#                'taxi service': [1.125, -0.375],
#                'tea': [0, -0.625],
#                'temperature': [0, -0.75],
#                'term': [0.5, 0],
#                'th': [1.25, -0.5],
#                'thank': [0, -1.25],
#                'thing': [0, 0],
#                'time': [1.625, -1.5],
#                'tiny': [0, 0],
#                'toaster': [0, 0],
#                'today': [0, 0],
#                'toilet': [0, 0],
#                'tourist bustle': [3.25, 0],
#                'transport': [1.75, 0],
#                'trouble': [1.375, -0.25],
#                'tube': [4.125, -1.0],
#                'tube station': [3.5, 0],
#                'tv': [0.375, -0.75],
#                'uk vacation': [0, 0],
#                'underground': [1.125, 0],
#                'upgrade': [1.0, -0.75],
#                'value': [0.5, 0],
#                'ventilation': [1.25, 0],
#                'view': [0, -2.125],
#                'visit special': [1.25, 0],
#                'walk': [1.875, 0],
#                'wall': [0.25, -0.625],
#                'water': [0, -1.375],
#                'water boiler': [0.5, -1.5],
#                'water location': [1.5, -1.25],
#                'way': [0.625, -2.0],
#                'week': [0, 0],
#                'welcome': [0.5, -0.625],
#                'well operating walk': [0, -5.625],
#                'wifi': [0.125, 0],
#                'window': [0.625, -3.75],
#                'windows': [0, -0.625],
#                'wine': [0, 0],
#                'winter nothing': [2.5, -5.5],
#                'winter warmer': [0.5, 0],
#                'work': [0.75, 0],
#                'world': [0, 0],
#                'would': [1.5, -0.125]}),
#   329],
#  ['The Park Grand London Paddington',
#   defaultdict(list,
#               {'ac': [0.875, -0.625],
#                'access': [0.375, -3.125],
#                'adult': [0, -0.875],
#                'air con': [3.5, -0.5],
#                'air conditioning': [0, 0],
#                'aircon comfy': [1.0, 0],
#                'alley': [0, 0],
#                'amount': [0, 0],
#                'anyone': [0.125, 0],
#                'anything': [1.125, -0.875],
#                'app': [0, 0],
#                'appalling': [0.625, 0],
#                'approx': [0, 0],
#                'area': [5.625, -1.25],
#                'armenia': [0, 0],
#                'arrival': [0, 0],
#                'arrival cause': [1.25, -2.75],
#                'attempt': [1.125, -1.875],
#                'australia': [0, 0],
#                'back': [1.375, -0.875],
#                'bag': [2.375, 0],
#                'balcony': [0.125, 0],
#                'bar': [2.125, 0],
#                'barfridge': [0, 0],
#                'basement': [0.5, -0.875],
#                'basement room': [0, -1.25],
#                'bath carpet': [0.5, -0.75],
#                'bathroom': [2.5, -4.25],
#                'bathroom door': [1.25, 0],
#                'bayswater station everyday': [0, 0],
#                'beautiful building': [2.75, 0],
#                'bed': [4.75, -8.75],
#                'big window': [3.75, 0],
#                'bit': [1.375, -5.0],
#                'board': [1.5, -2.5],
#                'boarding': [0.875, 0],
#                'boiler': [1.75, 0],
#                'boiler unit': [0.75, 0],
#                'bonus gift': [0.25, 0],
#                'book': [0.375, -3.125],
#                'booking': [0, 0],
#                'box': [0.625, 0],
#                'breakfast': [7.0, -3.0],
#                'breakfast buffet': [1.0, -1.25],
#                'budget room': [1.25, 0],
#                'build': [0.125, 0],
#                'building': [0.375, -3.125],
#                'business': [0, 0],
#                'c control': [0, -1.875],
# ...
#                'selection': [2.0, 0],
#                'sense': [0.375, 0],
#                'share': [0, 0],
#                'shortage': [0, 0],
#                'shower': [2.375, -1.75],
#                'shower everything': [2.0, -1.25],
#                'shower screen': [1.0, -1.25],
#                'signal': [0.375, -2.5],
#                'size': [1.625, -0.5],
#                'smell': [1.125, -1.875],
#                'sofa': [0, 0],
#                'someone': [0, 0],
#                'something': [0.625, -1.375],
#                'sort': [0, -0.25],
#                'space': [1.0, -0.625],
#                'staff': [12.5, -0.875],
#                'staff easy access': [3.375, 0],
#                'staff hyde': [4.5, 0],
#                'staff room': [2.75, 0],
#                'staffed': [0.75, 0],
#                'star': [0.375, 0],
#                'start': [0, -0.25],
#                'station': [0, 0],
#                'stay': [1.5, -0.875],
#                'street': [1.875, 0],
#                'suburb': [1.625, -0.5],
#                'suitcase': [0, -0.625],
#                'suite': [0, -0.25],
#                'surrounding': [0.875, -0.75],
#                'tap': [0.5, 0],
#                'tasty': [0.625, -1.375],
#                'taxi': [0.875, -0.875],
#                'tea': [0.5, 0],
#                'teapot': [0.5, -0.5],
#                'television upstairs': [0, 0],
#                'temperature': [0, 0],
#                'terrace building': [1.5, 0],
#                'theatre': [0, -0.375],
#                'time': [0, -1.5],
#                'tiny': [0, 0],
#                'toilet': [2.75, -0.875],
#                'toilet bath area': [0, 0],
#                'toilet bathroom': [2.5, -0.75],
#                'toilet floor': [0, 0],
#                'top': [0.375, -3.125],
#                'touch': [0, 0],
#                'transfer': [0, 0],
#                'transport': [0, 0],
#                'tricky': [0.375, 0],
#                'trip': [0, -0.25],
#                'tube': [1.375, 0],
#                'tv': [0, 0],
#                'twin bed': [0, 0],
#                'underfloor heating': [0, 0],
#                'urine': [0, 0],
#                'use': [0.875, 0],
#                'valet': [0.25, 0],
#                'value': [0.5, 0],
#                'vicinity helpful': [0.25, 0],
#                'view': [0.5, -0.25],
#                'visit': [1.25, 0],
#                'waitrose': [0, 0],
#                'walk': [1.625, 0],
#                'wall': [0.375, 0],
#                'wardrobe': [1.25, -0.75],
#                'wardrobe space': [3.0, 0],
#                'was': [2.625, -0.25],
#                'waste': [0.5, 0],
#                'water': [1.875, -2.125],
#                'way': [1.75, -0.25],
#                'week': [0, 0],
#                'weird': [1.125, -0.625],
#                'wet room shower glass door': [8.75, -1.25],
#                'which': [0.625, 0],
#                'wi': [0.375, -1.875],
#                'wider': [0.5, -0.625],
#                'wife': [0.625, 0],
#                'wifi': [0.375, -0.25],
#                'window': [2.125, -0.75],
#                'wine': [0, 0],
#                'wood': [2.125, -1.125],
#                'work': [1.75, -1.5]}),
#   440],
#  ['The Principal London',
#   defaultdict(list,
#               {'addition': [0, 0],
#                'air': [1.0, -1.25],
#                'air con': [1.0, 0],
#                'air con system': [1.75, -3.5],
#                'air conditioning': [3.25, -2.5],
#                'air conditioning system': [2.25, -1.25],
#                'aircon': [1.625, -0.375],
#                'airport': [0.375, 0],
#                'always': [1.25, -0.75],
#                'amazing victorianlandmark': [0, 0],
#                'appearance': [0, 0],
#                'architecture': [1.5, -0.5],
#                'area': [1.125, -0.875],
#                'awesome': [0.125, 0],
#                'bacon': [2.125, -1.0],
#                'baggage': [1.125, 0],
#                'bar': [0.125, -0.75],
#                'bar shame': [3.25, -3.0],
#                'bath': [0, 0],
#                'bath drain': [0, 0],
#                'bath tap': [0, 0],
#                'bathroom': [5.875, -1.75],
#                'bathroom floor': [1.0, 0],
#                'bay': [0.125, 0],
#                'beautiful': [0, 0],
#                'bed': [2.875, -4.125],
#                'bedroom': [0.5, -0.25],
#                'bedroom suite': [3.75, -1.5],
#                'before': [2.5, -1.5],
#                'birthday': [0.5, 0],
#                'bit': [4.875, -1.0],
#                'bloomsbury': [0, 0],
#                'bonus': [1.5, 0],
#                'booking': [0, 0],
#                'bother': [0.25, 0],
#                'bottle': [0.375, 0],
#                'breakfast': [7.25, -5.125],
#                'breakfast use': [0, 0],
#                'british': [0, 0],
#                'buffet food': [2.25, -1.5],
#                'building': [4.875, -0.25],
#                'building work': [0, 0],
#                'bummer': [0, 0],
#                'bus': [0.5, 0],
#                'bus tour': [2.125, -0.75],
#                'bygone era': [0.5, 0],
#                'caf': [0, 0],
#                'cancellation': [0, -0.75],
#                'cap shower gel': [0, 0],
#                'card': [0.375, 0],
#                'ceiling': [1.75, -1.25],
#                'chair': [0.5, -0.75],
#                'champagne': [0.375, 0],
#                'character': [2.375, -0.375],
#                'character breakfast': [1.0, 0],
#                'cheaper': [0, 0],
#                'check': [1.375, 0],
#                'choice': [1.375, -0.625],
#                'circle line': [6.25, 0],
#                'city': [0.625, 0],
#                'city centre': [0, 0],
#                'clean room': [1.0, -0.625],
#                'client': [0, 0],
#                'clockwork': [0.875, 0],
#                'coffee': [2.125, -0.625],
#                'cohen': [1.375, -0.625],
#                'combination': [0.125, -0.625],
#                'comfort': [1.5, -1.375],
#                'concern': [0, 0],
#                'concierge': [1.375, -0.5],
#                'concierge service': [6.25, 0],
#                'conditioner': [0, 0],
#                'consideration': [1.75, -0.625],
#                'convenient': [0.5, 0],
#                'conversation': [0, 0],
#                'corner': [1.625, 0],
#                'course': [0, 0],
#                'courtyard': [0, 0],
#                'covent garden': [3.25, 0],
#                'cramped': [0.625, -0.75],
#                'crazy': [0, -0.75],
#                'customer service': [0, 0],
#                'day': [2.375, -1.375],
#                'daylight': [0, 0],
#                'deal': [0.5, 0],
#                'decor': [0, 0],
#                'decorating': [1.375, 0],
#                'designer': [0, 0],
#                'desk': [3.625, -0.75],
#                'didnt': [0, 0],
#                'distance': [2.0, -0.625],
#                'door': [0.5, 0],
#                'door chain': [1.875, -0.5],
#                'door frame': [0, 0],
#                'door staff': [2.0, 0],
#                'doorman': [1.125, -1.125],
#                'downside': [0, 0],
#                'dozen': [0, 0],
#                'dragon sculpture': [0.75, -1.25],
#                'dresser': [0, 0],
#                'drink': [0, 0],
#                'elevator': [1.125, -0.625],
#                'engineer': [0.875, -0.625],
#                'english': [1.375, -0.625],
#                'enjoyed room service': [1.5, 0],
#                'etc': [0.375, -0.625],
#                'eurostar room': [4.25, 0],
#                'euston': [0, 0],
#                'euston hilton hotel': [0, 0],
#                'euston station': [2.25, 0],
#                'everything': [0.5, 0],
#                'example': [1.125, -0.125],
#                'exhaust': [0.125, 0],
#                'exit right': [2.25, -0.25],
#                'experience': [1.125, -0.625],
#                'fact': [2.875, 0],
#                'faulty water': [0, 0],
#                'feed': [0, 0],
#                'fire drill': [0, 0],
#                'flight': [0, -0.625],
#                'floor': [3.75, -1.25],
#                'floor air': [2.25, -1.25],
#                'floor windows': [1.125, -0.625],
#                'food': [1.5, -0.625],
#                'food comfy': [1.0, 0],
#                'fortune': [0, 0],
#                'freshen': [0, 0],
#                'fridge': [1.5, -0.625],
#                'front': [0, 0],
#                'front desk': [0, 0],
#                'front desk staff': [0, 0],
#                'fruit': [1.125, -0.75],
#                'function': [0, 0],
#                'future': [1.375, 0],
#                'generator': [0, 0],
#                'grandeur': [0, 0],
#                'gratuity': [0, 0],
#                'great': [0, -0.25],
#                'great access': [0, -0.75],
#                'great location': [2.75, 0],
#                'great ormond street hospital': [0, 0],
#                'ground floor': [0, 0],
#                'had': [0.375, -1.25],
#                'hair conditioner': [0.75, 0],
#                'heart': [0.875, 0],
#                'heathrow': [1.125, 0],
#                'helpful': [0, 0],
#                'hole': [0, 0],
#                'holiday': [1.375, 0],
#                'hong kong': [2.75, 0],
#                'hotel': [15.375, -10.375],
#                'hotel closing': [1.375, 0],
#                'hotel interior': [2.75, 0],
#                'hotel location': [0, 0],
#                'hotel manager': [0.625, 0],
#                'hotel russell': [7.75, -2.0],
#                'hotel russell station': [3.375, 0],
#                'husband': [0, 0],
#                'impact': [0, -0.5],
#                'incredibly': [0.625, -0.75],
#                'insufficient milk': [0, 0],
#                'interesting': [0, 0],
#                'interior': [0.5, -1.125],
#                'issue': [0, -0.625],
#                'kind': [0, 0],
#                'kind gesture': [1.5, 0],
#                'kings cross': [2.25, -0.25],
#                'lack': [0, 0],
#                'left': [0, 0],
#                'lift': [0, 0],
#                'light outside': [0, 0],
#                'line': [3.125, 0],
#                'lobby': [0, 0],
#                'location': [16.125, -2.75],
#                'location breakfast': [4.0, -2.75],
#                'location perfect': [2.25, -1.75],
#                'london': [3.875, -0.75],
#                'london close': [1.625, 0],
#                'lounge': [0.125, -0.75],
#                'luggage': [0.875, -0.5],
#                'machine': [0, 0],
#                'man': [1.375, 0],
#                'mattress': [1.125, -1.125],
#                'middle': [0.5, -0.25],
#                'miles': [0.625, -1.25],
#                'milk': [0.375, -1.25],
#                'minute walk': [2.25, 0],
#                'mistake': [1.125, -0.75],
#                'monday': [0, 0],
#                'money': [2.625, -1.875],
#                'monument': [0, 0],
#                'morn': [0.125, 0],
#                'morning': [0, 0],
#                'move': [1.625, -0.375],
#                'museum': [0.375, 0],
#                'musty smell': [0.5, 0],
#                'need': [0.625, -0.875],
#                'nicer': [0, 0],
#                'night': [0, -1.375],
#                'nobody': [1.125, -0.625],
#                'noise': [0.125, 0],
#                'note': [0, 0],
#                'old': [0, 0],
#                'opinion': [1.75, -0.625],
#                'opposite': [0.25, 0],
#                'option': [0.125, 0],
#                'opulence': [0, 0],
#                'outside': [2.5, -0.75],
#                'park': [0, 0],
#                'part': [0.375, 0],
#                'period': [0.375, -0.625],
#                'person': [0, -0.5],
#                'phone': [0, 0],
#                'photos': [0.5, 0],
#                'picadilly': [3.125, 0],
#                'picadilly tube': [6.25, 0],
#                'piccadilly line': [0.75, 0],
#                'pillow': [0, -0.75],
#                'place': [0.625, -0.75],
#                'platform': [0, 0],
#                'plenty': [2.0, -2.25],
#                'pm': [0, 0],
#                'point': [0.5, -0.25],
#                'potatoes': [0, 0],
#                'price': [1.5, 0],
#                'progress': [0, 0],
#                'quality comfy bar': [4.5, 0],
#                'quality drinks': [3.0, -1.25],
#                'quieter': [0.875, -0.625],
#                'rate': [0.125, 0],
#                'reception': [0.125, -0.75],
#                'reception staff': [6.25, -1.5],
#                'reception staff excellent': [3.0, 0],
#                'receptionist': [1.25, 0],
#                'reflection': [0, 0],
#                'refurbishment': [0.5, -0.25],
#                'renovation': [0, 0],
#                'requested room change given room': [3.375, -1.875],
#                'resection': [2.0, 0],
#                'restaurant': [1.5, -0.875],
#                'return': [1.125, -0.75],
#                'road': [0.625, -0.75],
#                'road side': [0.625, 0],
#                'room': [21.625, -14.375],
#                'room bill': [4.25, -3.0],
#                'room breakfast': [1.125, -1.875],
#                'room service': [5.625, -3.0],
#                'room very': [2.75, 0],
#                'rooms': [0, -0.75],
#                'russel': [0.625, 0],
#                'russell': [0.25, 0],
#                'russell hotel breakfast buffet': [0, -1.25],
#                'russell square gardens': [4.125, -1.875],
#                'sandwich': [1.625, -1.5],
#                'selection': [0, 0],
#                'service charge': [0, 0],
#                'service gorgeous': [1.75, 0],
#                'service location': [6.25, 0],
#                'shop': [0.375, -1.25],
#                'shower': [5.0, -2.375],
#                'shower brilliant': [0, 0],
#                'side': [1.375, 0],
#                'sink': [1.0, 0],
#                'size': [2.125, 0],
#                'smartphone': [0, 0],
#                'smell': [0, 0],
#                'something': [0, 0],
#                'space': [0, 0],
#                'spot': [1.125, -1.5],
#                'sq': [0, 0],
#                'square': [0, 0],
#                'st pancras': [0, -0.375],
#                'st pancras station': [0.875, -0.25],
#                'staff': [9.75, -3.375],
#                'staff polite': [0, 0],
#                'stair case': [2.75, 0],
#                'staircase': [0.375, -0.625],
#                'stairway': [0, 0],
#                'standard': [0, 0],
#                'station': [4.0, -1.125],
#                'statuesque grandeur': [0, 0],
#                'stay': [1.875, -0.75],
#                'street': [0, 0],
#                'style': [0.375, -0.625],
#                'suitcase': [0, 0],
#                'summer air conditioning': [3.0, -3.0],
#                'superb': [0.375, 0],
#                'survivor': [0.25, 0],
#                'tap': [2.125, -1.0],
#                'taste': [0, -1.25],
#                'tea': [1.375, -0.625],
#                'thank': [0, 0],
#                'time': [1.5, -2.0],
#                'titanic': [0.375, -1.125],
#                'titanic located': [2.75, 0],
#                'today': [0, 0],
#                'tour': [1.625, -0.75],
#                'tours': [0.5, 0],
#                'traffic': [0, 0],
#                'transportation': [0, 0],
#                'travel': [0, 0],
#                'tube': [5.25, 0],
#                'tube station': [1.5, 0],
#                'tube stop': [2.25, 0],
#                'twin': [0.375, -0.625],
#                'underground': [1.0, -0.5],
#                'upgrade': [0.125, -0.625],
#                'upper woburn': [0, 0],
#                'value': [2.0, 0],
#                'view': [0.5, -1.125],
#                'visit': [0.125, 0],
#                'waitress': [0, 0],
#                'walk': [1.625, 0],
#                'walking': [3.125, 0],
#                'water': [1.125, -0.75],
#                'way': [1.125, -0.625],
#                'wedding anniversary': [0, 0],
#                'week': [1.375, 0],
#                'wifi': [0.5, 0],
#                'wifi breakfast': [1.0, 0],
#                'woke': [0, -0.75],
#                'work': [0.875, -1.0],
#                'world': [1.125, -1.5],
#                'world charm modem': [2.625, 0],
#                'worst': [0, 0]}),
#   546]]

# %%
def unify_aspects(hotels_w_aspects):
    dict_aspect = {}
    
    for hotel in hotels_w_aspects:
        for key, value in hotel[1].items():
            
            if key in dict_aspect:
                dict_aspect[key] += [[value[0], hotel[0]]]
                dict_aspect[key] = sorted(dict_aspect[key])[::-1]
            else:
                dict_aspect.setdefault(key, [[value[0], hotel[0]]])
                
    return dict_aspect


start_time = time.time()

aspects_info = unify_aspects(hotel_info)

print("--- %s seconds ---" % (time.time() - start_time))

aspects_info
# Out:
# --- 0.0059239864349365234 seconds ---
# {'bath quiet': [[0.5, 'Apex Temple Court Hotel']],
#  'staff walking': [[1.0, 'Apex Temple Court Hotel']],
#  'line': [[3.125, 'The Principal London'],
#   [1.25, 'K K Hotel George'],
#   [0, 'Hotel Arena']],
#  'card': [[0.875, 'Apex Temple Court Hotel'],
#   [0.375, 'The Principal London'],
#   [0.375, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington']],
#  'drink etc': [[1.5, 'K K Hotel George']],
#  'storage': [[0.625, 'K K Hotel George']],
#  'neck room service': [[1.5, 'Hotel Arena']],
#  'elevator': [[1.125, 'The Principal London']],
#  'tea coffee': [[0, 'Hotel Arena']],
#  'door staff': [[2.0, 'The Principal London']],
#  'monastery building': [[1.5, 'Hotel Arena']],
#  'someone drilling concrete': [[1.125, 'Hotel Arena']],
#  'invitation': [[0, 'Apex Temple Court Hotel']],
#  'centre': [[1.25, 'Hotel Arena'],
#   [1.125, 'Apex Temple Court Hotel'],
#   [0.25, 'The Park Grand London Paddington']],
#  'bacon': [[2.125, 'The Principal London'],
#   [1.0, 'Apex Temple Court Hotel'],
#   [0.375, 'K K Hotel George'],
#   [0, 'Hotel Arena']],
#  'theatre': [[0, 'The Park Grand London Paddington']],
#  'outlook towels': [[3.75, 'The Park Grand London Paddington']],
#  'basement': [[0.5, 'The Park Grand London Paddington']],
#  'apex': [[3.625, 'Apex Temple Court Hotel']],
#  'meant': [[0, 'Hotel Arena']],
#  'center': [[0, 'Hotel Arena'], [0, 'Apex Temple Court Hotel']],
#  'back': [[1.375, 'The Park Grand London Paddington'],
#   [0.75, 'K K Hotel George']],
#  'beautiful building': [[2.75, 'The Park Grand London Paddington']],
#  'metro close': [[1.75, 'Hotel Arena']],
#  'novelty': [[0.875, 'Hotel Arena']],
#  'small': [[0.75, 'K K Hotel George']],
#  'duvet': [[0.75, 'Hotel Arena']],
#  'cappuccino room': [[1.5, 'Hotel Arena']],
#  'great location': [[3.75, 'K K Hotel George'],
#   [2.75, 'The Principal London'],
#   [1.75, 'Apex Temple Court Hotel'],
#   [0.75, 'Hotel Arena']],
#  'maximum': [[0.375, 'K K Hotel George']],
#  'one': [[1.875, 'Hotel Arena'],
#   [0.5, 'Apex Temple Court Hotel'],
#   [0, 'K K Hotel George']],
#  'dog': [[0, 'Hotel Arena']],
#  'innercourt': [[0.875, 'Apex Temple Court Hotel']],
#  'spite': [[0.5, 'K K Hotel George']],
#  'housekeeping': [[0.625, 'K K Hotel George']],
#  'bed': [[9.5, 'Hotel Arena'],
#   [6.25, 'Apex Temple Court Hotel'],
#   [4.75, 'The Park Grand London Paddington'],
#   [3.25, 'K K Hotel George'],
#   [2.875, 'The Principal London']],
#  'instruction': [[0.5, 'The Park Grand London Paddington']],
#  'hotel yesterday': [[0, 'Apex Temple Court Hotel']],
#  'concierge': [[1.375, 'The Principal London'],
#   [0, 'Apex Temple Court Hotel']],
#  'pointless': [[0.375, 'Hotel Arena']],
#  'handful': [[0.125, 'The Park Grand London Paddington']],
#  'night room temperature control': [[1.5, 'Apex Temple Court Hotel']],
#  'white furniture': [[0, 'Hotel Arena']],
#  'hair conditioner': [[0.75, 'The Principal London']],
#  'training': [[0.625, 'Hotel Arena']],
#  'rain': [[0, 'Hotel Arena']],
#  'location major shopping': [[3.75, 'K K Hotel George']],
#  'quality apples': [[3.75, 'The Park Grand London Paddington']],
#  'river': [[0, 'Apex Temple Court Hotel']],
#  'room location': [[0, 'K K Hotel George']],
#  'room very': [[2.75, 'The Principal London']],
#  'approx': [[0, 'The Park Grand London Paddington']],
#  'comfy': [[1.625, 'Apex Temple Court Hotel'],
#   [1.0, 'K K Hotel George'],
#   [0.75, 'Hotel Arena']],
#  'a. saturday night': [[0, 'Hotel Arena']],
#  'mint chocolate': [[1.0, 'K K Hotel George']],
#  'guest svc manager francesco': [[9.5, 'Apex Temple Court Hotel']],
#  'spent': [[0, 'Apex Temple Court Hotel']],
#  'toilet bathroom': [[2.5, 'The Park Grand London Paddington']],
#  'hello': [[0.5, 'K K Hotel George']],
#  'am': [[0.25, 'Hotel Arena']],
#  'anything': [[1.125, 'The Park Grand London Paddington'],
#   [0.875, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'transfer': [[0, 'The Park Grand London Paddington']],
#  'music': [[0.25, 'Apex Temple Court Hotel']],
#  'westminster room': [[1.5, 'Apex Temple Court Hotel']],
#  'bakery': [[0.5, 'K K Hotel George'], [0, 'Hotel Arena']],
#  'reception staff': [[6.25, 'The Principal London']],
#  'quality food': [[3.25, 'Hotel Arena']],
#  'had': [[0.375, 'The Principal London'], [0, 'Apex Temple Court Hotel']],
#  'kensington palace albert hall knightsbridge': [[5.0, 'K K Hotel George']],
#  'star': [[0.375, 'The Park Grand London Paddington']],
#  'service horrible': [[0.5, 'Hotel Arena']],
#  'wrap': [[1.625, 'Hotel Arena']],
#  'difficulty': [[0, 'Hotel Arena']],
#  'return': [[1.125, 'The Principal London'],
#   [0.25, 'The Park Grand London Paddington']],
#  'soho oxford st': [[0, 'Apex Temple Court Hotel']],
#  'eu': [[1.875, 'Apex Temple Court Hotel']],
#  'britain': [[0.5, 'Apex Temple Court Hotel']],
#  'bike': [[0, 'Hotel Arena']],
#  'board': [[1.5, 'The Park Grand London Paddington'],
#   [0.375, 'Apex Temple Court Hotel']],
#  'thank': [[0, 'The Principal London'],
#   [0, 'K K Hotel George'],
#   [0, 'Apex Temple Court Hotel']],
#  'central london': [[0, 'K K Hotel George']],
#  'television upstairs': [[0, 'The Park Grand London Paddington']],
#  'quality': [[2.375, 'K K Hotel George'],
#   [1.375, 'Hotel Arena'],
#   [0.5, 'Apex Temple Court Hotel']],
#  'arrival cause': [[1.25, 'The Park Grand London Paddington']],
#  'water pressure': [[0, 'Hotel Arena']],
#  'russell hotel breakfast buffet': [[0, 'The Principal London']],
#  'cap shower gel': [[0, 'The Principal London']],
#  'closet': [[0.625, 'K K Hotel George']],
#  'bathroom floor': [[1.0, 'The Principal London']],
#  'line check': [[0, 'K K Hotel George']],
#  'hotel bar': [[4.5, 'Apex Temple Court Hotel'], [0, 'Hotel Arena']],
#  'before': [[2.5, 'The Principal London']],
#  'ride': [[0.875, 'The Park Grand London Paddington'], [0.625, 'Hotel Arena']],
#  'floor windows': [[1.125, 'The Principal London']],
#  'twice': [[0, 'Hotel Arena']],
#  'seal': [[1.0, 'Apex Temple Court Hotel']],
#  'floor air': [[2.25, 'The Principal London']],
#  'place closer': [[1.0, 'Apex Temple Court Hotel']],
#  'build': [[0.125, 'The Park Grand London Paddington']],
#  'room balcony': [[1.0, 'Apex Temple Court Hotel']],
#  'restaurant neither': [[0, 'Apex Temple Court Hotel']],
#  'transaction charge': [[0.75, 'Hotel Arena']],
#  'room key': [[1.25, 'Apex Temple Court Hotel'], [0.5, 'K K Hotel George']],
#  'appalling': [[0.625, 'The Park Grand London Paddington']],
#  'summer period i': [[5.625, 'K K Hotel George']],
#  'part': [[0.375, 'The Principal London'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'duty': [[0, 'Apex Temple Court Hotel']],
#  'july': [[0, 'Hotel Arena']],
#  'everyone': [[2.125, 'The Park Grand London Paddington'],
#   [0.625, 'Hotel Arena'],
#   [0.625, 'Apex Temple Court Hotel'],
#   [0.5, 'K K Hotel George']],
#  'city river': [[0, 'Apex Temple Court Hotel']],
#  'help': [[2.75, 'Hotel Arena']],
#  'complaint': [[0.625, 'The Park Grand London Paddington'],
#   [0, 'K K Hotel George']],
#  'great ormond street hospital': [[0, 'The Principal London']],
#  'look': [[0.875, 'Apex Temple Court Hotel']],
#  'glass': [[2.125, 'The Park Grand London Paddington'],
#   [0.75, 'K K Hotel George']],
#  'bathroom sink': [[4.75, 'K K Hotel George']],
#  'town': [[1.375, 'Hotel Arena']],
#  'checkout day': [[4.25, 'The Park Grand London Paddington']],
#  'tube room': [[2.25, 'Apex Temple Court Hotel']],
#  'room bill': [[4.25, 'The Principal London']],
#  'fact': [[2.875, 'The Principal London'],
#   [1.0, 'Apex Temple Court Hotel'],
#   [0.375, 'K K Hotel George'],
#   [0.375, 'Hotel Arena']],
#  'buffet food': [[2.25, 'The Principal London']],
#  'rat': [[0, 'K K Hotel George']],
#  'front desk staff': [[1.5, 'K K Hotel George'], [0, 'The Principal London']],
#  'temple': [[0.5, 'Apex Temple Court Hotel']],
#  'door frame': [[0, 'The Principal London']],
#  'oth': [[0, 'Hotel Arena']],
#  'adapter': [[0, 'Apex Temple Court Hotel']],
#  'delight': [[0.375, 'K K Hotel George']],
#  'tube station': [[3.5, 'K K Hotel George'], [1.5, 'The Principal London']],
#  'affair': [[0.375, 'Hotel Arena']],
#  'kinky amsterdam window': [[1.125, 'Hotel Arena']],
#  'restaurant menu': [[1.0, 'Hotel Arena']],
#  'room pic dose': [[0, 'The Park Grand London Paddington']],
#  'reception greeting': [[1.0, 'Apex Temple Court Hotel']],
#  'closeness': [[0, 'K K Hotel George']],
#  'water': [[1.875, 'The Park Grand London Paddington'],
#   [1.125, 'The Principal London'],
#   [0.5, 'Apex Temple Court Hotel'],
#   [0, 'K K Hotel George']],
#  'fruit platter': [[0, 'The Park Grand London Paddington']],
#  'st pancras': [[0, 'The Principal London']],
#  'smell': [[1.25, 'Hotel Arena'],
#   [1.125, 'The Park Grand London Paddington'],
#   [0, 'The Principal London']],
#  'drinking water': [[1.0, 'K K Hotel George']],
#  'breakfast spread perfect': [[0.75, 'Hotel Arena']],
#  'extra': [[0.375, 'Apex Temple Court Hotel'], [0, 'Hotel Arena']],
#  'euros': [[0.375, 'Hotel Arena']],
#  'reduction coupon': [[3.25, 'Apex Temple Court Hotel']],
#  'glad': [[0, 'Apex Temple Court Hotel']],
#  'whenever': [[1.625, 'Apex Temple Court Hotel']],
#  'taxi service': [[1.125, 'K K Hotel George']],
#  'waitress': [[0, 'The Principal London']],
#  'amazing victorianlandmark': [[0, 'The Principal London']],
#  'room broken': [[3.75, 'Apex Temple Court Hotel']],
#  'expense': [[0.5, 'Apex Temple Court Hotel']],
#  'evening': [[1.75, 'Hotel Arena'],
#   [0.5, 'The Park Grand London Paddington'],
#   [0, 'K K Hotel George']],
#  'courtyard terrace': [[2.5, 'Apex Temple Court Hotel']],
#  'coffee milk': [[0, 'Apex Temple Court Hotel']],
#  'perfect location': [[0, 'K K Hotel George']],
#  'tomato': [[1.0, 'Apex Temple Court Hotel']],
#  'access': [[2.375, 'K K Hotel George'],
#   [1.875, 'Hotel Arena'],
#   [0.375, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'worst': [[0, 'The Principal London']],
#  'earl s. court tube station': [[3.125, 'K K Hotel George']],
#  'rear': [[0.5, 'K K Hotel George']],
#  'cause': [[0.5, 'Hotel Arena'], [0, 'The Park Grand London Paddington']],
#  'husband': [[0.125, 'Apex Temple Court Hotel'],
#   [0, 'The Principal London'],
#   [0, 'K K Hotel George']],
#  'suburb': [[1.625, 'The Park Grand London Paddington']],
#  'pot': [[0, 'The Park Grand London Paddington']],
#  'eye contact': [[1.25, 'Hotel Arena']],
#  'fitness center': [[2.25, 'K K Hotel George']],
#  'beautiful garden': [[0, 'K K Hotel George']],
#  'enough': [[0.25, 'K K Hotel George']],
#  'telephone huge price difference': [[0, 'Hotel Arena']],
#  'com price': [[0, 'Hotel Arena']],
#  'court': [[1.625, 'K K Hotel George'], [1.5, 'Apex Temple Court Hotel']],
#  'feeling': [[0, 'Hotel Arena']],
#  'tidy': [[0, 'Apex Temple Court Hotel']],
#  'disgusting': [[0, 'The Park Grand London Paddington']],
#  'city centre': [[6.25, 'Hotel Arena'], [0, 'The Principal London']],
#  'difficult': [[0, 'K K Hotel George'], [0, 'Apex Temple Court Hotel']],
#  'wife': [[0.625, 'The Park Grand London Paddington'], [0.375, 'Hotel Arena']],
#  'nice restaurant': [[1.375, 'Hotel Arena']],
#  'city center': [[0.125, 'Hotel Arena']],
#  'nicer': [[0, 'The Principal London']],
#  'sleep': [[1.25, 'Apex Temple Court Hotel'], [1.125, 'Hotel Arena']],
#  'voucher': [[0.5, 'Apex Temple Court Hotel']],
#  'dust': [[0.5, 'Hotel Arena']],
#  'hold church': [[0, 'Hotel Arena']],
#  'history': [[0.75, 'Hotel Arena']],
#  'office window': [[0, 'Apex Temple Court Hotel']],
#  'payment': [[0.875, 'Hotel Arena']],
#  'something': [[1.25, 'K K Hotel George'],
#   [1.25, 'Hotel Arena'],
#   [0.625, 'The Park Grand London Paddington'],
#   [0, 'The Principal London']],
#  'wardrobe': [[1.25, 'The Park Grand London Paddington'],
#   [0.625, 'Hotel Arena']],
#  'picture': [[1.0, 'The Park Grand London Paddington']],
#  'daylight': [[0, 'The Principal London'],
#   [0, 'The Park Grand London Paddington']],
#  'shower drain': [[0, 'Hotel Arena']],
#  'table': [[0, 'K K Hotel George'], [0, 'Apex Temple Court Hotel']],
#  'sink': [[1.0, 'The Principal London'], [1.0, 'Apex Temple Court Hotel']],
#  'transformer': [[0.5, 'Hotel Arena']],
#  'excellent': [[2.125, 'K K Hotel George'],
#   [1.5, 'The Park Grand London Paddington'],
#   [1.0, 'Apex Temple Court Hotel']],
#  'bar room': [[2.5, 'Apex Temple Court Hotel']],
#  'nobody': [[1.125, 'The Principal London']],
#  'furniture': [[1.625, 'The Park Grand London Paddington']],
#  'dam square': [[0.75, 'Hotel Arena']],
#  'compact': [[2.0, 'The Park Grand London Paddington']],
#  'fab': [[1.625, 'K K Hotel George']],
#  'ambience': [[0.5, 'Apex Temple Court Hotel'], [0, 'K K Hotel George']],
#  'concession': [[0, 'Apex Temple Court Hotel']],
#  'breakfast use': [[0, 'The Principal London']],
#  'cool': [[0, 'Apex Temple Court Hotel']],
#  'curtain': [[0, 'The Park Grand London Paddington'], [0, 'Hotel Arena']],
#  'water soda wine': [[0, 'Apex Temple Court Hotel']],
#  'note': [[1.0, 'Apex Temple Court Hotel'], [0, 'The Principal London']],
#  'counter': [[0, 'The Park Grand London Paddington']],
#  'leeds': [[0, 'K K Hotel George']],
#  'staff food': [[1.0, 'Hotel Arena']],
#  'transport': [[1.75, 'K K Hotel George'],
#   [0.625, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington']],
#  'water damage': [[5.75, 'Hotel Arena']],
#  'upon arrival': [[3.25, 'Apex Temple Court Hotel']],
#  'bit': [[4.875, 'The Principal London'],
#   [3.125, 'Hotel Arena'],
#   [1.375, 'The Park Grand London Paddington'],
#   [0.625, 'Apex Temple Court Hotel'],
#   [0.5, 'K K Hotel George']],
#  'freezing': [[0, 'The Park Grand London Paddington']],
#  'sofa bed': [[0, 'K K Hotel George']],
#  'district': [[0, 'Apex Temple Court Hotel']],
#  'sight': [[0, 'Apex Temple Court Hotel']],
#  'sense': [[0.375, 'The Park Grand London Paddington']],
#  'example': [[1.125, 'The Principal London']],
#  'cleanness': [[1.125, 'K K Hotel George']],
#  'clean': [[3.375, 'Hotel Arena']],
#  'aircondition': [[0, 'Hotel Arena']],
#  'restaurant food': [[0, 'Apex Temple Court Hotel']],
#  'tate modern': [[0, 'Apex Temple Court Hotel']],
#  'chapel': [[0.625, 'Hotel Arena']],
#  'use': [[0.875, 'The Park Grand London Paddington'], [0, 'Hotel Arena']],
#  'hotel wifi': [[0, 'Apex Temple Court Hotel']],
#  'mobility': [[0, 'Apex Temple Court Hotel']],
#  'nothing': [[2.125, 'K K Hotel George'],
#   [0.375, 'The Park Grand London Paddington'],
#   [0, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'band': [[0.5, 'Apex Temple Court Hotel']],
#  'system': [[0.25, 'Hotel Arena']],
#  'half': [[0.375, 'Hotel Arena'], [0, 'Apex Temple Court Hotel']],
#  'was': [[2.625, 'The Park Grand London Paddington'], [0.75, 'Hotel Arena']],
#  'morning': [[1.75, 'Hotel Arena'],
#   [0.5, 'The Park Grand London Paddington'],
#   [0.5, 'K K Hotel George'],
#   [0, 'The Principal London']],
#  'man': [[1.375, 'The Principal London'], [0.25, 'K K Hotel George']],
#  'room bed': [[4.75, 'Apex Temple Court Hotel'], [2.0, 'K K Hotel George']],
#  'interesting': [[0, 'The Principal London']],
#  'lack': [[0, 'The Principal London']],
#  'right': [[0.25, 'Hotel Arena']],
#  'toilet bath area': [[0, 'The Park Grand London Paddington']],
#  'bloomsbury': [[0, 'The Principal London']],
#  'hotel': [[27.75, 'Hotel Arena'],
#   [24.75, 'Apex Temple Court Hotel'],
#   [21.0, 'K K Hotel George'],
#   [15.375, 'The Principal London'],
#   [13.625, 'The Park Grand London Paddington']],
#  'euston station': [[2.25, 'The Principal London']],
#  'quality breakfast food': [[1.875, 'K K Hotel George']],
#  'refurbishment': [[0.5, 'The Principal London']],
#  'negligence': [[0, 'Hotel Arena']],
#  'location perfect': [[2.25, 'The Principal London']],
#  'suit': [[2.5, 'K K Hotel George']],
#  'quieter': [[0.875, 'The Principal London']],
#  'being': [[0, 'Apex Temple Court Hotel']],
#  'wall': [[0.375, 'The Park Grand London Paddington'],
#   [0.25, 'K K Hotel George'],
#   [0, 'Hotel Arena']],
#  'tennis court': [[0.5, 'Hotel Arena']],
#  'friendliness': [[0.25, 'The Park Grand London Paddington']],
#  'oxford street': [[0, 'The Park Grand London Paddington']],
#  'pipe work': [[1.0, 'The Park Grand London Paddington']],
#  'age': [[1.875, 'Apex Temple Court Hotel']],
#  'circle line': [[6.25, 'The Principal London']],
#  'answer': [[0, 'Hotel Arena']],
#  'bygone era': [[0.5, 'The Principal London']],
#  'distance': [[2.5, 'Apex Temple Court Hotel'],
#   [2.0, 'The Principal London'],
#   [1.375, 'The Park Grand London Paddington'],
#   [1.125, 'K K Hotel George'],
#   [0.5, 'Hotel Arena']],
#  'laundry': [[0.5, 'K K Hotel George']],
#  'construction': [[0, 'Hotel Arena']],
#  'perfect': [[0, 'Hotel Arena']],
#  'area': [[5.625, 'The Park Grand London Paddington'],
#   [3.5, 'Apex Temple Court Hotel'],
#   [2.25, 'K K Hotel George'],
#   [1.75, 'Hotel Arena'],
#   [1.125, 'The Principal London']],
#  'room everything': [[0.625, 'Apex Temple Court Hotel']],
#  'anyone': [[1.625, 'Hotel Arena'],
#   [0.125, 'The Park Grand London Paddington']],
#  'club lounge': [[1.375, 'Apex Temple Court Hotel']],
#  'window mechanism': [[0.5, 'Hotel Arena']],
#  'security': [[1.125, 'K K Hotel George']],
#  'earls court': [[3.75, 'K K Hotel George']],
#  'mail': [[0.375, 'Hotel Arena']],
#  'railway': [[1.0, 'K K Hotel George']],
#  'gorgeous': [[1.125, 'Apex Temple Court Hotel']],
#  'euston': [[0, 'The Principal London']],
#  'air con': [[3.5, 'The Park Grand London Paddington'],
#   [1.0, 'The Principal London'],
#   [0.5, 'K K Hotel George']],
#  'awful': [[0, 'K K Hotel George']],
#  'vibe': [[2.125, 'Apex Temple Court Hotel']],
#  'winter warmer': [[0.5, 'K K Hotel George']],
#  'occurrence': [[1.375, 'Hotel Arena']],
#  'waist': [[1.125, 'Hotel Arena']],
#  'food supermarket': [[1.0, 'K K Hotel George']],
#  'restaurant': [[9.0, 'Hotel Arena'],
#   [3.75, 'K K Hotel George'],
#   [2.75, 'The Park Grand London Paddington'],
#   [1.5, 'The Principal London'],
#   [0.5, 'Apex Temple Court Hotel']],
#  'area shower': [[0.5, 'Hotel Arena']],
#  'fab experience': [[1.625, 'K K Hotel George']],
#  'pad': [[0.25, 'Hotel Arena']],
#  'key everyday': [[0, 'Hotel Arena']],
#  'aircon comfy': [[1.0, 'The Park Grand London Paddington']],
#  'london hotel': [[1.0, 'K K Hotel George']],
#  'touch': [[0, 'The Park Grand London Paddington']],
#  'label club lounge': [[6.75, 'The Park Grand London Paddington']],
#  'paddington': [[2.5, 'The Park Grand London Paddington']],
#  'relaxing stay': [[1.0, 'Hotel Arena']],
#  'night': [[5.25, 'K K Hotel George'],
#   [3.5, 'Apex Temple Court Hotel'],
#   [3.0, 'Hotel Arena'],
#   [2.0, 'The Park Grand London Paddington'],
#   [0, 'The Principal London']],
#  'charge': [[0.125, 'K K Hotel George'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'edge': [[0, 'Apex Temple Court Hotel']],
#  'waitrose': [[0, 'The Park Grand London Paddington']],
#  'pleasant': [[1.5, 'K K Hotel George']],
#  'great position': [[2.0, 'K K Hotel George']],
#  'parking': [[1.75, 'K K Hotel George'], [1.0, 'Apex Temple Court Hotel']],
#  'btw': [[0.625, 'Hotel Arena']],
#  'old': [[0, 'The Principal London']],
#  'wi': [[0.375, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'daughter': [[1.25, 'The Park Grand London Paddington'],
#   [0.625, 'K K Hotel George']],
#  'internet': [[0, 'K K Hotel George']],
#  'position': [[1.75, 'The Park Grand London Paddington'],
#   [1.0, 'K K Hotel George']],
#  'room i': [[8.0, 'Hotel Arena']],
#  'tax': [[0, 'K K Hotel George']],
#  'road': [[0.625, 'The Principal London'],
#   [0.625, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'room nothing': [[5.0, 'Apex Temple Court Hotel']],
#  'stuffy': [[0, 'K K Hotel George']],
#  'light': [[0, 'Hotel Arena']],
#  'reception staff excellent': [[3.0, 'The Principal London']],
#  'night guard': [[0, 'Hotel Arena']],
#  'platform': [[0, 'The Principal London']],
#  'building': [[8.75, 'Hotel Arena'],
#   [4.875, 'The Principal London'],
#   [0.375, 'The Park Grand London Paddington']],
#  'relaxing soak': [[2.75, 'Apex Temple Court Hotel']],
#  'bar space': [[1.0, 'Apex Temple Court Hotel']],
#  'fussy': [[0, 'Apex Temple Court Hotel']],
#  'staff polite': [[0, 'The Principal London']],
#  'knocking noise': [[0.75, 'K K Hotel George']],
#  'segregation': [[0.5, 'The Park Grand London Paddington']],
#  'gluten free diet selection': [[7.0, 'The Park Grand London Paddington']],
#  'hotel story': [[0, 'The Park Grand London Paddington']],
#  'paddington quiet location': [[3.375, 'The Park Grand London Paddington']],
#  'comfy room': [[0, 'K K Hotel George']],
#  'shut': [[0.25, 'Apex Temple Court Hotel']],
#  'setting': [[3.375, 'Hotel Arena']],
#  'toilet': [[2.75, 'The Park Grand London Paddington'],
#   [1.375, 'Hotel Arena'],
#   [0.625, 'Apex Temple Court Hotel'],
#   [0, 'K K Hotel George']],
#  'courtyard': [[0.375, 'Hotel Arena'], [0, 'The Principal London']],
#  'weather': [[1.25, 'Apex Temple Court Hotel']],
#  'next morning': [[1.25, 'The Park Grand London Paddington']],
#  'great choice': [[3.0, 'K K Hotel George']],
#  'plaster': [[0.25, 'Hotel Arena']],
#  'was kind': [[0.5, 'Hotel Arena']],
#  'hilton bankside': [[0, 'K K Hotel George']],
#  'street': [[1.875, 'The Park Grand London Paddington'],
#   [1.875, 'K K Hotel George'],
#   [0.5, 'Hotel Arena'],
#   [0, 'The Principal London'],
#   [0, 'Apex Temple Court Hotel']],
#  'shower door': [[2.0, 'Apex Temple Court Hotel']],
#  'wheelchair': [[0, 'Apex Temple Court Hotel']],
#  'offer': [[0.625, 'Hotel Arena'], [0, 'The Park Grand London Paddington']],
#  'room perfect hotel': [[2.375, 'Hotel Arena']],
#  'fi': [[0, 'Apex Temple Court Hotel']],
#  'bathtub': [[0, 'Hotel Arena']],
#  'proximity': [[0.5, 'K K Hotel George'],
#   [0.375, 'The Park Grand London Paddington']],
#  'hotel restaurant': [[1.375, 'Hotel Arena']],
#  'juice': [[0.625, 'Hotel Arena']],
#  'recommendation': [[0, 'K K Hotel George']],
#  'bath carpet': [[0.5, 'The Park Grand London Paddington']],
#  'safety requirement': [[0, 'K K Hotel George']],
#  'stupid room': [[0.5, 'Hotel Arena']],
#  'night shift manager': [[5.0, 'Hotel Arena']],
#  'station': [[4.75, 'K K Hotel George'],
#   [4.0, 'The Principal London'],
#   [1.625, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington']],
#  'attitude': [[0.5, 'K K Hotel George']],
#  'check': [[1.375, 'The Principal London'],
#   [1.375, 'The Park Grand London Paddington'],
#   [1.25, 'K K Hotel George'],
#   [1.0, 'Hotel Arena'],
#   [0.875, 'Apex Temple Court Hotel']],
#  'hotel closing': [[1.375, 'The Principal London']],
#  'diverse breakfast': [[1.0, 'K K Hotel George']],
#  'midnight': [[2.0, 'Hotel Arena']],
#  'airport': [[2.0, 'K K Hotel George'],
#   [0.875, 'Hotel Arena'],
#   [0.375, 'The Principal London']],
#  'bose speaker': [[0, 'Apex Temple Court Hotel']],
#  'fab fluffy': [[2.0, 'K K Hotel George']],
#  'slate bathroom': [[0, 'K K Hotel George']],
#  'main street': [[0, 'The Park Grand London Paddington']],
#  'winter nothing': [[2.5, 'K K Hotel George']],
#  'walk': [[2.625, 'Hotel Arena'],
#   [1.875, 'K K Hotel George'],
#   [1.625, 'The Principal London'],
#   [1.625, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'selection': [[2.0, 'The Park Grand London Paddington'],
#   [1.0, 'Apex Temple Court Hotel'],
#   [0.5, 'K K Hotel George'],
#   [0.5, 'Hotel Arena'],
#   [0, 'The Principal London']],
#  'equipment': [[0, 'K K Hotel George']],
#  'paddinton station': [[1.25, 'The Park Grand London Paddington']],
#  'bar super': [[1.0, 'Apex Temple Court Hotel']],
#  'generator': [[0, 'The Principal London']],
#  'rome': [[2.125, 'The Park Grand London Paddington']],
#  'miles': [[0.625, 'The Principal London']],
#  'room door': [[1.25, 'The Park Grand London Paddington']],
#  'paddington area': [[2.75, 'The Park Grand London Paddington']],
#  'titanic located': [[2.75, 'The Principal London']],
#  'price': [[2.875, 'K K Hotel George'],
#   [1.625, 'The Park Grand London Paddington'],
#   [1.5, 'The Principal London'],
#   [1.125, 'Hotel Arena'],
#   [1.125, 'Apex Temple Court Hotel']],
#  'underground': [[1.875, 'Apex Temple Court Hotel'],
#   [1.125, 'K K Hotel George'],
#   [1.0, 'The Principal London']],
#  'glass bathroom': [[1.25, 'Hotel Arena']],
#  'reception area': [[2.0, 'Hotel Arena'], [0, 'K K Hotel George']],
#  'location right': [[2.5, 'Apex Temple Court Hotel']],
#  'character breakfast': [[1.0, 'The Principal London']],
#  'sunday': [[0, 'Apex Temple Court Hotel']],
#  'love': [[0, 'Hotel Arena']],
#  'cold': [[0.5, 'Hotel Arena']],
#  'paddington station': [[4.0, 'The Park Grand London Paddington']],
#  'order': [[1.125, 'The Park Grand London Paddington'],
#   [1.125, 'Hotel Arena'],
#   [0.75, 'K K Hotel George'],
#   [0.125, 'Apex Temple Court Hotel']],
#  'staff member speak': [[0, 'K K Hotel George']],
#  'dinner bar': [[0, 'Hotel Arena']],
#  'london rooms': [[3.5, 'K K Hotel George'],
#   [3.25, 'The Park Grand London Paddington']],
#  'roof': [[1.375, 'Hotel Arena']],
#  'wednesday': [[0, 'Apex Temple Court Hotel']],
#  'ease': [[0.875, 'The Park Grand London Paddington']],
#  'badge': [[0, 'Apex Temple Court Hotel']],
#  'complain': [[0, 'Hotel Arena']],
#  'didnt': [[0, 'The Principal London']],
#  'temperature': [[0.125, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'K K Hotel George']],
#  'lady': [[1.125, 'K K Hotel George'],
#   [0, 'The Park Grand London Paddington']],
#  'construction work': [[0, 'Hotel Arena']],
#  'omg': [[0, 'The Park Grand London Paddington']],
#  'russell': [[0.25, 'The Principal London']],
#  'distance temple area': [[2.25, 'Apex Temple Court Hotel']],
#  'reflection': [[0, 'The Principal London']],
#  'sound': [[0.875, 'Hotel Arena']],
#  'breakfast': [[14.875, 'K K Hotel George'],
#   [7.375, 'Apex Temple Court Hotel'],
#   [7.25, 'The Principal London'],
#   [7.0, 'The Park Grand London Paddington'],
#   [6.875, 'Hotel Arena']],
#  'order shower': [[1.25, 'Hotel Arena']],
#  'transport blackfriars tube station': [[0, 'Apex Temple Court Hotel']],
#  'heathrow': [[1.25, 'K K Hotel George'],
#   [1.125, 'The Principal London'],
#   [0, 'The Park Grand London Paddington']],
#  'standard': [[2.0, 'Apex Temple Court Hotel'],
#   [0.5, 'Hotel Arena'],
#   [0, 'The Principal London']],
#  'coffee': [[3.25, 'Hotel Arena'],
#   [2.5, 'The Park Grand London Paddington'],
#   [2.125, 'The Principal London'],
#   [1.125, 'K K Hotel George'],
#   [0.875, 'Apex Temple Court Hotel']],
#  'boiler': [[1.75, 'The Park Grand London Paddington'],
#   [1.625, 'Hotel Arena']],
#  'amsterdam room': [[2.0, 'Hotel Arena']],
#  'gratuity': [[0, 'The Principal London']],
#  'orphanage': [[0, 'Hotel Arena']],
#  'heathrow express': [[2.75, 'The Park Grand London Paddington']],
#  'dragon sculpture': [[0.75, 'The Principal London']],
#  'bummer': [[0, 'The Principal London']],
#  'shower cabin': [[1.25, 'Apex Temple Court Hotel']],
#  'room hotel': [[1.0, 'Apex Temple Court Hotel']],
#  'glass box': [[0.875, 'Hotel Arena']],
#  'take': [[0, 'K K Hotel George']],
#  'room hidden courtyard view': [[5.0, 'Apex Temple Court Hotel']],
#  'boat': [[0, 'Apex Temple Court Hotel']],
#  'communication': [[0, 'The Park Grand London Paddington']],
#  'invoice': [[0, 'Apex Temple Court Hotel']],
#  'area breakfast': [[1.0, 'K K Hotel George']],
#  'kensington': [[1.0, 'The Park Grand London Paddington']],
#  'rude receptionist': [[0, 'K K Hotel George']],
#  'staff': [[19.875, 'Hotel Arena'],
#   [17.0, 'K K Hotel George'],
#   [12.5, 'The Park Grand London Paddington'],
#   [11.875, 'Apex Temple Court Hotel'],
#   [9.75, 'The Principal London']],
#  'mine': [[0.875, 'Apex Temple Court Hotel']],
#  'conditioner': [[0, 'The Principal London']],
#  'tray charge': [[2.0, 'Apex Temple Court Hotel']],
#  'attempt': [[1.125, 'The Park Grand London Paddington']],
#  'front desk': [[2.5, 'Hotel Arena'],
#   [1.5, 'The Park Grand London Paddington'],
#   [0, 'The Principal London'],
#   [0, 'K K Hotel George']],
#  'online': [[0, 'Hotel Arena']],
#  'bath': [[7.0, 'Apex Temple Court Hotel'],
#   [1.125, 'K K Hotel George'],
#   [0.5, 'Hotel Arena'],
#   [0, 'The Principal London']],
#  'hole': [[0, 'The Principal London']],
#  'world charm modem': [[2.625, 'The Principal London']],
#  'floor': [[3.75, 'The Principal London'],
#   [2.75, 'Hotel Arena'],
#   [2.625, 'The Park Grand London Paddington'],
#   [1.0, 'K K Hotel George']],
#  'size': [[2.125, 'The Principal London'],
#   [1.875, 'Apex Temple Court Hotel'],
#   [1.625, 'The Park Grand London Paddington'],
#   [0.5, 'K K Hotel George']],
#  'trafalgar square': [[0, 'Apex Temple Court Hotel']],
#  'view': [[1.125, 'Hotel Arena'],
#   [0.875, 'Apex Temple Court Hotel'],
#   [0.5, 'The Principal London'],
#   [0.5, 'The Park Grand London Paddington'],
#   [0, 'K K Hotel George']],
#  'earls court station': [[1.875, 'K K Hotel George']],
#  'budget room': [[1.25, 'The Park Grand London Paddington']],
#  'opulence': [[0, 'The Principal London']],
#  'destination': [[0, 'Hotel Arena']],
#  'breakfast food': [[3.5, 'Hotel Arena']],
#  'diet': [[0.5, 'K K Hotel George']],
#  'great hotel': [[0, 'Hotel Arena']],
#  'room service food': [[3.375, 'Apex Temple Court Hotel']],
#  'statuesque grandeur': [[0, 'The Principal London']],
#  'concern': [[0, 'The Principal London']],
#  'mini bar': [[1.25, 'K K Hotel George']],
#  'hotel all': [[3.25, 'Hotel Arena']],
#  'gutter': [[0.5, 'Hotel Arena']],
#  'park cool': [[0, 'Hotel Arena']],
#  'sized bathroom': [[4.75, 'Apex Temple Court Hotel']],
#  'park room': [[6.75, 'Hotel Arena']],
#  'i': [[9.625, 'Hotel Arena'],
#   [1.375, 'Apex Temple Court Hotel'],
#   [0.25, 'K K Hotel George']],
#  'garden view': [[1.75, 'Hotel Arena']],
#  'sue': [[1.0, 'Apex Temple Court Hotel']],
#  'jet engine': [[0.75, 'The Park Grand London Paddington']],
#  'presentation': [[0, 'Apex Temple Court Hotel']],
#  'hand': [[0.25, 'Hotel Arena']],
#  'champagne': [[0.375, 'The Principal London']],
#  'wedding': [[0.625, 'Hotel Arena']],
#  'laundrette': [[0.5, 'K K Hotel George']],
#  'dining': [[0, 'Hotel Arena']],
#  'rent': [[1.125, 'Hotel Arena']],
#  'trip': [[0.25, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'company': [[0, 'Hotel Arena']],
#  'manky': [[0, 'The Park Grand London Paddington']],
#  'room awkward': [[3.625, 'The Park Grand London Paddington']],
#  'room decor': [[0, 'Hotel Arena']],
#  'staff good breakfast': [[3.75, 'K K Hotel George']],
#  'sunshine': [[0.75, 'K K Hotel George']],
#  'book': [[0.875, 'Hotel Arena'], [0.375, 'The Park Grand London Paddington']],
#  'vicinity helpful': [[0.25, 'The Park Grand London Paddington']],
#  'air con system': [[1.75, 'The Principal London']],
#  'staff shampoo': [[1.75, 'Hotel Arena']],
#  'question': [[0.625, 'Hotel Arena'], [0.375, 'Apex Temple Court Hotel']],
#  'air conditioning': [[3.25, 'The Principal London'],
#   [0, 'The Park Grand London Paddington']],
#  'advance': [[1.0, 'Apex Temple Court Hotel'], [0, 'Hotel Arena']],
#  'room being': [[0, 'Apex Temple Court Hotel']],
#  'car': [[1.625, 'K K Hotel George'], [0, 'Apex Temple Court Hotel']],
#  'wine': [[0, 'The Park Grand London Paddington'], [0, 'K K Hotel George']],
#  'bar': [[2.125, 'The Park Grand London Paddington'],
#   [2.0, 'K K Hotel George'],
#   [2.0, 'Hotel Arena'],
#   [0.125, 'The Principal London'],
#   [0.125, 'Apex Temple Court Hotel']],
#  'fire drill': [[0, 'The Principal London']],
#  'cleanliness': [[0.5, 'Apex Temple Court Hotel']],
#  'appreciation': [[0.375, 'Hotel Arena']],
#  'machine': [[1.125, 'K K Hotel George'],
#   [0, 'The Principal London'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'spacious': [[0.75, 'Hotel Arena']],
#  'ground floor room': [[2.625, 'The Park Grand London Paddington']],
#  'guess': [[0.5, 'Hotel Arena']],
#  'shower everything': [[2.0, 'The Park Grand London Paddington']],
#  'customer service': [[0, 'The Principal London']],
#  'rooms': [[0.5, 'K K Hotel George'], [0, 'The Principal London']],
#  'ownership': [[0, 'Hotel Arena']],
#  'information': [[2.125, 'The Park Grand London Paddington'],
#   [0, 'Hotel Arena']],
#  'aspect fantastic location': [[5.25, 'K K Hotel George']],
#  'character': [[2.375, 'The Principal London']],
#  'double bed': [[1.75, 'Hotel Arena']],
#  'hotel russell': [[7.75, 'The Principal London']],
#  'booking process': [[0, 'Hotel Arena']],
#  'summer air conditioning': [[3.0, 'The Principal London']],
#  'bus tour': [[2.125, 'The Principal London']],
#  'picadilly': [[3.125, 'The Principal London']],
#  'perfect launch pad': [[0.25, 'Hotel Arena']],
#  'hairdryer': [[0.25, 'The Park Grand London Paddington']],
#  'name': [[1.125, 'The Park Grand London Paddington']],
#  'bonus gift': [[0.25, 'The Park Grand London Paddington']],
#  'sandwich': [[1.625, 'The Principal London']],
#  'great': [[0.5, 'Hotel Arena'], [0, 'The Principal London']],
#  'bath drain': [[0, 'The Principal London']],
#  'colleague': [[0, 'Apex Temple Court Hotel']],
#  'wonderful': [[0.25, 'Hotel Arena']],
#  'london': [[6.0, 'The Park Grand London Paddington'],
#   [4.75, 'K K Hotel George'],
#   [3.875, 'The Principal London'],
#   [2.375, 'Apex Temple Court Hotel'],
#   [0.125, 'Hotel Arena']],
#  'toilet floor': [[0, 'The Park Grand London Paddington']],
#  'arrive': [[0.625, 'Hotel Arena']],
#  'grandeur': [[0, 'The Principal London']],
#  'breakfast room': [[0, 'Apex Temple Court Hotel']],
#  'breakfast buffet': [[1.0, 'The Park Grand London Paddington'],
#   [0, 'K K Hotel George']],
#  'enjoyed room service': [[1.5, 'The Principal London']],
#  'did': [[0, 'K K Hotel George']],
#  'hospital': [[0, 'Hotel Arena']],
#  'spaciousness': [[1.5, 'Apex Temple Court Hotel']],
#  'mess': [[0, 'Hotel Arena']],
#  'breakfast check': [[0.75, 'Hotel Arena']],
#  'change': [[1.625, 'The Park Grand London Paddington'],
#   [0, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'bar restaurant area': [[4.125, 'Hotel Arena']],
#  'little privacy': [[0, 'Hotel Arena']],
#  'luck': [[0, 'The Park Grand London Paddington']],
#  'barfridge': [[0, 'The Park Grand London Paddington']],
#  'superb': [[0.625, 'K K Hotel George'], [0.375, 'The Principal London']],
#  'complimentary': [[0.375, 'The Park Grand London Paddington']],
#  'space': [[1.375, 'Hotel Arena'],
#   [1.25, 'K K Hotel George'],
#   [1.0, 'The Park Grand London Paddington'],
#   [0, 'The Principal London']],
#  'future': [[1.375, 'The Principal London'], [1.25, 'K K Hotel George']],
#  'continental breakfast': [[3.125, 'Apex Temple Court Hotel']],
#  'response': [[0, 'The Park Grand London Paddington']],
#  'microwave': [[0, 'The Park Grand London Paddington']],
#  'backdrop': [[1.25, 'Apex Temple Court Hotel']],
#  'oostpark': [[0, 'Hotel Arena']],
#  'bath tap': [[0, 'The Principal London']],
#  'floor corridor': [[1.625, 'Hotel Arena']],
#  'hong kong': [[2.75, 'The Principal London']],
#  'architecture': [[1.5, 'The Principal London'], [0.75, 'Hotel Arena']],
#  'tube': [[5.25, 'The Principal London'],
#   [4.125, 'K K Hotel George'],
#   [1.375, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'set': [[1.25, 'Hotel Arena']],
#  'sausage': [[1.0, 'Apex Temple Court Hotel']],
#  'power walk': [[0, 'The Park Grand London Paddington']],
#  'birthday present': [[0.75, 'Hotel Arena']],
#  'russel': [[0.625, 'The Principal London']],
#  'progress': [[0, 'The Principal London']],
#  'shower screen': [[1.0, 'The Park Grand London Paddington']],
#  'bobby gin': [[0, 'Hotel Arena']],
#  'tap': [[2.125, 'The Principal London'],
#   [0.5, 'The Park Grand London Paddington']],
#  'meal': [[0, 'The Park Grand London Paddington'], [0, 'Hotel Arena']],
#  'cutlery': [[0, 'K K Hotel George']],
#  'reservation': [[0.625, 'Apex Temple Court Hotel']],
#  'reception': [[2.75, 'K K Hotel George'],
#   [1.875, 'Apex Temple Court Hotel'],
#   [0.375, 'Hotel Arena'],
#   [0.125, 'The Principal London'],
#   [0.125, 'The Park Grand London Paddington']],
#  'guest': [[0.625, 'Hotel Arena']],
#  'tourist trap': [[0.75, 'Hotel Arena']],
#  'privacy location temple': [[1.5, 'Apex Temple Court Hotel']],
#  'very': [[0.75, 'Apex Temple Court Hotel']],
#  'greenery': [[0, 'Hotel Arena']],
#  'neighbourhood': [[0.5, 'K K Hotel George']],
#  'which': [[0.875, 'Hotel Arena'],
#   [0.625, 'The Park Grand London Paddington']],
#  'seating': [[0.5, 'Apex Temple Court Hotel']],
#  'block': [[1.25, 'K K Hotel George']],
#  'underfloor heating': [[0, 'The Park Grand London Paddington']],
#  'forth': [[0.625, 'The Park Grand London Paddington']],
#  'lobby need attention': [[0, 'The Park Grand London Paddington']],
#  'notch quality': [[0, 'Apex Temple Court Hotel']],
#  'cleaner': [[1.5, 'The Park Grand London Paddington'],
#   [1.375, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'explanation': [[0, 'K K Hotel George']],
#  'service charge': [[0, 'The Principal London']],
#  'st paul': [[0, 'Apex Temple Court Hotel']],
#  'dirty': [[1.375, 'Hotel Arena']],
#  'holiday': [[1.375, 'The Principal London'],
#   [0.875, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington']],
#  'carbon paper': [[0, 'The Park Grand London Paddington']],
#  'majority': [[0, 'The Park Grand London Paddington']],
#  'lift': [[0.5, 'The Park Grand London Paddington'],
#   [0, 'The Principal London']],
#  'hyde park kensington gardens gate': [[0,
#    'The Park Grand London Paddington']],
#  'friend': [[0, 'K K Hotel George']],
#  'ventilation': [[1.25, 'K K Hotel George'], [0, 'Apex Temple Court Hotel']],
#  'boarding': [[0.875, 'The Park Grand London Paddington'],
#   [0, 'K K Hotel George']],
#  'business': [[1.0, 'Apex Temple Court Hotel'],
#   [0.5, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington']],
#  'summer': [[1.75, 'Apex Temple Court Hotel'], [0.5, 'K K Hotel George']],
#  'aircon': [[1.625, 'The Principal London']],
#  'menu': [[1.125, 'Apex Temple Court Hotel']],
#  'earl s. court tube': [[5.0, 'K K Hotel George']],
#  'court station': [[3.25, 'K K Hotel George']],
#  'combination': [[0.125, 'The Principal London']],
#  'air': [[1.125, 'Apex Temple Court Hotel'], [1.0, 'The Principal London']],
#  'axcess': [[0, 'Hotel Arena']],
#  'suitcase': [[0.5, 'K K Hotel George'],
#   [0, 'The Principal London'],
#   [0, 'The Park Grand London Paddington']],
#  'period': [[0.375, 'The Principal London']],
#  'consideration': [[1.75, 'The Principal London'], [0, 'K K Hotel George']],
#  'phone': [[1.75, 'The Park Grand London Paddington'],
#   [1.125, 'K K Hotel George'],
#   [0.375, 'Hotel Arena'],
#   [0.125, 'Apex Temple Court Hotel'],
#   [0, 'The Principal London']],
#  'head': [[1.75, 'The Park Grand London Paddington'], [0.5, 'Hotel Arena']],
#  'paddington station lots': [[0.375, 'The Park Grand London Paddington']],
#  'com': [[1.0, 'Apex Temple Court Hotel'],
#   [0, 'K K Hotel George'],
#   [0, 'Hotel Arena']],
#  'fan': [[1.25, 'K K Hotel George'], [0, 'Apex Temple Court Hotel']],
#  'first room': [[4.0, 'Hotel Arena']],
#  'consumer': [[0.375, 'Hotel Arena']],
#  'clean room': [[1.0, 'The Principal London']],
#  'welcome': [[0.5, 'K K Hotel George']],
#  'water location': [[1.5, 'K K Hotel George']],
#  'musty smell': [[0.5, 'The Principal London']],
#  'conversation': [[0, 'The Principal London']],
#  'espresso cappucino': [[4.25, 'K K Hotel George']],
#  'understand': [[0, 'Apex Temple Court Hotel']],
#  'shower': [[5.125, 'Apex Temple Court Hotel'],
#   [5.0, 'The Principal London'],
#   [2.375, 'The Park Grand London Paddington'],
#   [1.0, 'K K Hotel George'],
#   [1.0, 'Hotel Arena']],
#  'faulty water': [[0, 'The Principal London']],
#  'decor': [[0, 'The Principal London']],
#  'earl': [[3.875, 'K K Hotel George']],
#  'meter': [[0.5, 'Hotel Arena']],
#  'assistance': [[0, 'K K Hotel George']],
#  'mistake': [[1.125, 'The Principal London'],
#   [0.375, 'K K Hotel George'],
#   [0.375, 'Hotel Arena']],
#  'permission': [[0, 'Apex Temple Court Hotel']],
#  'practice': [[0, 'Hotel Arena']],
#  'painting': [[0.5, 'The Park Grand London Paddington']],
#  'duck': [[0.125, 'Apex Temple Court Hotel']],
#  'wing': [[0.375, 'Hotel Arena']],
#  'disaster room': [[2.375, 'Hotel Arena']],
#  'reference': [[0, 'Apex Temple Court Hotel']],
#  'hold': [[0, 'The Park Grand London Paddington']],
#  'meager': [[0, 'K K Hotel George']],
#  'handrail': [[0.5, 'Hotel Arena']],
#  'hour journey': [[0, 'The Park Grand London Paddington']],
#  'c controller': [[1.5, 'The Park Grand London Paddington']],
#  'firmer pillow': [[3.0, 'K K Hotel George']],
#  'room temperature': [[0, 'The Park Grand London Paddington']],
#  'station clean quiet breakfast': [[2.0, 'K K Hotel George']],
#  'point': [[2.125, 'The Park Grand London Paddington'],
#   [0.5, 'The Principal London'],
#   [0.375, 'Hotel Arena']],
#  'park grand london kensington': [[3.5, 'The Park Grand London Paddington']],
#  'hotel location': [[2.0, 'The Park Grand London Paddington'],
#   [0, 'The Principal London']],
#  'caf': [[0, 'The Principal London']],
#  'relax': [[0, 'K K Hotel George']],
#  'toilet seat': [[0.75, 'Apex Temple Court Hotel']],
#  'deal': [[0.625, 'Hotel Arena'], [0.5, 'The Principal London']],
#  'beauty': [[0.875, 'Hotel Arena']],
#  'suite': [[0.875, 'Apex Temple Court Hotel'],
#   [0, 'The Park Grand London Paddington']],
#  'covent garden soho': [[0, 'Apex Temple Court Hotel']],
#  'everything': [[2.875, 'Apex Temple Court Hotel'],
#   [2.125, 'The Park Grand London Paddington'],
#   [0.75, 'Hotel Arena'],
#   [0.5, 'The Principal London']],
#  'mr': [[0, 'Apex Temple Court Hotel']],
#  'boyfriend': [[0.875, 'Apex Temple Court Hotel']],
#  'discount': [[0, 'Apex Temple Court Hotel']],
#  'london eye': [[0, 'Apex Temple Court Hotel']],
#  'day': [[6.0, 'Hotel Arena'],
#   [3.75, 'K K Hotel George'],
#   [2.375, 'The Principal London'],
#   [1.375, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'decoration': [[1.25, 'Apex Temple Court Hotel']],
#  'oven': [[0.375, 'K K Hotel George']],
#  'bathroom mirror': [[1.0, 'Apex Temple Court Hotel']],
#  'toaster': [[0, 'K K Hotel George']],
#  'manager': [[0, 'The Park Grand London Paddington'], [0, 'Hotel Arena']],
#  'extras': [[0, 'Apex Temple Court Hotel']],
#  'bio weapon': [[0, 'Hotel Arena']],
#  'euston hilton hotel': [[0, 'The Principal London']],
#  'spoonful': [[1.0, 'Apex Temple Court Hotel']],
#  'boiler unit': [[0.75, 'The Park Grand London Paddington']],
#  'picadilly tube': [[6.25, 'The Principal London']],
#  'brit': [[0, 'Hotel Arena']],
#  'plate': [[0.25, 'The Park Grand London Paddington']],
#  'construction renovation': [[0, 'Hotel Arena']],
#  'job': [[0.75, 'Apex Temple Court Hotel'], [0, 'K K Hotel George']],
#  'business centre': [[0, 'K K Hotel George']],
#  'stair case': [[2.75, 'The Principal London']],
#  'english style': [[1.5, 'K K Hotel George']],
#  'barefoot': [[0, 'Hotel Arena']],
#  'room price': [[0, 'Apex Temple Court Hotel']],
#  'tour': [[1.625, 'The Principal London'], [0, 'Hotel Arena']],
#  'clineanliness': [[1.0, 'K K Hotel George']],
#  'junior suite': [[0, 'Apex Temple Court Hotel']],
#  'bathroom': [[10.5, 'Apex Temple Court Hotel'],
#   [5.875, 'The Principal London'],
#   [5.625, 'K K Hotel George'],
#   [3.125, 'Hotel Arena'],
#   [2.5, 'The Park Grand London Paddington']],
#  'room bar': [[0, 'K K Hotel George']],
#  'concierge desk': [[1.5, 'The Park Grand London Paddington']],
#  'rainfall': [[1.375, 'Hotel Arena']],
#  'top': [[1.875, 'Hotel Arena'],
#   [0.5, 'Apex Temple Court Hotel'],
#   [0.375, 'The Park Grand London Paddington']],
#  'location breakfast': [[4.0, 'The Principal London']],
#  'fitness area': [[2.5, 'K K Hotel George']],
#  'wardrobe space': [[3.0, 'The Park Grand London Paddington'],
#   [1.0, 'Apex Temple Court Hotel']],
#  'remodeling': [[0, 'Hotel Arena']],
#  'iphone': [[0, 'Apex Temple Court Hotel']],
#  'room service': [[5.625, 'The Principal London'],
#   [2.5, 'The Park Grand London Paddington'],
#   [1.0, 'Apex Temple Court Hotel']],
#  'opinion': [[2.5, 'Hotel Arena'], [1.75, 'The Principal London']],
#  'layout': [[0, 'The Park Grand London Paddington']],
#  'consisting': [[1.0, 'Apex Temple Court Hotel']],
#  'propert': [[0.75, 'The Park Grand London Paddington']],
#  'board iron': [[0.75, 'Apex Temple Court Hotel']],
#  'hotel inside': [[4.375, 'Hotel Arena']],
#  'flight': [[0, 'The Principal London'],
#   [0, 'The Park Grand London Paddington']],
#  'addition': [[0, 'The Principal London']],
#  'element': [[0.5, 'Hotel Arena']],
#  'atmosphere': [[1.0, 'Apex Temple Court Hotel']],
#  'book breakfast': [[0.25, 'K K Hotel George']],
#  'food comfy': [[1.0, 'The Principal London']],
#  'deposit': [[0.875, 'Hotel Arena'], [0, 'K K Hotel George']],
#  'advertising': [[0.875, 'Hotel Arena']],
#  'rubber duck': [[0, 'Apex Temple Court Hotel']],
#  'im i': [[2.125, 'The Park Grand London Paddington']],
#  'smartphone': [[0, 'The Principal London']],
#  'tea': [[1.375, 'The Principal London'],
#   [0.5, 'The Park Grand London Paddington'],
#   [0, 'K K Hotel George'],
#   [0, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'happening': [[0, 'Apex Temple Court Hotel']],
#  'minute': [[0, 'The Park Grand London Paddington']],
#  'trash lorry': [[0, 'Hotel Arena']],
#  'room space': [[0, 'K K Hotel George']],
#  'disruption': [[0.875, 'Hotel Arena']],
#  'eurostar room': [[4.25, 'The Principal London']],
#  'front entrance': [[2.5, 'Apex Temple Court Hotel']],
#  'hot': [[0.625, 'Hotel Arena']],
#  'solo': [[0, 'K K Hotel George']],
#  'space cost money': [[0, 'K K Hotel George']],
#  'minute walk': [[11.0, 'K K Hotel George'],
#   [2.25, 'The Principal London'],
#   [1.0, 'Hotel Arena']],
#  'concierge service': [[6.25, 'The Principal London']],
#  'mile': [[0.875, 'Hotel Arena'], [0.5, 'Apex Temple Court Hotel']],
#  'design disaster': [[1.5, 'Hotel Arena']],
#  'dozen': [[0, 'The Principal London']],
#  'kind': [[3.375, 'K K Hotel George'],
#   [1.375, 'Apex Temple Court Hotel'],
#   [0, 'The Principal London']],
#  'windows': [[0, 'K K Hotel George']],
#  'health food': [[1.0, 'Hotel Arena']],
#  'you': [[0, 'Apex Temple Court Hotel']],
#  'bathroom shower': [[1.5, 'K K Hotel George']],
#  'shard half hour walk': [[0, 'Apex Temple Court Hotel']],
#  'ground floor': [[0, 'The Principal London']],
#  'cohen': [[1.375, 'The Principal London']],
#  'seat': [[0, 'K K Hotel George']],
#  'room service menu': [[1.875, 'The Park Grand London Paddington']],
#  'urine': [[0, 'The Park Grand London Paddington']],
#  'twin bed': [[0, 'The Park Grand London Paddington']],
#  'weird': [[1.125, 'The Park Grand London Paddington']],
#  'tram stop': [[1.0, 'Hotel Arena']],
#  'covent garden': [[3.25, 'The Principal London'],
#   [0, 'Apex Temple Court Hotel']],
#  'choice': [[2.375, 'K K Hotel George'], [1.375, 'The Principal London']],
#  'value': [[2.0, 'The Principal London'],
#   [1.125, 'Apex Temple Court Hotel'],
#   [0.5, 'The Park Grand London Paddington'],
#   [0.5, 'K K Hotel George']],
#  'care': [[1.875, 'Hotel Arena']],
#  'brunch': [[0.5, 'Hotel Arena']],
#  'packet': [[0, 'Apex Temple Court Hotel']],
#  'traffic noise': [[1.0, 'Apex Temple Court Hotel']],
#  'soap': [[0.875, 'Hotel Arena']],
#  'big window': [[3.75, 'The Park Grand London Paddington']],
#  'supplement': [[0, 'Apex Temple Court Hotel']],
#  'slab': [[0, 'Apex Temple Court Hotel']],
#  'tooth': [[0, 'Apex Temple Court Hotel']],
#  'ground floor room l01': [[0, 'K K Hotel George']],
#  'visit': [[1.25, 'The Park Grand London Paddington'],
#   [0.125, 'The Principal London']],
#  'breakfast staff': [[0.875, 'K K Hotel George'], [0.75, 'Hotel Arena']],
#  'theatre district': [[0, 'Apex Temple Court Hotel']],
#  'uk vacation': [[0, 'K K Hotel George']],
#  'info': [[0.875, 'Apex Temple Court Hotel']],
#  'way': [[3.625, 'Hotel Arena'],
#   [2.5, 'Apex Temple Court Hotel'],
#   [1.75, 'The Park Grand London Paddington'],
#   [1.125, 'The Principal London'],
#   [0.625, 'K K Hotel George']],
#  'banging': [[0.5, 'Hotel Arena']],
#  'oosterpark': [[0.75, 'Hotel Arena']],
#  'russell square gardens': [[4.125, 'The Principal London']],
#  'work': [[1.75, 'The Park Grand London Paddington'],
#   [0.875, 'The Principal London'],
#   [0.875, 'Hotel Arena'],
#   [0.75, 'K K Hotel George']],
#  'beer': [[0.75, 'K K Hotel George'], [0, 'Apex Temple Court Hotel']],
#  'easy': [[1.0, 'K K Hotel George'], [0.875, 'Apex Temple Court Hotel']],
#  'c control': [[0, 'The Park Grand London Paddington']],
#  'conceierge service': [[2.75, 'Apex Temple Court Hotel']],
#  'english breakfast': [[2.0, 'The Park Grand London Paddington']],
#  'staffed': [[0.75, 'The Park Grand London Paddington']],
#  'clockwork': [[0.875, 'The Principal London']],
#  'bottle': [[0.375, 'The Principal London']],
#  'mood': [[0.75, 'Hotel Arena']],
#  'clock': [[0, 'Hotel Arena']],
#  'speed': [[0, 'Hotel Arena']],
#  'building meeting': [[0, 'Hotel Arena']],
#  'nail': [[0.375, 'Hotel Arena']],
#  'slip mat': [[0, 'K K Hotel George']],
#  'jug': [[0, 'Apex Temple Court Hotel']],
#  'world': [[1.125, 'The Principal London'], [0, 'K K Hotel George']],
#  'pop': [[0.375, 'Hotel Arena']],
#  'doorman': [[1.125, 'The Principal London']],
#  'pm': [[0, 'The Principal London']],
#  'start': [[0.5, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'room size': [[0.25, 'K K Hotel George']],
#  'tv': [[1.375, 'Apex Temple Court Hotel'],
#   [0.375, 'K K Hotel George'],
#   [0.375, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington']],
#  'hallway wall': [[3.75, 'Apex Temple Court Hotel']],
#  'bonus': [[1.5, 'The Principal London'],
#   [1.5, 'K K Hotel George'],
#   [0.875, 'Apex Temple Court Hotel']],
#  'road side': [[0.625, 'The Principal London']],
#  'glass window': [[0, 'Hotel Arena']],
#  'crazy': [[0, 'The Principal London']],
#  'signal': [[0.375, 'The Park Grand London Paddington']],
#  'someone': [[1.25, 'Hotel Arena'], [0, 'The Park Grand London Paddington']],
#  'dirt': [[1.375, 'Hotel Arena']],
#  'requested room change given room': [[3.375, 'The Principal London']],
#  'apex hotel': [[1.75, 'Apex Temple Court Hotel']],
#  'novello': [[0, 'Apex Temple Court Hotel']],
#  'site restaurant': [[3.25, 'Hotel Arena']],
#  'service': [[1.75, 'Hotel Arena'],
#   [1.125, 'K K Hotel George'],
#   [0, 'Apex Temple Court Hotel']],
#  'idea': [[0.75, 'Hotel Arena'],
#   [0.625, 'K K Hotel George'],
#   [0, 'Apex Temple Court Hotel']],
#  'luca': [[0.5, 'Apex Temple Court Hotel']],
#  'challenge': [[0, 'The Park Grand London Paddington']],
#  'repairman': [[0.5, 'Hotel Arena']],
#  'london older facility': [[3.75, 'K K Hotel George']],
#  'engineer': [[0.875, 'The Principal London']],
#  'hotel dirty dusty': [[0.875, 'Hotel Arena']],
#  'shampoo body': [[1.25, 'Hotel Arena']],
#  'design': [[2.25, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'cost': [[1.125, 'K K Hotel George']],
#  'city tax': [[0, 'Hotel Arena']],
#  'thursday': [[0, 'Apex Temple Court Hotel']],
#  'wider': [[0.5, 'The Park Grand London Paddington']],
#  'chill': [[1.375, 'Hotel Arena']],
#  'move': [[1.625, 'The Principal London'],
#   [0.375, 'The Park Grand London Paddington']],
#  'potato': [[0.375, 'K K Hotel George']],
#  'room bathroom': [[0, 'K K Hotel George']],
#  'lot': [[1.625, 'Apex Temple Court Hotel'],
#   [0.75, 'Hotel Arena'],
#   [0, 'K K Hotel George']],
#  'bathroom smelt': [[0.5, 'Hotel Arena']],
#  'structure': [[1.25, 'K K Hotel George'], [0.375, 'Hotel Arena']],
#  'taxi': [[1.125, 'K K Hotel George'],
#   [0.875, 'The Park Grand London Paddington'],
#   [0, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'split level room': [[1.875, 'Hotel Arena']],
#  'water boiler': [[0.5, 'K K Hotel George']],
#  'site': [[1.0, 'K K Hotel George'],
#   [0, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'bother': [[0.25, 'The Principal London']],
#  'basement room': [[0.5, 'K K Hotel George'],
#   [0, 'The Park Grand London Paddington']],
#  'patch': [[1.0, 'The Park Grand London Paddington']],
#  'pain': [[0, 'Hotel Arena']],
#  'noise': [[1.125, 'Hotel Arena'],
#   [0.5, 'The Park Grand London Paddington'],
#   [0.375, 'K K Hotel George'],
#   [0.125, 'The Principal London']],
#  'reason': [[0.625, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'wedding anniversary': [[0, 'The Principal London']],
#  'drink': [[1.125, 'K K Hotel George'],
#   [0.875, 'The Park Grand London Paddington'],
#   [0, 'The Principal London']],
#  'buffet': [[2.625, 'K K Hotel George'],
#   [0.5, 'Hotel Arena'],
#   [0, 'Apex Temple Court Hotel']],
#  'friday': [[0, 'Apex Temple Court Hotel']],
#  'cafes': [[2.25, 'The Park Grand London Paddington']],
#  'coffee machine': [[0.5, 'Apex Temple Court Hotel']],
#  'feed': [[0, 'The Principal London']],
#  'gowns': [[0, 'The Park Grand London Paddington']],
#  'neck': [[0, 'K K Hotel George']],
#  'weekend': [[2.875, 'Apex Temple Court Hotel']],
#  'outside': [[2.5, 'The Principal London'], [0.625, 'Hotel Arena']],
#  'erls court': [[0, 'K K Hotel George']],
#  'celcius': [[0, 'Hotel Arena']],
#  'bag': [[2.375, 'The Park Grand London Paddington']],
#  'ceiling room': [[0, 'The Park Grand London Paddington']],
#  'room desk': [[1.0, 'K K Hotel George']],
#  'room luxurious': [[1.0, 'The Park Grand London Paddington']],
#  'booking': [[0, 'The Principal London'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'first': [[1.0, 'The Park Grand London Paddington'], [0, 'Hotel Arena']],
#  'public': [[0.25, 'Hotel Arena']],
#  'tourist bustle': [[3.25, 'K K Hotel George']],
#  'one office chair': [[8.5, 'Apex Temple Court Hotel']],
#  'nice room': [[0, 'Apex Temple Court Hotel']],
#  'room fit': [[0, 'The Park Grand London Paddington']],
#  'heart': [[0.875, 'The Principal London'],
#   [0.625, 'The Park Grand London Paddington'],
#   [0.625, 'Apex Temple Court Hotel']],
#  'museum': [[0.375, 'The Principal London']],
#  'end room': [[1.5, 'Apex Temple Court Hotel']],
#  'interest': [[0, 'Hotel Arena']],
#  'opportunity': [[0, 'K K Hotel George']],
#  'amsterdam would': [[1.0, 'Hotel Arena']],
#  'window': [[2.125, 'The Park Grand London Paddington'],
#   [2.125, 'Hotel Arena'],
#   [0.625, 'K K Hotel George']],
#  'minimalistic': [[2.5, 'Apex Temple Court Hotel']],
#  'awesome park': [[2.625, 'Hotel Arena']],
#  'chair room service hair dryer fridge kettle': [[4.625, 'Hotel Arena']],
#  'walkway': [[0, 'Apex Temple Court Hotel']],
#  'amenity': [[0, 'K K Hotel George']],
#  'section': [[0, 'Apex Temple Court Hotel']],
#  'bar staff': [[0, 'Hotel Arena']],
#  'super location': [[0, 'K K Hotel George']],
#  'paddington station good': [[1.875, 'The Park Grand London Paddington']],
#  'difference': [[2.875, 'The Park Grand London Paddington'],
#   [0.5, 'K K Hotel George']],
#  'adult': [[0, 'The Park Grand London Paddington']],
#  'stuff': [[0.875, 'Apex Temple Court Hotel']],
#  'nice bathroom': [[0.5, 'Apex Temple Court Hotel']],
#  'piccadilly line': [[0.75, 'The Principal London'], [0, 'K K Hotel George']],
#  'transaction': [[0.375, 'Hotel Arena']],
#  'pond': [[0.25, 'Hotel Arena']],
#  'time': [[2.0, 'Hotel Arena'],
#   [1.625, 'K K Hotel George'],
#   [1.5, 'The Principal London'],
#   [0, 'The Park Grand London Paddington'],
#   [0, 'Apex Temple Court Hotel']],
#  'transportation': [[2.75, 'Hotel Arena'], [0, 'The Principal London']],
#  'excuse': [[1.0, 'The Park Grand London Paddington']],
#  'sort': [[0, 'The Park Grand London Paddington'], [0, 'Hotel Arena']],
#  'miniscule': [[0, 'K K Hotel George']],
#  'website': [[0.25, 'Hotel Arena']],
#  'exit right': [[2.25, 'The Principal London']],
#  'lobby': [[0.875, 'K K Hotel George'],
#   [0.375, 'Hotel Arena'],
#   [0, 'The Principal London']],
#  'ca': [[1.375, 'K K Hotel George'],
#   [0.625, 'Hotel Arena'],
#   [0, 'The Park Grand London Paddington']],
#  'forget': [[0, 'Hotel Arena']],
#  'traffic': [[0, 'The Principal London']],
#  'possibility': [[2.5, 'Apex Temple Court Hotel']],
#  'breakfast table': [[0.625, 'K K Hotel George']],
#  'pub': [[0, 'The Park Grand London Paddington']],
#  'opposite': [[0.25, 'The Principal London']],
#  'product': [[0.125, 'Hotel Arena']],
#  'australia': [[0, 'The Park Grand London Paddington']],
#  'room breakfast': [[1.125, 'The Principal London']],
#  'manner': [[0.625, 'The Park Grand London Paddington']],
#  'ranging': [[0.25, 'K K Hotel George']],
#  'leeds very kind': [[4.5, 'K K Hotel George']],
#  'incredibly': [[0.625, 'The Principal London']],
#  'state': [[1.125, 'Hotel Arena']],
#  'center train': [[2.5, 'Hotel Arena']],
#  'upper woburn': [[0, 'The Principal London']],
#  'tram ride': [[2.5, 'Hotel Arena']],
#  'chain': [[0.25, 'The Park Grand London Paddington']],
#  'luggage': [[0.875, 'The Principal London'],
#   [0.875, 'The Park Grand London Paddington'],
#   [0, 'Hotel Arena']],
#  'shower temp control': [[1.5, 'K K Hotel George']],
#  'office': [[2.5, 'Apex Temple Court Hotel'], [1.125, 'K K Hotel George']],
#  'quality comfy bar': [[4.5, 'The Principal London']],
#  'room': [[31.875, 'The Park Grand London Paddington'],
#   [25.375, 'Hotel Arena'],
#   [21.625, 'The Principal London'],
#   [15.25, 'Apex Temple Court Hotel'],
#   [11.5, 'K K Hotel George']],
#  'survivor': [[0.25, 'The Principal London']],
#  'today': [[0, 'The Principal London'], [0, 'K K Hotel George']],
#  'airy': [[0, 'Hotel Arena']],
#  'ticket machine': [[1.0, 'Hotel Arena']],
#  'side': [[1.375, 'The Principal London'], [1.125, 'Apex Temple Court Hotel']],
#  'issue': [[0.875, 'Hotel Arena'],
#   [0.5, 'The Park Grand London Paddington'],
#   [0.5, 'K K Hotel George'],
#   [0, 'The Principal London'],
#   [0, 'Apex Temple Court Hotel']],
#  'hair parking': [[0.5, 'The Park Grand London Paddington']],
#  'party': [[0.625, 'Hotel Arena'], [0.5, 'Apex Temple Court Hotel']],
#  'comfort': [[1.5, 'The Principal London']],
#  'inside': [[0.875, 'Apex Temple Court Hotel'], [0.625, 'Hotel Arena']],
#  'box': [[1.375, 'Apex Temple Court Hotel'],
#   [0.625, 'The Park Grand London Paddington']],
#  'gym': [[0.5, 'K K Hotel George']],
#  'system outage': [[2.75, 'Apex Temple Court Hotel']],
#  'travel': [[0, 'The Principal London']],
#  'potatoes': [[0, 'The Principal London']],
#  'disatisfaction': [[0, 'The Park Grand London Paddington']],
#  'run': [[0.5, 'The Park Grand London Paddington']],
#  'rooftop room': [[1.0, 'The Park Grand London Paddington']],
#  'night room': [[2.0, 'Hotel Arena']],
#  'bedroom': [[0.875, 'Hotel Arena'],
#   [0.5, 'The Principal London'],
#   [0.25, 'Apex Temple Court Hotel']],
#  'hall': [[0, 'Hotel Arena']],
#  'well operating walk': [[0, 'K K Hotel George']],
#  'kind gesture': [[1.5, 'The Principal London']],
#  'francis': [[0, 'Apex Temple Court Hotel']],
#  'hidden wardrobe drop': [[0, 'The Park Grand London Paddington']],
#  'hyde park': [[0.75, 'The Park Grand London Paddington']],
#  'resection': [[2.0, 'The Principal London']],
#  'cheaper': [[0, 'The Principal London']],
#  'staff offer': [[1.75, 'Hotel Arena']],
#  'bay': [[0.125, 'The Principal London']],
#  'refrigerator': [[0, 'Hotel Arena']],
#  'british': [[0, 'The Principal London']],
#  'paddngton station': [[0, 'The Park Grand London Paddington']],
#  'bar area': [[6.75, 'Hotel Arena'],
#   [1.0, 'K K Hotel George'],
#   [1.0, 'Apex Temple Court Hotel']],
#  'broken window': [[1.25, 'Hotel Arena']],
#  'inquiry': [[0.625, 'K K Hotel George']],
#  'alley': [[0, 'The Park Grand London Paddington']],
#  'sq': [[0, 'The Principal London']],
#  'road nice': [[1.25, 'K K Hotel George']],
#  'b': [[1.0, 'K K Hotel George']],
#  'park grand london paddington underground station': [[5.25,
#    'The Park Grand London Paddington']],
#  'iron': [[0.375, 'The Park Grand London Paddington']],
#  'middle': [[1.0, 'Hotel Arena'], [0.5, 'The Principal London']],
#  'background': [[1.625, 'Hotel Arena']],
#  'chocolate': [[0.25, 'Apex Temple Court Hotel']],
#  'hassle': [[0.625, 'Apex Temple Court Hotel']],
#  'standard room': [[2.25, 'Apex Temple Court Hotel']],
#  'complimentary fruit water': [[0, 'The Park Grand London Paddington']],
#  'cleaning lady': [[0.625, 'Hotel Arena']],
#  'cell wifi': [[0, 'The Park Grand London Paddington']],
#  'building park location': [[0, 'Hotel Arena']],
#  'variety': [[0.75, 'Hotel Arena'], [0.25, 'Apex Temple Court Hotel']],
#  'tube stop': [[2.25, 'The Principal London']],
#  'story': [[0, 'Hotel Arena']],
#  'fond': [[0.5, 'The Park Grand London Paddington']],
#  'beat': [[0, 'K K Hotel George']],
#  'hdmi cable': [[0, 'K K Hotel George']],
#  'english': [[1.375, 'The Principal London'], [0.375, 'K K Hotel George']],
#  'satisfactory': [[0, 'K K Hotel George']],
#  'staircase': [[1.5, 'Hotel Arena'], [0.375, 'The Principal London']],
#  'birthday': [[0.5, 'The Principal London'], [0, 'Apex Temple Court Hotel']],
#  'tasty': [[0.625, 'The Park Grand London Paddington']],
#  'entrance': [[2.125, 'Apex Temple Court Hotel'],
#   [1.875, 'The Park Grand London Paddington'],
#   [0.375, 'Hotel Arena']],
#  'couple': [[1.0, 'Apex Temple Court Hotel'], [0.25, 'Hotel Arena']],
#  'cramped': [[0.625, 'The Principal London'],
#   [0.625, 'The Park Grand London Paddington']],
#  'area sauna': [[2.5, 'K K Hotel George']],
#  'existent': [[0, 'Hotel Arena']],
#  'request': [[0.625, 'K K Hotel George'],
#   [0.125, 'The Park Grand London Paddington'],
#   [0, 'Hotel Arena']],
#  'thermostat': [[0, 'Hotel Arena']],
#  'bedroom suite': [[3.75, 'The Principal London']],
#  'sofa': [[0, 'The Park Grand London Paddington']],
#  'glass wall': [[0, 'Hotel Arena']],
#  'kind breakfast': [[1.0, 'K K Hotel George']],
#  'experience': [[1.125, 'The Principal London'], [0.75, 'K K Hotel George']],
#  'decorating': [[1.375, 'The Principal London']],
#  'subway station customers': [[2.625, 'Apex Temple Court Hotel']],
#  'bottle opener': [[3.75, 'Apex Temple Court Hotel']],
#  'front desk staff would love': [[1.875, 'K K Hotel George']],
#  'has': [[0, 'K K Hotel George']],
#  'great transport system': [[3.0, 'The Park Grand London Paddington']],
#  'elephant': [[0.875, 'Apex Temple Court Hotel']],
#  'situation': [[0, 'Hotel Arena']],
#  'impact': [[0, 'The Principal London']],
#  'email': [[0, 'Apex Temple Court Hotel']],
#  'shortage': [[0, 'The Park Grand London Paddington']],
#  'interior': [[0.5, 'The Principal London']],
#  'hair dryer': [[1.5, 'K K Hotel George'], [1.25, 'Hotel Arena']],
#  'toilet bowl': [[1.125, 'Apex Temple Court Hotel']],
#  'inconvenience': [[0, 'The Park Grand London Paddington']],
#  'plane': [[0, 'Apex Temple Court Hotel']],
#  'theater district': [[0, 'Apex Temple Court Hotel']],
#  'bathroom door': [[1.25, 'The Park Grand London Paddington']],
#  'billowing': [[1.0, 'K K Hotel George']],
#  'visit special': [[1.25, 'K K Hotel George']],
#  'light outside': [[0, 'The Principal London']],
#  'milk': [[0.375, 'The Principal London']],
#  'room pillows': [[0.5, 'K K Hotel George']],
#  'solution': [[0, 'Hotel Arena']],
#  'monday': [[0, 'The Principal London']],
#  'would': [[1.5, 'K K Hotel George']],
#  'morn': [[0.125, 'The Principal London']],
#  ...}

# %%
# Store the hotel data
outfile = open("Stored Data/sample_hotel_info.pickle", "wb")
pk.dump(hotel_info, outfile)
outfile.close()

# Store the aspect data
outfile = open("Stored Data/sample_aspect_info.pickle", "wb")
pk.dump(aspects_info, outfile)
outfile.close()
